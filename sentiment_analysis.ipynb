# %% [markdown]
# # Sentiment analysis
#
# In this notebook two sentiment analysis techniques will be applied:
# 1. VADER (Valence Aware Dictionaty and sEntiment Reasoner) - Bag of words approach
# 2. Roberta Pretrained Model from huggingface
# 3. Huggingface Pipeline

# %% [markdown]
# Read in Data and `NLTK` Basics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import webvtt

plt.style.use('ggplot')

import nltk

# %%
# Path to your .vtt file
vtt_file = '/Users/nico/Desktop/Projects/word_analyses_DW/code/youtube_output/¿Cómo podría el conflicto entre Israel y Hamás ampliarse en Medio Oriente？.es.vtt'

vtt = webvtt.read(vtt_file)

# print the content in WebVTT format
print(vtt.content)
# Out:
# WEBVTT
#
# 00:00:02.230 --> 00:00:02.240
# todo el mundo habla del riesgo de una
#
# 00:00:02.240 --> 00:00:03.909
# todo el mundo habla del riesgo de una
# escalada<00:00:02.639><c> en</c><00:00:02.800><c> medio</c><00:00:03.080><c> oriente</c><00:00:03.719><c> las</c>
#
# 00:00:03.909 --> 00:00:03.919
# escalada en medio oriente las
#
# 00:00:03.919 --> 00:00:05.950
# escalada en medio oriente las
# iniciativas<00:00:04.560><c> diplomáticas</c><00:00:05.480><c> ya</c><00:00:05.600><c> se</c><00:00:05.759><c> han</c>
#
# 00:00:05.950 --> 00:00:05.960
# iniciativas diplomáticas ya se han
#
# 00:00:05.960 --> 00:00:08.190
# iniciativas diplomáticas ya se han
# activado<00:00:06.440><c> e</c><00:00:06.680><c> intentan</c><00:00:07.200><c> frenéticamente</c>
#
# 00:00:08.190 --> 00:00:08.200
# activado e intentan frenéticamente
#
# 00:00:08.200 --> 00:00:10.350
# activado e intentan frenéticamente
# detener<00:00:08.760><c> la</c><00:00:08.880><c> propagación</c><00:00:09.400><c> del</c><00:00:09.599><c> conflicto</c>
#
# 00:00:10.350 --> 00:00:10.360
# detener la propagación del conflicto
#
# 00:00:10.360 --> 00:00:12.789
# detener la propagación del conflicto
# Pero<00:00:10.599><c> qué</c><00:00:10.759><c> es</c><00:00:10.880><c> lo</c><00:00:11.000><c> que</c><00:00:11.120><c> podría</c><00:00:11.480><c> ocurrir</c><00:00:12.240><c> veamos</c>
#
# 00:00:12.789 --> 00:00:12.799
# Pero qué es lo que podría ocurrir veamos
#
# 00:00:12.799 --> 00:00:14.709
# Pero qué es lo que podría ocurrir veamos
# paso<00:00:13.080><c> a</c><00:00:13.240><c> paso</c><00:00:13.519><c> cuál</c><00:00:13.799><c> sería</c><00:00:14.080><c> un</c><00:00:14.280><c> posible</c>
#
# 00:00:14.709 --> 00:00:14.719
# paso a paso cuál sería un posible
#
# 00:00:14.719 --> 00:00:16.990
# paso a paso cuál sería un posible
# escenario<00:00:15.400><c> En</c><00:00:15.639><c> caso</c><00:00:16.039><c> de</c><00:00:16.160><c> que</c><00:00:16.279><c> se</c><00:00:16.400><c> intensifique</c>
#
# 00:00:16.990 --> 00:00:17.000
# escenario En caso de que se intensifique
#
# 00:00:17.000 --> 00:00:19.630
# escenario En caso de que se intensifique
# el<00:00:17.119><c> conflicto</c><00:00:17.920><c> primer</c><00:00:18.320><c> paso</c><00:00:18.920><c> empecemos</c><00:00:19.439><c> por</c>
#
# 00:00:19.630 --> 00:00:19.640
# el conflicto primer paso empecemos por
#
# 00:00:19.640 --> 00:00:21.590
# el conflicto primer paso empecemos por
# donde<00:00:19.960><c> estamos</c><00:00:20.240><c> ahora</c><00:00:20.840><c> los</c><00:00:21.039><c> atentados</c>
#
# 00:00:21.590 --> 00:00:21.600
# donde estamos ahora los atentados
#
# 00:00:21.600 --> 00:00:24.269
# donde estamos ahora los atentados
# terroristas<00:00:22.080><c> de</c><00:00:22.439><c> jamás</c><00:00:22.920><c> del</c><00:00:23.080><c> 7</c><00:00:23.480><c> de</c><00:00:23.560><c> octubre</c>
#
# 00:00:24.269 --> 00:00:24.279
# terroristas de jamás del 7 de octubre
#
# 00:00:24.279 --> 00:00:26.109
# terroristas de jamás del 7 de octubre
# fueron<00:00:24.640><c> los</c><00:00:24.800><c> más</c><00:00:25.039><c> mortíferos</c><00:00:25.720><c> desde</c><00:00:26.000><c> la</c>
#
# 00:00:26.109 --> 00:00:26.119
# fueron los más mortíferos desde la
#
# 00:00:26.119 --> 00:00:28.990
# fueron los más mortíferos desde la
# fundación<00:00:26.519><c> de</c><00:00:26.720><c> Israel</c><00:00:27.720><c> Israel</c><00:00:28.320><c> se</c><00:00:28.439><c> dispone</c><00:00:28.800><c> a</c>
#
# 00:00:28.990 --> 00:00:29.000
# fundación de Israel Israel se dispone a
#
# 00:00:29.000 --> 00:00:30.990
# fundación de Israel Israel se dispone a
# invadir<00:00:29.320><c> la</c><00:00:29.400><c> franja</c><00:00:29.759><c> de</c><00:00:30.039><c> gaza</c><00:00:30.439><c> para</c><00:00:30.599><c> acabar</c>
#
# 00:00:30.990 --> 00:00:31.000
# invadir la franja de gaza para acabar
#
# 00:00:31.000 --> 00:00:33.790
# invadir la franja de gaza para acabar
# con<00:00:31.160><c> los</c><00:00:31.359><c> militantes</c><00:00:31.920><c> islamistas</c><00:00:32.800><c> en</c><00:00:33.079><c> Líbano</c>
#
# 00:00:33.790 --> 00:00:33.800
# con los militantes islamistas en Líbano
#
# 00:00:33.800 --> 00:00:36.709
# con los militantes islamistas en Líbano
# al<00:00:34.040><c> norte</c><00:00:34.320><c> de</c><00:00:34.480><c> Israel</c><00:00:35.239><c> la</c><00:00:35.440><c> milicia</c><00:00:35.800><c> de</c><00:00:35.960><c> hezbolá</c>
#
# 00:00:36.709 --> 00:00:36.719
# al norte de Israel la milicia de hezbolá
#
# 00:00:36.719 --> 00:00:39.549
# al norte de Israel la milicia de hezbolá
# aliada<00:00:37.200><c> de</c><00:00:37.320><c> hamás</c><00:00:38.160><c> ha</c><00:00:38.399><c> estado</c><00:00:38.800><c> disparando</c><00:00:39.440><c> a</c>
#
# 00:00:39.549 --> 00:00:39.559
# aliada de hamás ha estado disparando a
#
# 00:00:39.559 --> 00:00:41.950
# aliada de hamás ha estado disparando a
# través<00:00:39.920><c> de</c><00:00:40.039><c> la</c><00:00:40.160><c> frontera</c><00:00:40.920><c> Israel</c><00:00:41.719><c> ha</c>
#
# 00:00:41.950 --> 00:00:41.960
# través de la frontera Israel ha
#
# 00:00:41.960 --> 00:00:44.549
# través de la frontera Israel ha
# respondido<00:00:42.440><c> al</c><00:00:42.600><c> fuego</c><00:00:43.280><c> y</c><00:00:43.600><c> apoyando</c><00:00:44.079><c> tanto</c><00:00:44.320><c> a</c>
#
# 00:00:44.549 --> 00:00:44.559
# respondido al fuego y apoyando tanto a
#
# 00:00:44.559 --> 00:00:47.430
# respondido al fuego y apoyando tanto a
# jamás<00:00:45.000><c> como</c><00:00:45.120><c> a</c><00:00:45.320><c> hezbolá</c><00:00:45.960><c> está</c><00:00:46.559><c> Irán</c><00:00:47.160><c> por</c>
#
# 00:00:47.430 --> 00:00:47.440
# jamás como a hezbolá está Irán por
#
# 00:00:47.440 --> 00:00:50.229
# jamás como a hezbolá está Irán por
# décadas<00:00:48.320><c> los</c><00:00:48.559><c> enfrentamientos</c><00:00:49.559><c> no</c><00:00:49.760><c> habían</c>
#
# 00:00:50.229 --> 00:00:50.239
# décadas los enfrentamientos no habían
#
# 00:00:50.239 --> 00:00:53.950
# décadas los enfrentamientos no habían
# sido<00:00:50.640><c> tan</c><00:00:51.160><c> intensos</c><00:00:52.160><c> Entonces</c><00:00:53.120><c> qué</c><00:00:53.399><c> podría</c>
#
# 00:00:53.950 --> 00:00:53.960
# sido tan intensos Entonces qué podría
#
# 00:00:53.960 --> 00:00:56.270
# sido tan intensos Entonces qué podría
# suceder<00:00:54.399><c> a</c><00:00:54.760><c> continuación</c><00:00:55.600><c> empecemos</c><00:00:56.079><c> a</c>
#
# 00:00:56.270 --> 00:00:56.280
# suceder a continuación empecemos a
#
# 00:00:56.280 --> 00:00:58.950
# suceder a continuación empecemos a
# adentrarnos<00:00:56.840><c> en</c><00:00:57.280><c> este</c><00:00:57.640><c> posible</c><00:00:58.079><c> escenario</c>
#
# 00:00:58.950 --> 00:00:58.960
# adentrarnos en este posible escenario
#
# 00:00:58.960 --> 00:01:00.670
# adentrarnos en este posible escenario
# paso<00:00:59.239><c> dos</c><00:00:59.920><c> un</c>
#
# 00:01:00.670 --> 00:01:00.680
# paso dos un
#
# 00:01:00.680 --> 00:01:03.549
# paso dos un
# multiframe<00:01:01.680><c> netanyahu</c><00:01:02.519><c> el</c><00:01:02.760><c> Primer</c><00:01:03.120><c> Ministro</c>
#
# 00:01:03.549 --> 00:01:03.559
# multiframe netanyahu el Primer Ministro
#
# 00:01:03.559 --> 00:01:06.270
# multiframe netanyahu el Primer Ministro
# israelí<00:01:04.479><c> envía</c><00:01:04.960><c> sus</c><00:01:05.159><c> tropas</c><00:01:05.439><c> a</c><00:01:05.600><c> la</c><00:01:05.760><c> franja</c><00:01:06.159><c> de</c>
#
# 00:01:06.270 --> 00:01:06.280
# israelí envía sus tropas a la franja de
#
# 00:01:06.280 --> 00:01:10.070
# israelí envía sus tropas a la franja de
# gaza<00:01:06.680><c> hezbolá</c><00:01:07.680><c> intensificar</c><00:01:08.680><c> sus</c><00:01:08.880><c> ataques</c><00:01:09.560><c> en</c>
#
# 00:01:10.070 --> 00:01:10.080
# gaza hezbolá intensificar sus ataques en
#
# 00:01:10.080 --> 00:01:12.630
# gaza hezbolá intensificar sus ataques en
# cisjordania<00:01:11.040><c> los</c><00:01:11.240><c> militantes</c><00:01:11.960><c> atacarían</c>
#
# 00:01:12.630 --> 00:01:12.640
# cisjordania los militantes atacarían
#
# 00:01:12.640 --> 00:01:15.870
# cisjordania los militantes atacarían
# objetivos<00:01:13.240><c> israelíes</c><00:01:14.240><c> en</c><00:01:14.439><c> el</c><00:01:14.600><c> noreste</c><00:01:15.439><c> las</c>
#
# 00:01:15.870 --> 00:01:15.880
# objetivos israelíes en el noreste las
#
# 00:01:15.880 --> 00:01:18.429
# objetivos israelíes en el noreste las
# milicias<00:01:16.320><c> en</c><00:01:16.479><c> Siria</c><00:01:16.920><c> pasarían</c><00:01:17.400><c> a</c><00:01:17.600><c> la</c><00:01:17.799><c> lucha</c>
#
# 00:01:18.429 --> 00:01:18.439
# milicias en Siria pasarían a la lucha
#
# 00:01:18.439 --> 00:01:20.630
# milicias en Siria pasarían a la lucha
# contando<00:01:19.040><c> también</c><00:01:19.360><c> con</c><00:01:19.520><c> el</c><00:01:19.720><c> apoyo</c><00:01:20.000><c> de</c><00:01:20.240><c> Irán</c>
#
# 00:01:20.630 --> 00:01:20.640
# contando también con el apoyo de Irán
#
# 00:01:20.640 --> 00:01:23.310
# contando también con el apoyo de Irán
# ahora<00:01:21.280><c> Israel</c><00:01:21.840><c> se</c><00:01:22.040><c> estaría</c><00:01:22.479><c> enfrentando</c><00:01:23.079><c> a</c>
#
# 00:01:23.310 --> 00:01:23.320
# ahora Israel se estaría enfrentando a
#
# 00:01:23.320 --> 00:01:26.230
# ahora Israel se estaría enfrentando a
# ataques<00:01:23.920><c> desde</c><00:01:24.240><c> múltiples</c><00:01:24.840><c> flancos</c><00:01:25.240><c> a</c><00:01:25.400><c> la</c><00:01:25.560><c> vez</c>
#
# 00:01:26.230 --> 00:01:26.240
# ataques desde múltiples flancos a la vez
#
# 00:01:26.240 --> 00:01:29.950
# ataques desde múltiples flancos a la vez
# paso<00:01:26.520><c> tres</c><00:01:26.960><c> Irán</c><00:01:27.880><c> Israel</c><00:01:28.680><c> intensificar</c><00:01:29.520><c> los</c>
#
# 00:01:29.950 --> 00:01:29.960
# paso tres Irán Israel intensificar los
#
# 00:01:29.960 --> 00:01:32.190
# paso tres Irán Israel intensificar los
# ataques<00:01:30.320><c> contra</c><00:01:30.680><c> objetivos</c><00:01:31.200><c> en</c><00:01:31.439><c> Líbano</c><00:01:31.960><c> y</c>
#
# 00:01:32.190 --> 00:01:32.200
# ataques contra objetivos en Líbano y
#
# 00:01:32.200 --> 00:01:34.830
# ataques contra objetivos en Líbano y
# Siria<00:01:32.799><c> y</c><00:01:33.040><c> llevaría</c><00:01:33.520><c> a</c><00:01:33.680><c> cabo</c><00:01:33.880><c> incursiones</c><00:01:34.520><c> en</c>
#
# 00:01:34.830 --> 00:01:34.840
# Siria y llevaría a cabo incursiones en
#
# 00:01:34.840 --> 00:01:37.389
# Siria y llevaría a cabo incursiones en
# cisjordania<00:01:35.840><c> pero</c><00:01:36.000><c> la</c><00:01:36.280><c> tensión</c><00:01:36.799><c> se</c><00:01:37.000><c> centraría</c>
#
# 00:01:37.389 --> 00:01:37.399
# cisjordania pero la tensión se centraría
#
# 00:01:37.399 --> 00:01:40.469
# cisjordania pero la tensión se centraría
# en<00:01:37.920><c> Irán</c><00:01:38.159><c> como</c><00:01:38.399><c> enemigo</c><00:01:38.880><c> final</c><00:01:39.119><c> de</c><00:01:39.320><c> Israel</c><00:01:40.200><c> el</c>
#
# 00:01:40.469 --> 00:01:40.479
# en Irán como enemigo final de Israel el
#
# 00:01:40.479 --> 00:01:42.990
# en Irán como enemigo final de Israel el
# mayor<00:01:40.799><c> temor</c><00:01:41.479><c> se</c><00:01:41.680><c> cree</c><00:01:41.960><c> que</c><00:01:42.040><c> Irán</c><00:01:42.560><c> está</c><00:01:42.840><c> a</c>
#
# 00:01:42.990 --> 00:01:43.000
# mayor temor se cree que Irán está a
#
# 00:01:43.000 --> 00:01:45.870
# mayor temor se cree que Irán está a
# punto<00:01:43.240><c> de</c><00:01:43.439><c> poseer</c><00:01:43.799><c> un</c><00:01:44.240><c> arma</c><00:01:44.520><c> nuclear</c><00:01:45.320><c> Así</c><00:01:45.640><c> que</c>
#
# 00:01:45.870 --> 00:01:45.880
# punto de poseer un arma nuclear Así que
#
# 00:01:45.880 --> 00:01:47.950
# punto de poseer un arma nuclear Así que
# las<00:01:46.040><c> fuerzas</c><00:01:46.439><c> israelíes</c><00:01:47.320><c> atacarían</c>
#
# 00:01:47.950 --> 00:01:47.960
# las fuerzas israelíes atacarían
#
# 00:01:47.960 --> 00:01:50.350
# las fuerzas israelíes atacarían
# objetivos<00:01:48.479><c> del</c><00:01:48.680><c> programa</c><00:01:49.119><c> nuclear</c><00:01:49.479><c> iraní</c>
#
# 00:01:50.350 --> 00:01:50.360
# objetivos del programa nuclear iraní
#
# 00:01:50.360 --> 00:01:53.109
# objetivos del programa nuclear iraní
# irán<00:01:51.040><c> ordenaría</c><00:01:51.680><c> a</c><00:01:51.799><c> hezbolá</c><00:01:52.479><c> lanzar</c><00:01:52.880><c> una</c>
#
# 00:01:53.109 --> 00:01:53.119
# irán ordenaría a hezbolá lanzar una
#
# 00:01:53.119 --> 00:01:55.550
# irán ordenaría a hezbolá lanzar una
# represalia<00:01:53.560><c> masiva</c><00:01:54.399><c> y</c><00:01:54.640><c> amenazaría</c><00:01:55.200><c> con</c>
#
# 00:01:55.550 --> 00:01:55.560
# represalia masiva y amenazaría con
#
# 00:01:55.560 --> 00:01:57.749
# represalia masiva y amenazaría con
# unirse<00:01:55.960><c> a</c><00:01:56.079><c> la</c><00:01:56.159><c> lucha</c><00:01:56.759><c> Israel</c><00:01:57.360><c> estaría</c>
#
# 00:01:57.749 --> 00:01:57.759
# unirse a la lucha Israel estaría
#
# 00:01:57.759 --> 00:02:00.429
# unirse a la lucha Israel estaría
# entonces<00:01:58.320><c> a</c><00:01:58.439><c> punto</c><00:01:58.680><c> de</c><00:01:58.960><c> verse</c><00:01:59.240><c> desbordado</c><00:02:00.200><c> y</c>
#
# 00:02:00.429 --> 00:02:00.439
# entonces a punto de verse desbordado y
#
# 00:02:00.439 --> 00:02:03.109
# entonces a punto de verse desbordado y
# pediría<00:02:00.880><c> a</c><00:02:01.079><c> Estados</c><00:02:01.439><c> Unidos</c><00:02:01.880><c> que</c><00:02:02.119><c> intervenga</c>
#
# 00:02:03.109 --> 00:02:03.119
# pediría a Estados Unidos que intervenga
#
# 00:02:03.119 --> 00:02:06.270
# pediría a Estados Unidos que intervenga
# paso<00:02:03.439><c> cuatro</c><00:02:04.200><c> las</c><00:02:04.520><c> superpotencias</c><00:02:05.280><c> Cuanto</c>
#
# 00:02:06.270 --> 00:02:06.280
# paso cuatro las superpotencias Cuanto
#
# 00:02:06.280 --> 00:02:08.389
# paso cuatro las superpotencias Cuanto
# más<00:02:06.479><c> avanzamos</c><00:02:06.960><c> en</c><00:02:07.119><c> este</c><00:02:07.360><c> escenario</c><00:02:08.160><c> más</c>
#
# 00:02:08.389 --> 00:02:08.399
# más avanzamos en este escenario más
#
# 00:02:08.399 --> 00:02:10.790
# más avanzamos en este escenario más
# inciertas<00:02:08.959><c> se</c><00:02:09.119><c> vuelven</c><00:02:09.520><c> las</c><00:02:09.640><c> cosas</c><00:02:10.399><c> pero</c><00:02:10.679><c> es</c>
#
# 00:02:10.790 --> 00:02:10.800
# inciertas se vuelven las cosas pero es
#
# 00:02:10.800 --> 00:02:12.990
# inciertas se vuelven las cosas pero es
# fácil<00:02:11.200><c> ver</c><00:02:11.400><c> cómo</c><00:02:11.760><c> las</c><00:02:11.920><c> grandes</c><00:02:12.360><c> potencias</c>
#
# 00:02:12.990 --> 00:02:13.000
# fácil ver cómo las grandes potencias
#
# 00:02:13.000 --> 00:02:15.830
# fácil ver cómo las grandes potencias
# podrían<00:02:13.800><c> involucrarse</c><00:02:14.800><c> Estados</c><00:02:15.239><c> Unidos</c>
#
# 00:02:15.830 --> 00:02:15.840
# podrían involucrarse Estados Unidos
#
# 00:02:15.840 --> 00:02:17.790
# podrían involucrarse Estados Unidos
# intervendría<00:02:16.599><c> activamente</c><00:02:17.040><c> del</c><00:02:17.440><c> lado</c><00:02:17.680><c> de</c>
#
# 00:02:17.790 --> 00:02:17.800
# intervendría activamente del lado de
#
# 00:02:17.800 --> 00:02:20.790
# intervendría activamente del lado de
# Israel<00:02:18.560><c> golpeando</c><00:02:19.040><c> a</c><00:02:19.160><c> hezbolá</c><00:02:19.840><c> e</c><00:02:20.120><c> incluso</c><00:02:20.599><c> al</c>
#
# 00:02:20.790 --> 00:02:20.800
# Israel golpeando a hezbolá e incluso al
#
# 00:02:20.800 --> 00:02:23.509
# Israel golpeando a hezbolá e incluso al
# propio<00:02:21.120><c> irán</c><00:02:21.480><c> con</c><00:02:21.680><c> ataques</c><00:02:22.040><c> aéreos</c><00:02:23.040><c> Rusia</c><00:02:23.360><c> por</c>
#
# 00:02:23.509 --> 00:02:23.519
# propio irán con ataques aéreos Rusia por
#
# 00:02:23.519 --> 00:02:25.830
# propio irán con ataques aéreos Rusia por
# su<00:02:23.840><c> parte</c><00:02:24.319><c> podría</c><00:02:24.800><c> proporcionar</c><00:02:25.560><c> cierto</c>
#
# 00:02:25.830 --> 00:02:25.840
# su parte podría proporcionar cierto
#
# 00:02:25.840 --> 00:02:28.190
# su parte podría proporcionar cierto
# grado<00:02:26.120><c> de</c><00:02:26.239><c> apoyo</c><00:02:26.480><c> a</c><00:02:26.680><c> Irán</c><00:02:27.120><c> Vladimir</c><00:02:27.760><c> Putin</c><00:02:28.080><c> le</c>
#
# 00:02:28.190 --> 00:02:28.200
# grado de apoyo a Irán Vladimir Putin le
#
# 00:02:28.200 --> 00:02:30.110
# grado de apoyo a Irán Vladimir Putin le
# debe<00:02:28.440><c> a</c><00:02:28.599><c> Terán</c><00:02:29.080><c> las</c><00:02:29.200><c> armas</c><00:02:29.519><c> que</c><00:02:29.800><c> que</c><00:02:29.920><c> le</c><00:02:30.000><c> ha</c>
#
# 00:02:30.110 --> 00:02:30.120
# debe a Terán las armas que que le ha
#
# 00:02:30.120 --> 00:02:31.869
# debe a Terán las armas que que le ha
# estado<00:02:30.360><c> suministrando</c><00:02:31.120><c> para</c><00:02:31.280><c> su</c><00:02:31.440><c> guerra</c><00:02:31.720><c> en</c>
#
# 00:02:31.869 --> 00:02:31.879
# estado suministrando para su guerra en
#
# 00:02:31.879 --> 00:02:35.190
# estado suministrando para su guerra en
# Ucrania<00:02:32.440><c> y</c><00:02:32.760><c> China</c><00:02:33.560><c> bueno</c><00:02:34.239><c> China</c><00:02:34.599><c> podría</c><00:02:35.000><c> ser</c>
#
# 00:02:35.190 --> 00:02:35.200
# Ucrania y China bueno China podría ser
#
# 00:02:35.200 --> 00:02:37.990
# Ucrania y China bueno China podría ser
# la<00:02:35.360><c> mayor</c><00:02:35.599><c> incógnita</c><00:02:36.440><c> de</c><00:02:36.560><c> todas</c><00:02:37.319><c> china</c><00:02:37.680><c> es</c><00:02:37.879><c> un</c>
#
# 00:02:37.990 --> 00:02:38.000
# la mayor incógnita de todas china es un
#
# 00:02:38.000 --> 00:02:39.990
# la mayor incógnita de todas china es un
# gran<00:02:38.200><c> importador</c><00:02:38.840><c> de</c><00:02:39.000><c> petróleo</c><00:02:39.480><c> de</c><00:02:39.640><c> oriente</c>
#
# 00:02:39.990 --> 00:02:40.000
# gran importador de petróleo de oriente
#
# 00:02:40.000 --> 00:02:42.430
# gran importador de petróleo de oriente
# medio<00:02:40.760><c> eso</c><00:02:41.080><c> significa</c><00:02:41.480><c> que</c><00:02:41.720><c> le</c><00:02:41.920><c> interesa</c><00:02:42.319><c> que</c>
#
# 00:02:42.430 --> 00:02:42.440
# medio eso significa que le interesa que
#
# 00:02:42.440 --> 00:02:45.030
# medio eso significa que le interesa que
# haya<00:02:42.760><c> cierta</c><00:02:43.200><c> estabilidad</c><00:02:44.200><c> pero</c><00:02:44.440><c> esta</c><00:02:44.720><c> crisis</c>
#
# 00:02:45.030 --> 00:02:45.040
# haya cierta estabilidad pero esta crisis
#
# 00:02:45.040 --> 00:02:46.910
# haya cierta estabilidad pero esta crisis
# también<00:02:45.280><c> podría</c><00:02:45.680><c> ser</c><00:02:45.920><c> una</c><00:02:46.080><c> oportunidad</c><00:02:46.680><c> para</c>
#
# 00:02:46.910 --> 00:02:46.920
# también podría ser una oportunidad para
#
# 00:02:46.920 --> 00:02:49.149
# también podría ser una oportunidad para
# china<00:02:47.239><c> al</c><00:02:47.599><c> servicio</c><00:02:48.040><c> de</c><00:02:48.200><c> un</c><00:02:48.400><c> objetivo</c><00:02:48.959><c> más</c>
#
# 00:02:49.149 --> 00:02:49.159
# china al servicio de un objetivo más
#
# 00:02:49.159 --> 00:02:51.910
# china al servicio de un objetivo más
# elevado<00:02:49.800><c> shi</c><00:02:50.319><c> jinping</c><00:02:50.879><c> ha</c><00:02:51.040><c> Jurado</c><00:02:51.400><c> Que</c><00:02:51.640><c> china</c>
#
# 00:02:51.910 --> 00:02:51.920
# elevado shi jinping ha Jurado Que china
#
# 00:02:51.920 --> 00:02:54.229
# elevado shi jinping ha Jurado Que china
# tomará<00:02:52.280><c> el</c><00:02:52.519><c> control</c><00:02:52.640><c> de</c><00:02:52.800><c> Taiwán</c><00:02:53.480><c> esta</c><00:02:53.920><c> podría</c>
#
# 00:02:54.229 --> 00:02:54.239
# tomará el control de Taiwán esta podría
#
# 00:02:54.239 --> 00:02:55.830
# tomará el control de Taiwán esta podría
# convertirse<00:02:54.879><c> en</c><00:02:55.040><c> su</c><00:02:55.200><c> primera</c><00:02:55.599><c> gran</c>
#
# 00:02:55.830 --> 00:02:55.840
# convertirse en su primera gran
#
# 00:02:55.840 --> 00:02:59.149
# convertirse en su primera gran
# oportunidad<00:02:56.840><c> por</c><00:02:57.120><c> qué</c><00:02:57.480><c> esta</c><00:02:58.159><c> es</c><00:02:58.280><c> la</c><00:02:58.360><c> hipótesis</c>
#
# 00:02:59.149 --> 00:02:59.159
# oportunidad por qué esta es la hipótesis
#
# 00:02:59.159 --> 00:03:01.390
# oportunidad por qué esta es la hipótesis
# el<00:02:59.400><c> año</c><00:02:59.760><c> ao</c><00:02:59.959><c> que</c><00:03:00.080><c> viene</c><00:03:00.360><c> si</c><00:03:00.599><c> Estados</c><00:03:00.959><c> Unidos</c><00:03:01.280><c> Se</c>
#
# 00:03:01.390 --> 00:03:01.400
# el año ao que viene si Estados Unidos Se
#
# 00:03:01.400 --> 00:03:03.990
# el año ao que viene si Estados Unidos Se
# involucra<00:03:02.080><c> estaría</c><00:03:02.640><c> muy</c><00:03:02.840><c> ocupado</c><00:03:03.440><c> ayudando</c><00:03:03.840><c> a</c>
#
# 00:03:03.990 --> 00:03:04.000
# involucra estaría muy ocupado ayudando a
#
# 00:03:04.000 --> 00:03:06.550
# involucra estaría muy ocupado ayudando a
# Israel<00:03:04.560><c> contra</c><00:03:04.840><c> Irán</c><00:03:05.440><c> además</c><00:03:05.760><c> de</c><00:03:06.080><c> Ucrania</c>
#
# 00:03:06.550 --> 00:03:06.560
# Israel contra Irán además de Ucrania
#
# 00:03:06.560 --> 00:03:09.630
# Israel contra Irán además de Ucrania
# contra<00:03:06.840><c> Rusia</c><00:03:07.400><c> y</c><00:03:07.760><c> recordemos</c><00:03:08.280><c> que</c><00:03:08.360><c> en</c><00:03:08.640><c> 2024</c>
#
# 00:03:09.630 --> 00:03:09.640
# contra Rusia y recordemos que en 2024
#
# 00:03:09.640 --> 00:03:11.390
# contra Rusia y recordemos que en 2024
# también<00:03:10.040><c> celebrará</c><00:03:10.680><c> elecciones</c>
#
# 00:03:11.390 --> 00:03:11.400
# también celebrará elecciones
#
# 00:03:11.400 --> 00:03:13.670
# también celebrará elecciones
# presidenciales<00:03:12.400><c> estaría</c><00:03:12.879><c> en</c><00:03:13.000><c> condiciones</c><00:03:13.480><c> de</c>
#
# 00:03:13.670 --> 00:03:13.680
# presidenciales estaría en condiciones de
#
# 00:03:13.680 --> 00:03:16.430
# presidenciales estaría en condiciones de
# defender<00:03:14.040><c> a</c><00:03:14.200><c> Taiwán</c><00:03:14.840><c> para</c><00:03:15.599><c> shi</c><00:03:15.959><c> podría</c><00:03:16.280><c> ser</c>
#
# 00:03:16.430 --> 00:03:16.440
# defender a Taiwán para shi podría ser
#
# 00:03:16.440 --> 00:03:18.990
# defender a Taiwán para shi podría ser
# una<00:03:16.599><c> oportunidad</c><00:03:17.400><c> Irresistible</c><00:03:18.400><c> una</c><00:03:18.720><c> opción</c>
#
# 00:03:18.990 --> 00:03:19.000
# una oportunidad Irresistible una opción
#
# 00:03:19.000 --> 00:03:21.509
# una oportunidad Irresistible una opción
# sería<00:03:19.400><c> imponer</c><00:03:19.760><c> un</c><00:03:19.879><c> bloqueo</c><00:03:20.200><c> a</c><00:03:20.280><c> Taiwán</c><00:03:20.879><c> biden</c>
#
# 00:03:21.509 --> 00:03:21.519
# sería imponer un bloqueo a Taiwán biden
#
# 00:03:21.519 --> 00:03:23.470
# sería imponer un bloqueo a Taiwán biden
# tendría<00:03:21.879><c> que</c><00:03:22.000><c> elegir</c><00:03:22.319><c> entre</c><00:03:22.799><c> meterse</c><00:03:23.120><c> en</c><00:03:23.239><c> otro</c>
#
# 00:03:23.470 --> 00:03:23.480
# tendría que elegir entre meterse en otro
#
# 00:03:23.480 --> 00:03:25.589
# tendría que elegir entre meterse en otro
# conflicto<00:03:24.120><c> y</c><00:03:24.280><c> arriesgarse</c><00:03:25.000><c> a</c><00:03:25.120><c> una</c><00:03:25.280><c> guerra</c>
#
# 00:03:25.589 --> 00:03:25.599
# conflicto y arriesgarse a una guerra
#
# 00:03:25.599 --> 00:03:27.910
# conflicto y arriesgarse a una guerra
# mundial<00:03:26.200><c> o</c><00:03:26.400><c> dejar</c><00:03:26.640><c> a</c><00:03:26.799><c> Taiwán</c><00:03:27.239><c> expuesto</c>
#
# 00:03:27.910 --> 00:03:27.920
# mundial o dejar a Taiwán expuesto
#
# 00:03:27.920 --> 00:03:30.110
# mundial o dejar a Taiwán expuesto
# admitiendo<00:03:28.360><c> que</c><00:03:28.599><c> Estados</c><00:03:28.920><c> Unidos</c><00:03:29.200><c> ha</c><00:03:29.799><c> llegado</c>
#
# 00:03:30.110 --> 00:03:30.120
# admitiendo que Estados Unidos ha llegado
#
# 00:03:30.120 --> 00:03:32.949
# admitiendo que Estados Unidos ha llegado
# al<00:03:30.319><c> límite</c><00:03:30.760><c> de</c><00:03:30.840><c> sus</c><00:03:31.080><c> poderes</c><00:03:31.920><c> sería</c><00:03:32.439><c> una</c><00:03:32.680><c> gran</c>
#
# 00:03:32.949 --> 00:03:32.959
# al límite de sus poderes sería una gran
#
# 00:03:32.959 --> 00:03:36.190
# al límite de sus poderes sería una gran
# decisión<00:03:33.959><c> pero</c><00:03:34.239><c> volvamos</c><00:03:34.720><c> al</c><00:03:34.920><c> presente</c><00:03:35.799><c> nada</c>
#
# 00:03:36.190 --> 00:03:36.200
# decisión pero volvamos al presente nada
#
# 00:03:36.200 --> 00:03:38.869
# decisión pero volvamos al presente nada
# de<00:03:36.360><c> esto</c><00:03:36.760><c> está</c><00:03:37.080><c> predestinado</c><00:03:37.879><c> a</c><00:03:37.959><c> suceder</c><00:03:38.640><c> pero</c>
#
# 00:03:38.869 --> 00:03:38.879
# de esto está predestinado a suceder pero
#
# 00:03:38.879 --> 00:03:40.869
# de esto está predestinado a suceder pero
# es<00:03:39.040><c> fácil</c><00:03:39.439><c> entender</c><00:03:39.879><c> Por</c><00:03:40.000><c> qué</c><00:03:40.159><c> los</c><00:03:40.360><c> líderes</c>
#
# 00:03:40.869 --> 00:03:40.879
# es fácil entender Por qué los líderes
#
# 00:03:40.879 --> 00:03:42.910
# es fácil entender Por qué los líderes
# están<00:03:41.200><c> desesperados</c><00:03:41.840><c> por</c><00:03:42.000><c> detener</c><00:03:42.640><c> esta</c>
#
# 00:03:42.910 --> 00:03:42.920
# están desesperados por detener esta
#
# 00:03:42.920 --> 00:03:45.270
# están desesperados por detener esta
# cadena<00:03:43.280><c> de</c><00:03:43.519><c> acontecimientos</c><00:03:44.519><c> las</c><00:03:44.760><c> próximas</c>
#
# 00:03:45.270 --> 00:03:45.280
# cadena de acontecimientos las próximas
#
# 00:03:45.280 --> 00:03:50.670
# cadena de acontecimientos las próximas
# semanas<00:03:45.959><c> son</c><00:03:46.239><c> realmente</c>

# %% [markdown]
# ## Data cleaning
#
# Subtitle input file needs to be transform to a clean body of text. For this:
# + Time marks needs to be removed.
# + Values seems to be triplicated.

# %%
# Path to your .vtt file
vtt_file = '/Users/nico/Desktop/Projects/Youtube-project/data/en_DW/‘Beyond worst case scenario’ The situation on the ground in Gaza  DW News.en.vtt'

# Open and extract text from the .vtt file, remove duplicates
text_output = []
seen_lines = set()  # Set to keep track of unique lines
for caption in webvtt.read(vtt_file):
    for line in caption.text.splitlines():
        if line not in seen_lines:  # Check for duplicates
            text_output.append(line)
            seen_lines.add(line)

# Join the unique extracted text into a single string variable
text = ' '.join(text_output)
text
# Out:
# "right turning now to Israel's war on Hamas Israel says its Army carried out a large ground incursion in the Gaza Strip overnight to attack Hamas positions the military described it as its biggest incursion into Gaza yet the United Nations humanitarian coordinator for the Palestinian territories has warned that nowhere in Gaza is safe as Israel steps up its preparations for an expected ground Invasion Israeli tanks and Northern Gaza setting the stage for Israel's next phase of combat a full ground war has not started yet but air strikes are hitting the Gaza Strip nonstop theyve already reduced entire neighborhoods to Rubble because of the bombing destruction and killing I came to seek shelter inside this camp with nine members of my family in two cars I had to sleep out in the open in the heat for 10 days to get a tent Israel says it is striking targets of the islamist militant group Hamas considered a terrorist organization by many Western governments according to the UN about 1.4 million gazin are now displaced the organization now says nowhere is safe in the entire Gaza Strip residents there who have no way out of the strip are calling for an end to the hostilities we don't want war we want it to stop we're so tired we're overwhelmed we stand in Long cues just to use the toilets we don't even have basic rights we are more like lifeless bodies a Complete Siege imposed by Israel after the Hamas terror attack has caused a critical shortage of supplies and air strikes are impeding eight deliveries uh we've been asked if we've been able to deliver to the Turkish Hospital which is uh perhaps the biggest provider of cancer services in in Gaza the answer is no um the answer is no because we do not have security guarantees to deliver that Aid International diplomacy efforts for a ceasefire have so far failed a ground war to topple mass now may worsen an already dire situation in Gaza well earlier I talked to DW correspondent tany kma in Jerusalem she tell me more about the Israeli incursion into Gaza overnight while the Israeli military confirmed only that uh what they described as a targeted raid into Gaza they also released uh this video where you can see tanks and the Infantry basically moving in they say they targeted that Hamas infrastructure there also Hamas militants and the Army Radio described it as the largest incursion yet as to date so they also said that this is done in preparation for the next stages of combat possibly referring to a even larger uh ground uh incursion that uh everybody in Israel at least is waiting for all of this happens of course with also massive air bombardment uh Israeli air bombardment on uh the Gaza Strip and north and south and we heard again also uh that Palestinians still in the north of Gaza where also is the Gaza City uh were called on leaving and that prompted also a statement by the UN un's humanitarian coordinator this Hastings saying that Palestinians they face an impossible situation because some had opted to stay they don't have the means or they don't want to leave so it's a very very difficult situation for the civilian population there tell you with heard Israel's primee Minister there explaining that preparations are still underway for a ground operation as they have been for days did he shed uh any new light as to what we can expect of that operation well I think he needed to address the Israeli public there are a lot of questions being asked where this is going in Israel uh people are looking uh what's happening in Gaza obviously but also what is happening in noris on the northern border with Hezbollah as well and uh he didn't say much new he said that the ground offensive will happen soon but he didn't give any details he also said that uh a priority is still also to get the hostages the Israeli hostages and other foreign Nationals that are being held in Gaza now at the number of 224 only four were were released so far that are being held in Gaza to get them out he also briefly ...

# %% [markdown]
# ## Tokenize the text
#
# I will just use a pre-trainned ML model for better tokenization than rule based tokenizer.

# %% [markdown]
# ### Setup for tokenization
#
# The setup is environment dependant (i.e. your operative system or hardware). To set it up, use https://spacy.io/usage

# %%
# Setup [It will take some time to run the installation!]
# !pip install -U pip setuptools wheel
# !pip install -U 'spacy[apple]'
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_trf

# %% [markdown]
# ### Tokenizing

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_trf") # small model
# Out:
# /Users/nico/miniconda3/envs/dw_words/lib/python3.12/site-packages/thinc/shims/pytorch.py:253: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filelike, map_location=device))

# %%
# %%time
doc = nlp(text)
# Out:
# /Users/nico/miniconda3/envs/dw_words/lib/python3.12/site-packages/thinc/shims/pytorch.py:114: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self._mixed_precision):
# CPU times: user 3.53 s, sys: 1.34 s, total: 4.87 s
# Wall time: 913 ms

# %%
for token in doc[:10]:
    print (token)
# Out:
# right
# turning
# now
# to
# Israel
# 's
# war
# on
# Hamas
# Israel

# %% [markdown]
# #### Token exploratory data analysis
#
# > There are several atributes, for more detail https://spacy.io/api/token#attributes
#
# After running the previous loop, the variable `token` have contained the last element of the loop, in this case "Israel"

# %%
token.text
# Out:
# 'Israel'

# %%
token.left_edge
# Out:
# Israel

# %%
token.right_edge
# Out:
# Israel

# %% [markdown]
# Not having other words at the left and right edges indicate that the word is an entity by itself.

# %%
token.ent_type_
# Out:
# 'GPE'

# %% [markdown]
# 'GPE' indicate Geo-Politycal Entity

# %%
doc[8].ent_type_
# Out:
# 'ORG'

# %% [markdown]
# 'Hamas' (`doc[8]`) was classified as an Organization

# %%
doc[1].lemma_ # Index number 8 of the current doc is 'turning', lemma return the infinitive form of the word
# Out:
# 'turn'

# %%
token.morph # Morphological analysis.
# Out:
# Number=Sing

# %%
doc[1].morph # Morphological analysis of 'turning'
# Out:
# Aspect=Prog|Tense=Pres|VerbForm=Part

# %%
token.pos_ # stands for part of speech
# Out:
# 'PROPN'

# %% [markdown]
# ### Speech tagging

# %%
for token in doc[:20]:
     print(token.text, token.pos_, token.dep_)
# Out:
# right ADV advmod
# turning VERB advcl
# now ADV advmod
# to ADP prep
# Israel PROPN poss
# 's PART case
# war NOUN pobj
# on ADP prep
# Hamas PROPN pobj
# Israel PROPN nsubj
# says VERB ccomp
# its PRON poss
# Army PROPN nsubj
# carried VERB ccomp
# out ADP prt
# a DET det
# large ADJ amod
# ground NOUN compound
# incursion NOUN dobj
# in ADP prep

# %%
from spacy import displacy
displacy.render(doc[:20], style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="acd282627bee4f46803b823e098f094a-0" class="displacy" width="3550" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">right</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">turning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">now</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Israel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">war</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Hamas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Israel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">says</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Army</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">carried</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">out</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">large</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">ground</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">incursion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-acd282627bee4f46803b823e098f094a-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-acd282627bee4f46803b823e098f094a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-acd282627bee4f46803b823e098f094a-0-1" stroke-width="2px" d="M245,352.0 C245,2.0 1800.0,2.0 1800.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-acd282627bee4f46803b823e098f094a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-acd282627bee4f46803b823e098f094a-0-2" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-acd282627bee4f46803b823e098f094a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,354.0 L393.0,342.0 377.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-acd282627bee4f46803b823e098f094a-0-3" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-acd282627bee4f46803b823e098f094a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,354.0 L573.0,342.0 557.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-acd282627bee4f46803b823e098f094a-0-4" stroke-width="2px" d="M770,352.0 C770,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-acd282627bee4f46803b823e098f094a-0-4" class="displacy-label" startOffs

# %% [markdown]
# Did the models delimitated clearly the different sentences? (the text have no puntuation)

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">right turning now to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's war on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hamas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  says its
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Army
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  carried out a large ground incursion in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Gaza Strip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     overnight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  to attack
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hamas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  positions the military described it as its biggest incursion into
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  yet the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     United Nations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  humanitarian coordinator for the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Palestinian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  territories has warned that nowhere in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is safe as
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  steps up its preparations for an expected ground Invasion
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israeli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  tanks and
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Northern Gaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  setting the stage for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's next phase of combat a full ground war has not started yet but air strikes are hitting
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Gaza Strip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  nonstop theyve already reduced entire neighborhoods to Rubble because of the bombing destruction and killing I came to seek shelter inside this camp with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  members of my family in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cars I had to sleep out in the open in the heat for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to get a tent
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Israel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  says it is striking targets of the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     islamist
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  militant group
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hamas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  considered a terrorist organization by many
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Western
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  governments according to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UN
#     <spa

# %% [markdown]
# ### Word Vectors (or word embeddings)
#
# Are numerical representations of words. Is a good way to say to a computer how close can different words be. Also give context about the meaning inside a sentence for example. Mean sintactical and semantical meaning (ask Lorenz to explain this)

# %%
# !python -m spacy download en_core_web_md

# %%
nlp = spacy.load('en_core_web_md')

# %%
# %%time
# tokenize again with the medium model
doc = nlp(text)
# Out:
# CPU times: user 122 ms, sys: 47.8 ms, total: 170 ms
# Wall time: 270 ms

# %%
sentence1 = list(doc.sents)[0]
sentence1 # is not really parsed by sentences
# Out:
# right turning now to Israel's war on Hamas Israel says its Army carried out a large ground incursion in the Gaza Strip overnight to attack Hamas positions the military described it as its biggest incursion into Gaza yet the United Nations humanitarian coordinator for the Palestinian territories has warned that nowhere in Gaza is safe as Israel steps up its preparations for an expected ground Invasion Israeli tanks and Northern Gaza setting the stage for Israel's next phase of combat a full ground war has not started yet but air strikes are hitting the Gaza Strip nonstop theyve already reduced entire neighborhoods to Rubble because of the bombing destruction and killing I came to seek shelter inside this camp with nine members of my family in two cars I had to sleep out in the open in the heat for 10 days to get a tent Israel says it is striking targets of the islamist militant group Hamas considered a terrorist organization by many Western governments according to the UN about 1.4 million gazin are now displaced the organization now says nowhere is safe in the entire Gaza Strip residents there who have no way out of the strip are calling for an end to the hostilities we don't want war we want it to stop we're so tired we're overwhelmed we stand in Long cues just to use the toilets we don't even have basic rights we are more like lifeless bodies a Complete Siege imposed by Israel after the Hamas terror attack has caused a critical shortage of supplies and air strikes are impeding eight deliveries uh we've been asked if we've been able to deliver to the Turkish Hospital which is uh perhaps the biggest provider of cancer services in in Gaza the answer is no um the answer is no because we do not have security guarantees to deliver that Aid International diplomacy efforts for a ceasefire have so far failed a ground war to topple mass now may worsen an already dire situation in Gaza well earlier I talked to DW correspondent tany kma in Jerusalem she tell me more about the Israeli incursion into Gaza overnight while the Israeli military confirmed only that uh what they described as a targeted raid into Gaza they also released uh this video where you can see tanks and the Infantry basically moving in they say they targeted that Hamas infrastructure there also Hamas militants and the Army Radio described it as the largest incursion yet as to date so they also said that this is done in preparation for the next stages of combat possibly referring to a even larger uh ground uh incursion that uh everybody in Israel at least is waiting for all of this happens of course with also massive air bombardment uh Israeli air bombardment on uh the Gaza Strip and north and south and we heard again also uh that Palestinians still in the north of Gaza where also is the Gaza City uh were called on leaving and that prompted also a statement by the UN un's humanitarian coordinator this Hastings saying that Palestinians they face an impossible situation because some had opted to stay they don't have the means or they don't want to leave so it's a very very difficult situation for the civilian population there tell you with heard Israel's primee Minister there explaining that preparations are still underway for a ground operation as they have been for days did he shed uh any new light as to what we can expect of that operation

# %% [markdown]
# #### We can look for the closest words to a defined word

# %%
import numpy as np

your_word = "war"

ms = nlp.vocab.vectors.most_similar(
    np.array([nlp.vocab.vectors[nlp.vocab.strings[your_word]]]), n=10)
words = [nlp.vocab.strings[w] for w in ms[0][0]]
distances = ms[2]
words
# Out:
# ['war-',
#  'dewars',
#  'battlecry',
#  'conflictual',
#  'War-',
#  'Zelyony',
#  'Bioinvasions',
#  'battlefronts',
#  'hellion',
#  'militares']

# %% [markdown]
# #### We can compare how close are 2 documents

# %% [markdown]
# ##### Load several text files

# %%
# Open and extract text from the .vtt file, remove duplicates
def clean_subtitles(vtt_file):
    text_output = []
    seen_lines = set()  # Set to keep track of unique lines
    for caption in webvtt.read(vtt_file):
        for line in caption.text.splitlines():
            if line not in seen_lines:  # Check for duplicates
                text_output.append(line)
                seen_lines.add(line)

    # Join the unique extracted text into a single string variable
    text = ' '.join(text_output)
    return(text)

# %%
# list all subtitle files in a folder

# function to scan files
from pathlib import Path

def get_files_with_extension(folder_location, file_extension):
    # Ensure the file extension starts with a dot
    if not file_extension.startswith('.'):
        file_extension = '.' + file_extension
    
    # Use pathlib to get all files with the specified extension
    files = list(Path(folder_location).rglob(f'*{file_extension}'))
    
    return [str(file) for file in files]

# %%
# Path to your .vtt file
dataset_location = '/Users/nico/Desktop/Projects/Youtube-project/data/en_DW'
file_extension = "vtt" # for subtitles
files_list = get_files_with_extension(dataset_location, file_extension)
files_list

# %%
# Loading, cleaning and tokenizing in one step
text1 = clean_subtitles(files_list[0])
text2 = clean_subtitles(files_list[1])
text3 = clean_subtitles(files_list[2])

doc1 = nlp(text1)
doc2 = nlp(text2)
doc3 = nlp(text3)

# %% [markdown]
# #### Compare files

# %%
doc1.similarity(doc2)
# Out:
# /var/folders/ys/jgrvmqk94xn1pzwrg0gn_6r80000gn/T/ipykernel_80248/2159000743.py:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   doc1.similarity(doc2)
# 0.9780748129347001

# %% [markdown]
# It seems like when comparing 2 whole documents, it classifies as 100% similar. It can be related by the long lenght of them and the similar topic.

# %%
list(doc.sents)[0].similarity(list(doc.sents)[2])
# Out:
# 0.9768521785736084

# %% [markdown]
# When comparing sentences it compares them as similar, but not the same

# %% [markdown]
# ### Sentiment analysis (`TextBlop`)

# %% [markdown]
# When analysing sentiments with `TextBlop`, the sentiment property returns a namedtuple of the form Sentiment(polarity, subjectivity). The polarity score is a float within the range [-1.0, 1.0]. The subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.

# %%
# !pip install textblob

# %%
import spacy
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer

nlp = spacy.load("en_core_web_sm")

def preprocess_text(text):

    # Tokenize the text using Spacy
    doc = nlp(text)

    # Remove stop words
    filtered_tokens = [token.lemma_ for token in doc if not token.is_stop and token.text.isalpha()]

    # Join the tokens back into a string
    preprocessed_text = " ".join(filtered_tokens)
    return preprocessed_text

# Cleaning up  the text
preprocessed_text = preprocess_text(doc3)

# Create an instance of TextBlob with the cleaned text
blob = TextBlob(preprocessed_text)

# Getting the polarity of text which is between -1 (negative) and 1 (positive)
polarity = blob.sentiment.polarity

if polarity > 0.3:
    print("Positive")
elif polarity < -0.3:
    print("Negative")
else:
    print("Neutral")                        #
# Out:
# Neutral

# %% [markdown]
# When using `TextBlop`, it seems to clasify everything as neutral. Is that something related with journalistic editorial?

# %% [markdown]
# #### VADER sentiment scoring
#
# We will use NLTK's `SentimentIntensityAnalyzer` to get the neg/neu/pos scores of the text.
#
# This uses a "bag of words" approach:
# 1. Stop words are removed
# 2. each word is scored and combined to a total score.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/nico/miniconda3/envs/dw_words/lib/python3.12/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/nico/miniconda3/envs/dw_words/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/nico/miniconda3/envs/dw_words/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/nico/miniconda3/envs/dw_words/lib/python3.12/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /Users/nico/miniconda3/envs/dw_words/lib/python3.12/site-packages (from nltk) (4.66.4)

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/nico/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sia.polarity_scores(text) # it uses the raw text as input, not tokenized
# Out:
# {'neg': 0.102, 'neu': 0.838, 'pos': 0.06, 'compound': -0.9989}

# %%
sia.polarity_scores(text1) # it uses the raw text as input, not tokenized
# Out:
# {'neg': 0.074, 'neu': 0.867, 'pos': 0.058, 'compound': -0.9588}

# %%
sia.polarity_scores(text2) # it uses the raw text as input, not tokenized
# Out:
# {'neg': 0.119, 'neu': 0.811, 'pos': 0.069, 'compound': -0.9984}

# %%
sia.polarity_scores(text3) # it uses the raw text as input, not tokenized
# Out:
# {'neg': 0.102, 'neu': 0.866, 'pos': 0.032, 'compound': -0.9665}

# %% [markdown]
# > dominates "neu" with different levels of 'neg', 'pos' and 'compound'. As neutral as Switzerland

# %% [markdown]
# #### Roberta Pretrained Model¶
# + Use a model trained of a large corpus of data.
# + Transformer model accounts for the words but also the context related to other words.

# %%
# !pip install transformers
# !pip install scipy

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
# huggingface provide several pre-trainned models for classifications
MODEL = f"cardiffnlp/xlm-roberta-base-tweet-sentiment-en"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
text
# Out:
# "right turning now to Israel's war on Hamas Israel says its Army carried out a large ground incursion in the Gaza Strip overnight to attack Hamas positions the military described it as its biggest incursion into Gaza yet the United Nations humanitarian coordinator for the Palestinian territories has warned that nowhere in Gaza is safe as Israel steps up its preparations for an expected ground Invasion Israeli tanks and Northern Gaza setting the stage for Israel's next phase of combat a full ground war has not started yet but air strikes are hitting the Gaza Strip nonstop theyve already reduced entire neighborhoods to Rubble because of the bombing destruction and killing I came to seek shelter inside this camp with nine members of my family in two cars I had to sleep out in the open in the heat for 10 days to get a tent Israel says it is striking targets of the islamist militant group Hamas considered a terrorist organization by many Western governments according to the UN about 1.4 million gazin are now displaced the organization now says nowhere is safe in the entire Gaza Strip residents there who have no way out of the strip are calling for an end to the hostilities we don't want war we want it to stop we're so tired we're overwhelmed we stand in Long cues just to use the toilets we don't even have basic rights we are more like lifeless bodies a Complete Siege imposed by Israel after the Hamas terror attack has caused a critical shortage of supplies and air strikes are impeding eight deliveries uh we've been asked if we've been able to deliver to the Turkish Hospital which is uh perhaps the biggest provider of cancer services in in Gaza the answer is no um the answer is no because we do not have security guarantees to deliver that Aid International diplomacy efforts for a ceasefire have so far failed a ground war to topple mass now may worsen an already dire situation in Gaza well earlier I talked to DW correspondent tany kma in Jerusalem she tell me more about the Israeli incursion into Gaza overnight while the Israeli military confirmed only that uh what they described as a targeted raid into Gaza they also released uh this video where you can see tanks and the Infantry basically moving in they say they targeted that Hamas infrastructure there also Hamas militants and the Army Radio described it as the largest incursion yet as to date so they also said that this is done in preparation for the next stages of combat possibly referring to a even larger uh ground uh incursion that uh everybody in Israel at least is waiting for all of this happens of course with also massive air bombardment uh Israeli air bombardment on uh the Gaza Strip and north and south and we heard again also uh that Palestinians still in the north of Gaza where also is the Gaza City uh were called on leaving and that prompted also a statement by the UN un's humanitarian coordinator this Hastings saying that Palestinians they face an impossible situation because some had opted to stay they don't have the means or they don't want to leave so it's a very very difficult situation for the civilian population there tell you with heard Israel's primee Minister there explaining that preparations are still underway for a ground operation as they have been for days did he shed uh any new light as to what we can expect of that operation well I think he needed to address the Israeli public there are a lot of questions being asked where this is going in Israel uh people are looking uh what's happening in Gaza obviously but also what is happening in noris on the northern border with Hezbollah as well and uh he didn't say much new he said that the ground offensive will happen soon but he didn't give any details he also said that uh a priority is still also to get the hostages the Israeli hostages and other foreign Nationals that are being held in Gaza now at the number of 224 only four were were released so far that are being held in Gaza to get them out he also briefly ...

# %%
sia.polarity_scores(text1[:2394])
# Out:
# {'neg': 0.094, 'neu': 0.841, 'pos': 0.065, 'compound': -0.876}

# %%
# Run for Roberta Model
encoded_text = tokenizer(text1[:2285], return_tensors='pt') # the size of the tensors work a little strange for this model, are not tokens or characters, its something else
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
scores_dict
# Out:
# {'roberta_neg': 0.9649233,
#  'roberta_neu': 0.030621981,
#  'roberta_pos': 0.004454721}

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict
