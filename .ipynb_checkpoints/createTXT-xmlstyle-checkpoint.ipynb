# %% [markdown]
# Sentiment analysis
#
# In this Notebook the existing vtt files will be converted to txt files.

# %%
import os
import webvtt
import csv

# Increase the CSV field size limit to handle larger fields
csv.field_size_limit(10000000)  # Adjust the limit as needed

def list_vtt_files(directory):
    # Recursively find all .vtt files in the directory and subdirectories
    vtt_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.vtt'):
                vtt_files.append(os.path.join(root, file))  # Store full path of each .vtt file
    return vtt_files

def read_metadata(csv_file):
    metadata = {}
    # Read metadata from the CSV file and store it in a dictionary
    with open(csv_file, mode='r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            # Extract the base name from the thumbnail_path column
            thumbnail_path = row['thumbnail_path'].strip()
            base_name = os.path.splitext(os.path.basename(thumbnail_path))[0].strip().lower()
            # Remove 'transcript' column from the metadata
            metadata[base_name] = {key: value for key, value in row.items() if key != 'transcript'}
    return metadata

def format_metadata(metadata_row):
    # Format the metadata row into XML-like tags
    metadata_str = ""
    for key, value in metadata_row.items():
        metadata_str += f"<{key}>{value}</{key}>\n"
    return metadata_str

def normalize_filename(filename):
    # Remove any language suffixes and normalize the filename
    base_name = os.path.splitext(os.path.basename(filename))[0]
    # Remove common language suffixes (.de, .en, .es, etc.)
    base_name = base_name.split('.')[0].strip().lower()
    return base_name

def add_metadata(file, metadata):
    # Get the base filename (without path or extension) to match with 'thumbnail_path'
    base_name = normalize_filename(file)
    
    # Debug print
    print(f"Processing file: {file}")
    print(f"Base name for metadata lookup: {base_name}")

    # Check if metadata is available for this file
    if base_name in metadata:
        print(f"Metadata found for: {base_name}")  # Debug print
        metadata_info = format_metadata(metadata[base_name])
        return f"{metadata_info}"  # Enclose video_id tag and metadata
    else:
        print(f"No metadata found for: {base_name}")  # Debug print
    return ""  # Return an empty string if no metadata is found

def extract_txt(file, metadata):
    # Open and extract text from the .vtt file, remove duplicates
    text_output = []
    seen_lines = set()

    for caption in webvtt.read(file):
        for line in caption.text.splitlines():
            if line not in seen_lines:
                text_output.append(line)
                seen_lines.add(line)

    text = ' '.join(text_output)

    # Normalize the filename to use for the output file
    normalized_filename = normalize_filename(file)

    # Create the corresponding .txt filename in the same folder as the .vtt file
    output_directory = os.path.dirname(file)  # Get the directory of the .vtt file
    txt_filename = os.path.join(output_directory, f"{normalized_filename}.txt")  # Use normalized filename for the .txt output

    # Add metadata to the text
    metadata_info = add_metadata(file, metadata)

    # Write the metadata and the extracted text to a .txt file with specific tags
    with open(txt_filename, 'w', encoding='utf-8') as f:
        f.write(metadata_info)  # Write metadata with <video_id> and other tags
        f.write(f"\n<doc>\n{text}\n</doc>")  # Enclose the extracted text in <doc> tags

    print(f"Extracted text saved to: {txt_filename}")

# Example usage
directory_path = 'data/'  # Root directory containing subfolders with .vtt files
vtt_files = list_vtt_files(directory_path)

# Load metadata from the CSV files in the data/ folder
metadata_files = [f for f in os.listdir('data') if f.endswith('.csv')]
for metadata_file in metadata_files:
    csv_file = os.path.join('data', metadata_file)
    metadata = read_metadata(csv_file)  # Load the metadata from the data/ folder

    # Process each .vtt file
    for vtt_file in vtt_files:
        # Ensure that the CSV file corresponds to the folder name
        subfolder = os.path.basename(os.path.dirname(vtt_file))
        if metadata_file.startswith(f'{subfolder}.'):
            extract_txt(vtt_file, metadata)  # Extract text and save with metadata
        else:
            print(f"No matching metadata CSV for: {subfolder}")
# Out:
# Processing file: data/de_DW\54 Objekte in sieben deutschen Bundesländern durchsucht  DW Nachrichten.de.vtt
# Base name for metadata lookup: 54 objekte in sieben deutschen bundesländern durchsucht  dw nachrichten
# Metadata found for: 54 objekte in sieben deutschen bundesländern durchsucht  dw nachrichten
# Extracted text saved to: 54 objekte in sieben deutschen bundesländern durchsucht  dw nachrichten.txt
# Processing file: data/de_DW\Angespannte Proteste um den Gaza-Krieg an US-Unis  DW Nachrichten.de.vtt
# Base name for metadata lookup: angespannte proteste um den gaza-krieg an us-unis  dw nachrichten
# Metadata found for: angespannte proteste um den gaza-krieg an us-unis  dw nachrichten
# Extracted text saved to: angespannte proteste um den gaza-krieg an us-unis  dw nachrichten.txt
# Processing file: data/de_DW\Angriff auf dem Golan - Sorge vor einem größeren Krieg  DW Nachrichten.de.vtt
# Base name for metadata lookup: angriff auf dem golan - sorge vor einem größeren krieg  dw nachrichten
# Metadata found for: angriff auf dem golan - sorge vor einem größeren krieg  dw nachrichten
# Extracted text saved to: angriff auf dem golan - sorge vor einem größeren krieg  dw nachrichten.txt
# Processing file: data/de_DW\Angriff auf Israel Steckt der Iran dahinter  DW Nachrichten.de.vtt
# Base name for metadata lookup: angriff auf israel steckt der iran dahinter  dw nachrichten
# Metadata found for: angriff auf israel steckt der iran dahinter  dw nachrichten
# Extracted text saved to: angriff auf israel steckt der iran dahinter  dw nachrichten.txt
# Processing file: data/de_DW\Antisemitische Ausschreitungen in Dagestan  DW Nachrichten.de.vtt
# Base name for metadata lookup: antisemitische ausschreitungen in dagestan  dw nachrichten
# Metadata found for: antisemitische ausschreitungen in dagestan  dw nachrichten
# Extracted text saved to: antisemitische ausschreitungen in dagestan  dw nachrichten.txt
# Processing file: data/de_DW\Antisemitismus Das Schweigen der Kulturszene  DW Nachrichten.de.vtt
# Base name for metadata lookup: antisemitismus das schweigen der kulturszene  dw nachrichten
# Metadata found for: antisemitismus das schweigen der kulturszene  dw nachrichten
# Extracted text saved to: antisemitismus das schweigen der kulturszene  dw nachrichten.txt
# Processing file: data/de_DW\Armeesprecher Israelisches Militär fand Tunnelschacht im Schifa-Krankenhaus  DW Nachrichten.de.vtt
# Base name for metadata lookup: armeesprecher israelisches militär fand tunnelschacht im schifa-krankenhaus  dw nachrichten
# Metadata found for: armeesprecher israelisches militär fand tunnelschacht im schifa-krankenhaus  dw nachrichten
# Extracted text saved to: armeesprecher israelisches militär fand tunnelschacht im schifa-krankenhaus  dw nachrichten.txt
# Processing file: data/de_DW\Auch der Süden von Gaza ist nicht mehr sicher  DW Nachrichten.de.vtt
# Base name for metadata lookup: auch der süden von gaza ist nicht mehr sicher  dw nachrichten
# Metadata found for: auch der süden von gaza ist nicht mehr sicher  dw nachrichten
# Extracted text saved to: auch der süden von gaza ist nicht mehr sicher  dw nachrichten.txt
# Processing file: data/de_DW\Baerbock fordert internationale Verantwortung in Gaza  DW Nachrichten.de.vtt
# Base name for metadata lookup: baerbock fordert internationale verantwortung in gaza  dw nachrichten
# Metadata found for: baerbock fordert internationale verantwortung in gaza  dw nachrichten
# Extracted text saved to: baerbock fordert internationale verantwortung in gaza  dw nachrichten.txt
# Processing file: data/de_DW\Begrenzter israelischer Panzervorstoß im Gazastreifen  DW Nachrichten.de.vtt
# Base name for metadata lookup: begrenzter israelischer panzervorstoß im gazastreifen  dw nachrichten
# Metadata found for: begrenzter israelischer panzervorstoß im gazastreifen  dw nachrichten
# Extracted text saved to: begrenzter israelischer panzervorstoß im gazastreifen  dw nachrichten.txt
# Processing file: data/de_DW\Bundespräsident Deutschland ist gefordert wie lange nicht  DW Nachrichten.de.vtt
# Base name for metadata lookup: bundespräsident deutschland ist gefordert wie lange nicht  dw nachrichten
# Metadata found for: bundespräsident deutschland ist gefordert wie lange nicht  dw nachrichten
# Extracted text saved to: bundespräsident deutschland ist gefordert wie lange nicht  dw nachrichten.txt
# Processing file: data/de_DW\Bäckerei in Gaza-Stadt eröffnet zum ersten Mal seit Kriegsbeginn  DW Nachrichten.de.vtt
# Base name for metadata lookup: bäckerei in gaza-stadt eröffnet zum ersten mal seit kriegsbeginn  dw nachrichten
# Metadata found for: bäckerei in gaza-stadt eröffnet zum ersten mal seit kriegsbeginn  dw nachrichten
# Extracted text saved to: bäckerei in gaza-stadt eröffnet zum ersten mal seit kriegsbeginn  dw nachrichten.txt
# Processing file: data/de_DW\Das Freiheitstheater von Dschenin  DW Nachrichten.de.vtt
# Base name for metadata lookup: das freiheitstheater von dschenin  dw nachrichten
# Metadata found for: das freiheitstheater von dschenin  dw nachrichten
# Extracted text saved to: das freiheitstheater von dschenin  dw nachrichten.txt
# Processing file: data/de_DW\Deutsch-französische Besatzung fliegt Hilfe zu den Menschen in den Gazastreifen  DW Nachrichten.de.vtt
# Base name for metadata lookup: deutsch-französische besatzung fliegt hilfe zu den menschen in den gazastreifen  dw nachrichten
# Metadata found for: deutsch-französische besatzung fliegt hilfe zu den menschen in den gazastreifen  dw nachrichten
# Extracted text saved to: deutsch-französische besatzung fliegt hilfe zu den menschen in den gazastreifen  dw nachrichten.txt
# Processing file: data/de_DW\Deutschland Sorge über Krieg im Nahen Osten  DW Nachrichten.de.vtt
# Base name for metadata lookup: deutschland sorge über krieg im nahen osten  dw nachrichten
# Metadata found for: deutschland sorge über krieg im nahen osten  dw nachrichten
# Extracted text saved to: deutschland sorge über krieg im nahen osten  dw nachrichten.txt
# Processing file: data/de_DW\Die Einzigartigkeit deutsch-israelischer Beziehungen  DW Nachrichten.de.vtt
# Base name for metadata lookup: die einzigartigkeit deutsch-israelischer beziehungen  dw nachrichten
# Metadata found for: die einzigartigkeit deutsch-israelischer beziehungen  dw nachrichten
# Extracted text saved to: die einzigartigkeit deutsch-israelischer beziehungen  dw nachrichten.txt
# Processing file: data/de_DW\Die EU-Kommission ist für die Ukraine in der EU, was spricht noch dagegen  DW Nachrichten.de.vtt
# Base name for metadata lookup: die eu-kommission ist für die ukraine in der eu, was spricht noch dagegen  dw nachrichten
# Metadata found for: die eu-kommission ist für die ukraine in der eu, was spricht noch dagegen  dw nachrichten
# Extracted text saved to: die eu-kommission ist für die ukraine in der eu, was spricht noch dagegen  dw nachrichten.txt
# Processing file: data/de_DW\Drei Tote bei Attentat in Jerusalem  DW Nachrichten.de.vtt
# Base name for metadata lookup: drei tote bei attentat in jerusalem  dw nachrichten
# Metadata found for: drei tote bei attentat in jerusalem  dw nachrichten
# Extracted text saved to: drei tote bei attentat in jerusalem  dw nachrichten.txt
# Processing file: data/de_DW\Droht jetzt der Flächenbrand in Nahost  DW Nachrichten.de.vtt
# Base name for metadata lookup: droht jetzt der flächenbrand in nahost  dw nachrichten
# Metadata found for: droht jetzt der flächenbrand in nahost  dw nachrichten
# Extracted text saved to: droht jetzt der flächenbrand in nahost  dw nachrichten.txt
# Processing file: data/de_DW\Entsetzen und Proteste nach Raketeneinschlag auf Klinikgelände in Gaza  DW Nachrichten.de.vtt
# Base name for metadata lookup: entsetzen und proteste nach raketeneinschlag auf klinikgelände in gaza  dw nachrichten
# Metadata found for: entsetzen und proteste nach raketeneinschlag auf klinikgelände in gaza  dw nachrichten
# Extracted text saved to: entsetzen und proteste nach raketeneinschlag auf klinikgelände in gaza  dw nachrichten.txt
# Processing file: data/de_DW\Es ist eine Katastrophe, die nicht zu erklären ist  DW Nachrichten.de.vtt
# Base name for metadata lookup: es ist eine katastrophe, die nicht zu erklären ist  dw nachrichten
# Metadata found for: es ist eine katastrophe, die nicht zu erklären ist  dw nachrichten
# Extracted text saved to: es ist eine katastrophe, die nicht zu erklären ist  dw nachrichten.txt
# Processing file: data/de_DW\EU ringt um Haltung zum Nahost-Konflikt  DW Nachrichten.de.vtt
# Base name for metadata lookup: eu ringt um haltung zum nahost-konflikt  dw nachrichten
# Metadata found for: eu ringt um haltung zum nahost-konflikt  dw nachrichten
# Extracted text saved to: eu ringt um haltung zum nahost-konflikt  dw nachrichten.txt
# Processing file: data/de_DW\Ex-Geheimagent über die Herausforderung bei Verhandlungen zur Geiselbefreiung  DW Nachrichten.de.vtt
# Base name for metadata lookup: ex-geheimagent über die herausforderung bei verhandlungen zur geiselbefreiung  dw nachrichten
# Metadata found for: ex-geheimagent über die herausforderung bei verhandlungen zur geiselbefreiung  dw nachrichten
# Extracted text saved to: ex-geheimagent über die herausforderung bei verhandlungen zur geiselbefreiung  dw nachrichten.txt
# Processing file: data/de_DW\Extremisten in Deutschland Wann Ausweisungen und Abschiebungen möglich sind  DW Nachrichten.de.vtt
# Base name for metadata lookup: extremisten in deutschland wann ausweisungen und abschiebungen möglich sind  dw nachrichten
# Metadata found for: extremisten in deutschland wann ausweisungen und abschiebungen möglich sind  dw nachrichten
# Extracted text saved to: extremisten in deutschland wann ausweisungen und abschiebungen möglich sind  dw nachrichten.txt
# Processing file: data/de_DW\Faktencheck Wie man Desinformation im Nahost-Krieg erkennt  DW Nachrichten.de.vtt
# Base name for metadata lookup: faktencheck wie man desinformation im nahost-krieg erkennt  dw nachrichten
# Metadata found for: faktencheck wie man desinformation im nahost-krieg erkennt  dw nachrichten
# Extracted text saved to: faktencheck wie man desinformation im nahost-krieg erkennt  dw nachrichten.txt
# Processing file: data/de_DW\FDP-Politiker Semet Iran will Konflikt mit Israel nicht eskalieren lassen  DW Nachrichten.de.vtt
# Base name for metadata lookup: fdp-politiker semet iran will konflikt mit israel nicht eskalieren lassen  dw nachrichten
# Metadata found for: fdp-politiker semet iran will konflikt mit israel nicht eskalieren lassen  dw nachrichten
# Extracted text saved to: fdp-politiker semet iran will konflikt mit israel nicht eskalieren lassen  dw nachrichten.txt
# Processing file: data/de_DW\Fortschritte bei Verhandlungen über Geiselbefreiung  DW Nachrichten.de.vtt
# Base name for metadata lookup: fortschritte bei verhandlungen über geiselbefreiung  dw nachrichten
# Metadata found for: fortschritte bei verhandlungen über geiselbefreiung  dw nachrichten
# Extracted text saved to: fortschritte bei verhandlungen über geiselbefreiung  dw nachrichten.txt
# Processing file: data/de_DW\Gaza Apelle für humanitäre Hilfe, Hamas lässt erste Geiseln frei  DW Nachrichten.de.vtt
# Base name for metadata lookup: gaza apelle für humanitäre hilfe, hamas lässt erste geiseln frei  dw nachrichten
# Metadata found for: gaza apelle für humanitäre hilfe, hamas lässt erste geiseln frei  dw nachrichten
# Extracted text saved to: gaza apelle für humanitäre hilfe, hamas lässt erste geiseln frei  dw nachrichten.txt
# Processing file: data/de_DW\Gaza Das israelische Militär rückt weiter vor, warum kommt keine humanitäre Pause  DW Nachrichten.de.vtt
# Base name for metadata lookup: gaza das israelische militär rückt weiter vor, warum kommt keine humanitäre pause  dw nachrichten
# Metadata found for: gaza das israelische militär rückt weiter vor, warum kommt keine humanitäre pause  dw nachrichten
# Extracted text saved to: gaza das israelische militär rückt weiter vor, warum kommt keine humanitäre pause  dw nachrichten.txt
# Processing file: data/de_DW\Gaza Kaum Informationen über entführte Geiseln  DW Nachrichten.de.vtt
# Base name for metadata lookup: gaza kaum informationen über entführte geiseln  dw nachrichten
# Metadata found for: gaza kaum informationen über entführte geiseln  dw nachrichten
# Extracted text saved to: gaza kaum informationen über entführte geiseln  dw nachrichten.txt
# Processing file: data/de_DW\Gaza Krankenhäuser zwischen den Fronten  DW Nachrichten.de.vtt
# Base name for metadata lookup: gaza krankenhäuser zwischen den fronten  dw nachrichten
# Metadata found for: gaza krankenhäuser zwischen den fronten  dw nachrichten
# Extracted text saved to: gaza krankenhäuser zwischen den fronten  dw nachrichten.txt
# Processing file: data/de_DW\Gazastreifen Fast eine halbe Million Menschen leiden unter Hunger  DW Nachrichten.de.vtt
# Base name for metadata lookup: gazastreifen fast eine halbe million menschen leiden unter hunger  dw nachrichten
# Metadata found for: gazastreifen fast eine halbe million menschen leiden unter hunger  dw nachrichten
# Extracted text saved to: gazastreifen fast eine halbe million menschen leiden unter hunger  dw nachrichten.txt
# Processing file: data/de_DW\Geisel-Vereinbarung Warum Katar ein wichtiger Teil der Verhandlungen war  DW Nachrichten.de.vtt
# Base name for metadata lookup: geisel-vereinbarung warum katar ein wichtiger teil der verhandlungen war  dw nachrichten
# Metadata found for: geisel-vereinbarung warum katar ein wichtiger teil der verhandlungen war  dw nachrichten
# Extracted text saved to: geisel-vereinbarung warum katar ein wichtiger teil der verhandlungen war  dw nachrichten.txt
# Processing file: data/de_DW\Gewalt gegen Palästinenser im Westjordanland nimmt zu  DW Nachrichten.de.vtt
# Base name for metadata lookup: gewalt gegen palästinenser im westjordanland nimmt zu  dw nachrichten
# Metadata found for: gewalt gegen palästinenser im westjordanland nimmt zu  dw nachrichten
# Extracted text saved to: gewalt gegen palästinenser im westjordanland nimmt zu  dw nachrichten.txt
# Processing file: data/de_DW\Haft­be­fehle gegen Net­anyahu und Hamas-Führer bean­tragt  DW Nachrichten.de.vtt
# Base name for metadata lookup: haft­be­fehle gegen net­anyahu und hamas-führer bean­tragt  dw nachrichten
# Metadata found for: haft­be­fehle gegen net­anyahu und hamas-führer bean­tragt  dw nachrichten
# Extracted text saved to: haft­be­fehle gegen net­anyahu und hamas-führer bean­tragt  dw nachrichten.txt
# Processing file: data/de_DW\Hamas-Terror gegen Israel Wie der Konflikt die Region weiter spaltet  Auf den Punkt.de.vtt
# Base name for metadata lookup: hamas-terror gegen israel wie der konflikt die region weiter spaltet  auf den punkt
# Metadata found for: hamas-terror gegen israel wie der konflikt die region weiter spaltet  auf den punkt
# Extracted text saved to: hamas-terror gegen israel wie der konflikt die region weiter spaltet  auf den punkt.txt
# Processing file: data/de_DW\IDF Eine mögliche Offensive im Süden Gazas steht bevor  DW Nachrichten.de.vtt
# Base name for metadata lookup: idf eine mögliche offensive im süden gazas steht bevor  dw nachrichten
# Metadata found for: idf eine mögliche offensive im süden gazas steht bevor  dw nachrichten
# Extracted text saved to: idf eine mögliche offensive im süden gazas steht bevor  dw nachrichten.txt
# Processing file: data/de_DW\IGH beginnt Anhörung zur Besetzung der Palästinensergebiete  DW Nachrichten.de.vtt
# Base name for metadata lookup: igh beginnt anhörung zur besetzung der palästinensergebiete  dw nachrichten
# Metadata found for: igh beginnt anhörung zur besetzung der palästinensergebiete  dw nachrichten
# Extracted text saved to: igh beginnt anhörung zur besetzung der palästinensergebiete  dw nachrichten.txt
# Processing file: data/de_DW\Informationskrieg in Gaza  DW Nachrichten.de.vtt
# Base name for metadata lookup: informationskrieg in gaza  dw nachrichten
# Metadata found for: informationskrieg in gaza  dw nachrichten
# Extracted text saved to: informationskrieg in gaza  dw nachrichten.txt
# Processing file: data/de_DW\Israel billigt Deal zur Geiselfreilassung  DW Nachrichten.de.vtt
# Base name for metadata lookup: israel billigt deal zur geiselfreilassung  dw nachrichten
# Metadata found for: israel billigt deal zur geiselfreilassung  dw nachrichten
# Extracted text saved to: israel billigt deal zur geiselfreilassung  dw nachrichten.txt
# Processing file: data/de_DW\Israel fordert Menschen im Gazastreifen zur Flucht nach Süd-Gaza auf  DW Nachrichten.de.vtt
# Base name for metadata lookup: israel fordert menschen im gazastreifen zur flucht nach süd-gaza auf  dw nachrichten
# Metadata found for: israel fordert menschen im gazastreifen zur flucht nach süd-gaza auf  dw nachrichten
# Extracted text saved to: israel fordert menschen im gazastreifen zur flucht nach süd-gaza auf  dw nachrichten.txt
# Processing file: data/de_DW\Israel hat sich nach Angaben der USA zu täglichen Feuerpausen bereiterklärt  DW Nachrichten.de.vtt
# Base name for metadata lookup: israel hat sich nach angaben der usa zu täglichen feuerpausen bereiterklärt  dw nachrichten
# Metadata found for: israel hat sich nach angaben der usa zu täglichen feuerpausen bereiterklärt  dw nachrichten
# Extracted text saved to: israel hat sich nach angaben der usa zu täglichen feuerpausen bereiterklärt  dw nachrichten.txt
# Processing file: data/de_DW\Israel mobilisiert für potentielle Bodenoffensive in Gaza  DW Nachrichten.de.vtt
# Base name for metadata lookup: israel mobilisiert für potentielle bodenoffensive in gaza  dw nachrichten
# Metadata found for: israel mobilisiert für potentielle bodenoffensive in gaza  dw nachrichten
# Extracted text saved to: israel mobilisiert für potentielle bodenoffensive in gaza  dw nachrichten.txt
# Processing file: data/de_DW\Israel unternimmt weiteren Panzervorstoß nach Gaza  DW Nachrichten.de.vtt
# Base name for metadata lookup: israel unternimmt weiteren panzervorstoß nach gaza  dw nachrichten
# Metadata found for: israel unternimmt weiteren panzervorstoß nach gaza  dw nachrichten
# Extracted text saved to: israel unternimmt weiteren panzervorstoß nach gaza  dw nachrichten.txt
# Processing file: data/de_DW\Israel Vorbereitungen auf Einsatz im Gazastreifen laufen weiter  DW Nachrichten.de.vtt
# Base name for metadata lookup: israel vorbereitungen auf einsatz im gazastreifen laufen weiter  dw nachrichten
# Metadata found for: israel vorbereitungen auf einsatz im gazastreifen laufen weiter  dw nachrichten
# Extracted text saved to: israel vorbereitungen auf einsatz im gazastreifen laufen weiter  dw nachrichten.txt
# Processing file: data/de_DW\Israel will begrenzte Hilfslieferungen in den Gazastreifen zulassen  DW Nachrichten.de.vtt
# Base name for metadata lookup: israel will begrenzte hilfslieferungen in den gazastreifen zulassen  dw nachrichten
# Metadata found for: israel will begrenzte hilfslieferungen in den gazastreifen zulassen  dw nachrichten
# Extracted text saved to: israel will begrenzte hilfslieferungen in den gazastreifen zulassen  dw nachrichten.txt
# Processing file: data/de_DW\Israeli ruft nach dem Verlust seiner Eltern durch Hamas-Anschlag zum Frieden auf  DW #Shorts.de.vtt
# Base name for metadata lookup: israeli ruft nach dem verlust seiner eltern durch hamas-anschlag zum frieden auf  dw #shorts
# Metadata found for: israeli ruft nach dem verlust seiner eltern durch hamas-anschlag zum frieden auf  dw #shorts
# Extracted text saved to: israeli ruft nach dem verlust seiner eltern durch hamas-anschlag zum frieden auf  dw #shorts.txt
# Processing file: data/de_DW\Israelische Amee Hamas-Geiseln waren zeitweise in Schifa-Klinik  DW Nachrichten.de.vtt
# Base name for metadata lookup: israelische amee hamas-geiseln waren zeitweise in schifa-klinik  dw nachrichten
# Metadata found for: israelische amee hamas-geiseln waren zeitweise in schifa-klinik  dw nachrichten
# Extracted text saved to: israelische amee hamas-geiseln waren zeitweise in schifa-klinik  dw nachrichten.txt
# Processing file: data/de_DW\Israelische Armee verstärkt Offensive gegen Hamas  DW Nachrichten.de.vtt
# Base name for metadata lookup: israelische armee verstärkt offensive gegen hamas  dw nachrichten
# Metadata found for: israelische armee verstärkt offensive gegen hamas  dw nachrichten
# Extracted text saved to: israelische armee verstärkt offensive gegen hamas  dw nachrichten.txt
# Processing file: data/de_DW\Israelische Militäroperation in Gazas größtem Krankenhaus  DW Nachrichten.de.vtt
# Base name for metadata lookup: israelische militäroperation in gazas größtem krankenhaus  dw nachrichten
# Metadata found for: israelische militäroperation in gazas größtem krankenhaus  dw nachrichten
# Extracted text saved to: israelische militäroperation in gazas größtem krankenhaus  dw nachrichten.txt
# Processing file: data/de_DW\Israelische Reservisten wollen nicht wieder in den Krieg  DW Nachrichten.de.vtt
# Base name for metadata lookup: israelische reservisten wollen nicht wieder in den krieg  dw nachrichten
# Metadata found for: israelische reservisten wollen nicht wieder in den krieg  dw nachrichten
# Extracted text saved to: israelische reservisten wollen nicht wieder in den krieg  dw nachrichten.txt
# Processing file: data/de_DW\Kann der große Krieg im Nahen Osten noch verhindert werden  DW Nachrichten.de.vtt
# Base name for metadata lookup: kann der große krieg im nahen osten noch verhindert werden  dw nachrichten
# Metadata found for: kann der große krieg im nahen osten noch verhindert werden  dw nachrichten
# Extracted text saved to: kann der große krieg im nahen osten noch verhindert werden  dw nachrichten.txt
# Processing file: data/de_DW\Kann Israel die Terrororganisation Hamas in Gaza vollständig zerstören  DW Nachrichten.de.vtt
# Base name for metadata lookup: kann israel die terrororganisation hamas in gaza vollständig zerstören  dw nachrichten
# Metadata found for: kann israel die terrororganisation hamas in gaza vollständig zerstören  dw nachrichten
# Extracted text saved to: kann israel die terrororganisation hamas in gaza vollständig zerstören  dw nachrichten.txt
# Processing file: data/de_DW\Krieg in Nahost birgt Gefahr eines Flächenbrandes  DW Nachrichten.de.vtt
# Base name for metadata lookup: krieg in nahost birgt gefahr eines flächenbrandes  dw nachrichten
# Metadata found for: krieg in nahost birgt gefahr eines flächenbrandes  dw nachrichten
# Extracted text saved to: krieg in nahost birgt gefahr eines flächenbrandes  dw nachrichten.txt
# Processing file: data/de_DW\Kritik am Besuch des Emirs Scholz trifft Sponsor der Hamas  DW Nachrichten.de.vtt
# Base name for metadata lookup: kritik am besuch des emirs scholz trifft sponsor der hamas  dw nachrichten
# Metadata found for: kritik am besuch des emirs scholz trifft sponsor der hamas  dw nachrichten
# Extracted text saved to: kritik am besuch des emirs scholz trifft sponsor der hamas  dw nachrichten.txt
# Processing file: data/de_DW\Können die 199 Geiseln in den Händen der Hamas gerettet werden  DW Nachrichten.de.vtt
# Base name for metadata lookup: können die 199 geiseln in den händen der hamas gerettet werden  dw nachrichten
# Metadata found for: können die 199 geiseln in den händen der hamas gerettet werden  dw nachrichten
# Extracted text saved to: können die 199 geiseln in den händen der hamas gerettet werden  dw nachrichten.txt
# Processing file: data/de_DW\Leben im Luxus Die Hamas-Führung in Katar  DW Nachrichten.de.vtt
# Base name for metadata lookup: leben im luxus die hamas-führung in katar  dw nachrichten
# Metadata found for: leben im luxus die hamas-führung in katar  dw nachrichten
# Extracted text saved to: leben im luxus die hamas-führung in katar  dw nachrichten.txt
# Processing file: data/de_DW\Libanon Wie geht es den Menschen unter der Hisbollah  DW Deutsch.de.vtt
# Base name for metadata lookup: libanon wie geht es den menschen unter der hisbollah  dw deutsch
# Metadata found for: libanon wie geht es den menschen unter der hisbollah  dw deutsch
# Extracted text saved to: libanon wie geht es den menschen unter der hisbollah  dw deutsch.txt
# Processing file: data/de_DW\Mehr als 90 Tote in Gaza nach israelischem Luftschlag  DW Nachrichten.de.vtt
# Base name for metadata lookup: mehr als 90 tote in gaza nach israelischem luftschlag  dw nachrichten
# Metadata found for: mehr als 90 tote in gaza nach israelischem luftschlag  dw nachrichten
# Extracted text saved to: mehr als 90 tote in gaza nach israelischem luftschlag  dw nachrichten.txt
# Processing file: data/de_DW\Mehr als eine Million Menschen im Gazastreifen von Hungersnot bedroht  DW Nachrichten.de.vtt
# Base name for metadata lookup: mehr als eine million menschen im gazastreifen von hungersnot bedroht  dw nachrichten
# Metadata found for: mehr als eine million menschen im gazastreifen von hungersnot bedroht  dw nachrichten
# Extracted text saved to: mehr als eine million menschen im gazastreifen von hungersnot bedroht  dw nachrichten.txt
# Processing file: data/de_DW\Nach der Freilassung Könnten weitere Feuerpausen folgen  DW Nachrichten.de.vtt
# Base name for metadata lookup: nach der freilassung könnten weitere feuerpausen folgen  dw nachrichten
# Metadata found for: nach der freilassung könnten weitere feuerpausen folgen  dw nachrichten
# Extracted text saved to: nach der freilassung könnten weitere feuerpausen folgen  dw nachrichten.txt
# Processing file: data/de_DW\Nach Israels Luftschlag gegen NGO Hilfslieferungen nach Gaza vorerst gestoppt  DW Nachrichten.de.vtt
# Base name for metadata lookup: nach israels luftschlag gegen ngo hilfslieferungen nach gaza vorerst gestoppt  dw nachrichten
# Metadata found for: nach israels luftschlag gegen ngo hilfslieferungen nach gaza vorerst gestoppt  dw nachrichten
# Extracted text saved to: nach israels luftschlag gegen ngo hilfslieferungen nach gaza vorerst gestoppt  dw nachrichten.txt
# Processing file: data/de_DW\Nahost-Konflikt Auch Thema beim Seidenstraßen-Gipfel in Peking  DW Nachrichten.de.vtt
# Base name for metadata lookup: nahost-konflikt auch thema beim seidenstraßen-gipfel in peking  dw nachrichten
# Metadata found for: nahost-konflikt auch thema beim seidenstraßen-gipfel in peking  dw nachrichten
# Extracted text saved to: nahost-konflikt auch thema beim seidenstraßen-gipfel in peking  dw nachrichten.txt
# Processing file: data/de_DW\Nahost-Konflikt Biden wünscht sich Pause  DW Nachrichten.de.vtt
# Base name for metadata lookup: nahost-konflikt biden wünscht sich pause  dw nachrichten
# Metadata found for: nahost-konflikt biden wünscht sich pause  dw nachrichten
# Extracted text saved to: nahost-konflikt biden wünscht sich pause  dw nachrichten.txt
# Processing file: data/de_DW\Nahost-Konflikt Ukraine fürchtet um Militärhilfen  DW Nachrichten.de.vtt
# Base name for metadata lookup: nahost-konflikt ukraine fürchtet um militärhilfen  dw nachrichten
# Metadata found for: nahost-konflikt ukraine fürchtet um militärhilfen  dw nachrichten
# Extracted text saved to: nahost-konflikt ukraine fürchtet um militärhilfen  dw nachrichten.txt
# Processing file: data/de_DW\Palästinensische Geflüchtete berichten über ihr Leid  DW Nachrichten.de.vtt
# Base name for metadata lookup: palästinensische geflüchtete berichten über ihr leid  dw nachrichten
# Metadata found for: palästinensische geflüchtete berichten über ihr leid  dw nachrichten
# Extracted text saved to: palästinensische geflüchtete berichten über ihr leid  dw nachrichten.txt
# Processing file: data/de_DW\Scharfe Reaktionen auf iranischen Drohnenangriff auf Israel  DW Nachrichten.de.vtt
# Base name for metadata lookup: scharfe reaktionen auf iranischen drohnenangriff auf israel  dw nachrichten
# Metadata found for: scharfe reaktionen auf iranischen drohnenangriff auf israel  dw nachrichten
# Extracted text saved to: scharfe reaktionen auf iranischen drohnenangriff auf israel  dw nachrichten.txt
# Processing file: data/de_DW\Scholz besucht Israel 10 Tage nach Terroranschlag  DW Nachrichten.de.vtt
# Base name for metadata lookup: scholz besucht israel 10 tage nach terroranschlag  dw nachrichten
# Metadata found for: scholz besucht israel 10 tage nach terroranschlag  dw nachrichten
# Extracted text saved to: scholz besucht israel 10 tage nach terroranschlag  dw nachrichten.txt
# Processing file: data/de_DW\Sderot, Grenzort zum Gazastreifen, ist angeblich wieder sicher  DW Nachrichten.de.vtt
# Base name for metadata lookup: sderot, grenzort zum gazastreifen, ist angeblich wieder sicher  dw nachrichten
# Metadata found for: sderot, grenzort zum gazastreifen, ist angeblich wieder sicher  dw nachrichten
# Extracted text saved to: sderot, grenzort zum gazastreifen, ist angeblich wieder sicher  dw nachrichten.txt
# Processing file: data/de_DW\Studentenproteste Wann wird aus pro-palästinensischem Aktivismus Antisemitismus  DW Nachrichten.de.vtt
# Base name for metadata lookup: studentenproteste wann wird aus pro-palästinensischem aktivismus antisemitismus  dw nachrichten
# Metadata found for: studentenproteste wann wird aus pro-palästinensischem aktivismus antisemitismus  dw nachrichten
# Extracted text saved to: studentenproteste wann wird aus pro-palästinensischem aktivismus antisemitismus  dw nachrichten.txt
# Processing file: data/de_DW\Tote Journalisten Nichtregierungs-Organisationen schlagen Alarm  DW Nachrichten.de.vtt
# Base name for metadata lookup: tote journalisten nichtregierungs-organisationen schlagen alarm  dw nachrichten
# Metadata found for: tote journalisten nichtregierungs-organisationen schlagen alarm  dw nachrichten
# Extracted text saved to: tote journalisten nichtregierungs-organisationen schlagen alarm  dw nachrichten.txt
# Processing file: data/de_DW\Türkischer Präsident stellt vor Berlin-Reise Israels Existenzrecht in Frage  DW Nachrichten.de.vtt
# Base name for metadata lookup: türkischer präsident stellt vor berlin-reise israels existenzrecht in frage  dw nachrichten
# Metadata found for: türkischer präsident stellt vor berlin-reise israels existenzrecht in frage  dw nachrichten
# Extracted text saved to: türkischer präsident stellt vor berlin-reise israels existenzrecht in frage  dw nachrichten.txt
# Processing file: data/de_DW\US-Außenminister Blinken erneut in Israel   DW Nachrichten.de.vtt
# Base name for metadata lookup: us-außenminister blinken erneut in israel   dw nachrichten
# Metadata found for: us-außenminister blinken erneut in israel   dw nachrichten
# Extracted text saved to: us-außenminister blinken erneut in israel   dw nachrichten.txt
# Processing file: data/de_DW\USA Pro-palästinensische Proteste an Unis weiten sich aus  DW Nachrichten.de.vtt
# Base name for metadata lookup: usa pro-palästinensische proteste an unis weiten sich aus  dw nachrichten
# Metadata found for: usa pro-palästinensische proteste an unis weiten sich aus  dw nachrichten
# Extracted text saved to: usa pro-palästinensische proteste an unis weiten sich aus  dw nachrichten.txt
# Processing file: data/de_DW\Verfassungsschutz Viele radikale Gruppen in Deutschland pro-Hamas  DW Nachrichten.de.vtt
# Base name for metadata lookup: verfassungsschutz viele radikale gruppen in deutschland pro-hamas  dw nachrichten
# Metadata found for: verfassungsschutz viele radikale gruppen in deutschland pro-hamas  dw nachrichten
# Extracted text saved to: verfassungsschutz viele radikale gruppen in deutschland pro-hamas  dw nachrichten.txt
# Processing file: data/de_DW\Vergewaltigung, Misshandlung, Demütigung - Sexualisierte Gewalt in bewaffneten Konflikten.de.vtt
# Base name for metadata lookup: vergewaltigung, misshandlung, demütigung - sexualisierte gewalt in bewaffneten konflikten
# Metadata found for: vergewaltigung, misshandlung, demütigung - sexualisierte gewalt in bewaffneten konflikten
# Extracted text saved to: vergewaltigung, misshandlung, demütigung - sexualisierte gewalt in bewaffneten konflikten.txt
# Processing file: data/de_DW\Versuchter Brandanschlag auf jüdisches Zentrum in Berlin  DW Nachrichten.de.vtt
# Base name for metadata lookup: versuchter brandanschlag auf jüdisches zentrum in berlin  dw nachrichten
# Metadata found for: versuchter brandanschlag auf jüdisches zentrum in berlin  dw nachrichten
# Extracted text saved to: versuchter brandanschlag auf jüdisches zentrum in berlin  dw nachrichten.txt
# Processing file: data/de_DW\Warum nimmt im Westjordanland die Gewalt zu  Nachrichten.de.vtt
# Base name for metadata lookup: warum nimmt im westjordanland die gewalt zu  nachrichten
# Metadata found for: warum nimmt im westjordanland die gewalt zu  nachrichten
# Extracted text saved to: warum nimmt im westjordanland die gewalt zu  nachrichten.txt
# Processing file: data/de_DW\Was führte zum Ende des Waffenstillstands zwischen Israel und Hamas  DW Nachrichten.de.vtt
# Base name for metadata lookup: was führte zum ende des waffenstillstands zwischen israel und hamas  dw nachrichten
# Metadata found for: was führte zum ende des waffenstillstands zwischen israel und hamas  dw nachrichten
# Extracted text saved to: was führte zum ende des waffenstillstands zwischen israel und hamas  dw nachrichten.txt
# Processing file: data/de_DW\Was passiert mit dem Gazastreifen, wenn der Krieg vorbei ist  DW Nachrichten.de.vtt
# Base name for metadata lookup: was passiert mit dem gazastreifen, wenn der krieg vorbei ist  dw nachrichten
# Metadata found for: was passiert mit dem gazastreifen, wenn der krieg vorbei ist  dw nachrichten
# Extracted text saved to: was passiert mit dem gazastreifen, wenn der krieg vorbei ist  dw nachrichten.txt
# Processing file: data/de_DW\Was sagen die Konfliktparteien zur Verlängerung  DW Nachrichten.de.vtt
# Base name for metadata lookup: was sagen die konfliktparteien zur verlängerung  dw nachrichten
# Metadata found for: was sagen die konfliktparteien zur verlängerung  dw nachrichten
# Extracted text saved to: was sagen die konfliktparteien zur verlängerung  dw nachrichten.txt
# Processing file: data/de_DW\Welches Ziel hat die Hamas verfolgt mit dem Terroranschlag auf Israel  DW Nachrichten.de.vtt
# Base name for metadata lookup: welches ziel hat die hamas verfolgt mit dem terroranschlag auf israel  dw nachrichten
# Metadata found for: welches ziel hat die hamas verfolgt mit dem terroranschlag auf israel  dw nachrichten
# Extracted text saved to: welches ziel hat die hamas verfolgt mit dem terroranschlag auf israel  dw nachrichten.txt
# Processing file: data/de_DW\Wenn humanitäre Hilfe für Gaza blockiert wird  DW Nachrichten.de.vtt
# Base name for metadata lookup: wenn humanitäre hilfe für gaza blockiert wird  dw nachrichten
# Metadata found for: wenn humanitäre hilfe für gaza blockiert wird  dw nachrichten
# Extracted text saved to: wenn humanitäre hilfe für gaza blockiert wird  dw nachrichten.txt
# Processing file: data/de_DW\Wer Deutscher werden will, soll sich zum Existenzrecht Israels bekennen  DW Nachrichten.de.vtt
# Base name for metadata lookup: wer deutscher werden will, soll sich zum existenzrecht israels bekennen  dw nachrichten
# Metadata found for: wer deutscher werden will, soll sich zum existenzrecht israels bekennen  dw nachrichten
# Extracted text saved to: wer deutscher werden will, soll sich zum existenzrecht israels bekennen  dw nachrichten.txt
# Processing file: data/de_DW\Wie der Iran den Nahen Osten anzündet  DW Nachrichten.de.vtt
# Base name for metadata lookup: wie der iran den nahen osten anzündet  dw nachrichten
# Metadata found for: wie der iran den nahen osten anzündet  dw nachrichten
# Extracted text saved to: wie der iran den nahen osten anzündet  dw nachrichten.txt
# Processing file: data/de_DW\Wie der Nahost-Konflikt das Leben in Deutschland spaltet  Fokus Europa.de.vtt
# Base name for metadata lookup: wie der nahost-konflikt das leben in deutschland spaltet  fokus europa
# Metadata found for: wie der nahost-konflikt das leben in deutschland spaltet  fokus europa
# Extracted text saved to: wie der nahost-konflikt das leben in deutschland spaltet  fokus europa.txt
# Processing file: data/de_DW\Wie die Huthi-Miliz im Jemen Preise in Europa hochtreiben  DW Nachrichten.de.vtt
# Base name for metadata lookup: wie die huthi-miliz im jemen preise in europa hochtreiben  dw nachrichten
# Metadata found for: wie die huthi-miliz im jemen preise in europa hochtreiben  dw nachrichten
# Extracted text saved to: wie die huthi-miliz im jemen preise in europa hochtreiben  dw nachrichten.txt
# Processing file: data/de_DW\Wie eine Israelische Frau das Massaker der Hamas überlebte  DW Nachrichten.de.vtt
# Base name for metadata lookup: wie eine israelische frau das massaker der hamas überlebte  dw nachrichten
# Metadata found for: wie eine israelische frau das massaker der hamas überlebte  dw nachrichten
# Extracted text saved to: wie eine israelische frau das massaker der hamas überlebte  dw nachrichten.txt
# Processing file: data/de_DW\Wie eine israelische Mutter um die Freilassung ihres verschleppten Sohnes kämpft  DW Nachrichten.de.vtt
# Base name for metadata lookup: wie eine israelische mutter um die freilassung ihres verschleppten sohnes kämpft  dw nachrichten
# Metadata found for: wie eine israelische mutter um die freilassung ihres verschleppten sohnes kämpft  dw nachrichten
# Extracted text saved to: wie eine israelische mutter um die freilassung ihres verschleppten sohnes kämpft  dw nachrichten.txt
# Processing file: data/de_DW\Wie gut gerüstet sieht sich die NATO in einer Zeit der Unsicherheit  DW Nachrichten.de.vtt
# Base name for metadata lookup: wie gut gerüstet sieht sich die nato in einer zeit der unsicherheit  dw nachrichten
# Metadata found for: wie gut gerüstet sieht sich die nato in einer zeit der unsicherheit  dw nachrichten
# Extracted text saved to: wie gut gerüstet sieht sich die nato in einer zeit der unsicherheit  dw nachrichten.txt
# Processing file: data/de_DW\Wie internationale Kräfte an einer Verlängerung des Waffenstillstands arbeiten  DW Nachrichten.de.vtt
# Base name for metadata lookup: wie internationale kräfte an einer verlängerung des waffenstillstands arbeiten  dw nachrichten
# Metadata found for: wie internationale kräfte an einer verlängerung des waffenstillstands arbeiten  dw nachrichten
# Extracted text saved to: wie internationale kräfte an einer verlängerung des waffenstillstands arbeiten  dw nachrichten.txt
# Processing file: data/de_DW\Wie Israel sich vor Raketen aus Iran und Libanon schützt  DW Nachrichten.de.vtt
# Base name for metadata lookup: wie israel sich vor raketen aus iran und libanon schützt  dw nachrichten
# Metadata found for: wie israel sich vor raketen aus iran und libanon schützt  dw nachrichten
# Extracted text saved to: wie israel sich vor raketen aus iran und libanon schützt  dw nachrichten.txt
# Processing file: data/de_DW\Wie Juden aus Israel nach Ungarn fliehen  Fokus Europa.de.vtt
# Base name for metadata lookup: wie juden aus israel nach ungarn fliehen  fokus europa
# Metadata found for: wie juden aus israel nach ungarn fliehen  fokus europa
# Extracted text saved to: wie juden aus israel nach ungarn fliehen  fokus europa.txt
# Processing file: data/de_DW\Wie können Menschen in Deutschland den Terror der Hamas gutheißen  DW Nachrichten.de.vtt
# Base name for metadata lookup: wie können menschen in deutschland den terror der hamas gutheißen  dw nachrichten
# Metadata found for: wie können menschen in deutschland den terror der hamas gutheißen  dw nachrichten
# Extracted text saved to: wie können menschen in deutschland den terror der hamas gutheißen  dw nachrichten.txt
# Processing file: data/de_DW\Wo steht Israel einen Monat nach dem Terror-Angriff der Hamas  DW Nachrichten.de.vtt
# Base name for metadata lookup: wo steht israel einen monat nach dem terror-angriff der hamas  dw nachrichten
# Metadata found for: wo steht israel einen monat nach dem terror-angriff der hamas  dw nachrichten
# Extracted text saved to: wo steht israel einen monat nach dem terror-angriff der hamas  dw nachrichten.txt
# Processing file: data/de_DW\Ägypten lässt erste Verletzte uns Ausländer aus dem Gazastreifen einreisen  DW News.de.vtt
# Base name for metadata lookup: ägypten lässt erste verletzte uns ausländer aus dem gazastreifen einreisen  dw news
# Metadata found for: ägypten lässt erste verletzte uns ausländer aus dem gazastreifen einreisen  dw news
# Extracted text saved to: ägypten lässt erste verletzte uns ausländer aus dem gazastreifen einreisen  dw news.txt
# Processing file: data/de_DW\„Vom Fluss bis zum Meer“ Warum stellen Bundesländer die Parole unter Strafe  DW Nachrichten.de.vtt
# Base name for metadata lookup: „vom fluss bis zum meer“ warum stellen bundesländer die parole unter strafe  dw nachrichten
# Metadata found for: „vom fluss bis zum meer“ warum stellen bundesländer die parole unter strafe  dw nachrichten
# Extracted text saved to: „vom fluss bis zum meer“ warum stellen bundesländer die parole unter strafe  dw nachrichten.txt
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# ...
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
