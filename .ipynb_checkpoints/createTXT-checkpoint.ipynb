# %% [markdown]
# Sentiment analysis
#
# In this Notebook the existing vtt files will be converted to txt files.

# %%
import os
import webvtt
import csv

# Increase the CSV field size limit to handle larger fields
csv.field_size_limit(10000000)  # Adjust the limit as needed

def list_vtt_files(directory):
    # Recursively find all .vtt files in the directory and subdirectories
    vtt_files = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.vtt'):
                vtt_files.append(os.path.join(root, file))  # Store full path of each .vtt file
    return vtt_files

def read_metadata(csv_file):
    metadata = {}
    # Read metadata from the CSV file and store it in a dictionary
    with open(csv_file, mode='r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            # Extract the base name from the thumbnail_path column
            thumbnail_path = row['thumbnail_path'].strip()
            base_name = os.path.splitext(os.path.basename(thumbnail_path))[0].strip().lower()
            # Remove 'transcript' column from the metadata
            metadata[base_name] = {key: value for key, value in row.items() if key != 'transcript'}
    return metadata

def format_metadata(metadata_row):
    # Format the metadata row into a string
    metadata_str = ""
    for key, value in metadata_row.items():
        metadata_str += f"{key}: {value}\n"
    return metadata_str

def normalize_filename(filename):
    # Remove any language suffixes and normalize the filename
    base_name = os.path.splitext(os.path.basename(filename))[0]
    # Remove common language suffixes (.de, .en, .es, etc.)
    base_name = base_name.split('.')[0].strip().lower()
    return base_name

def add_metadata(file, metadata):
    # Get the base filename (without path or extension) to match with 'thumbnail_path'
    base_name = normalize_filename(file)
    
    # Debug print
    print(f"Processing file: {file}")
    print(f"Base name for metadata lookup: {base_name}")

    # Check if metadata is available for this file
    if base_name in metadata:
        print(f"Metadata found for: {base_name}")  # Debug print
        return format_metadata(metadata[base_name])  # Format the metadata as a string
    else:
        print(f"No metadata found for: {base_name}")  # Debug print
    return ""  # Return an empty string if no metadata is found

def extract_txt(file, metadata):
    # Open and extract text from the .vtt file, remove duplicates
    text_output = []
    seen_lines = set()

    for caption in webvtt.read(file):
        for line in caption.text.splitlines():
            if line not in seen_lines:
                text_output.append(line)
                seen_lines.add(line)

    text = ' '.join(text_output)

    # Create the corresponding .txt filename
    base_name = os.path.splitext(file)[0]
    txt_filename = base_name + '.txt'

    # Add metadata to the text
    metadata_info = add_metadata(file, metadata)

    # Write the metadata and the extracted text to a .txt file
    with open(txt_filename, 'w', encoding='utf-8') as f:
        f.write(metadata_info)  # Write metadata at the top
        f.write(text)  # Write the extracted text

    print(f"Extracted text saved to: {txt_filename}")

# Example usage
directory_path = 'data/'  # Root directory containing subfolders with .vtt files
vtt_files = list_vtt_files(directory_path)

# Load metadata from the CSV files in the data/ folder
metadata_files = [f for f in os.listdir('data') if f.endswith('.csv')]
for metadata_file in metadata_files:
    csv_file = os.path.join('data', metadata_file)
    metadata = read_metadata(csv_file)  # Load the metadata from the data/ folder

    # Process each .vtt file
    for vtt_file in vtt_files:
        # Ensure that the CSV file corresponds to the folder name
        subfolder = os.path.basename(os.path.dirname(vtt_file))
        if metadata_file.startswith(f'{subfolder}.'):
            extract_txt(vtt_file, metadata)  # Extract text and save with metadata
        else:
            print(f"No matching metadata CSV for: {subfolder}")
# Out:
# Base name for matching: 54 objekte in sieben deutschen bundesländern durchsucht  dw nachrichten
# No metadata found for: 54 objekte in sieben deutschen bundesländern durchsucht  dw nachrichten
# Extracted text saved to: data/de_DW\54 Objekte in sieben deutschen Bundesländern durchsucht  DW Nachrichten.de.txt
# Base name for matching: angespannte proteste um den gaza-krieg an us-unis  dw nachrichten
# No metadata found for: angespannte proteste um den gaza-krieg an us-unis  dw nachrichten
# Extracted text saved to: data/de_DW\Angespannte Proteste um den Gaza-Krieg an US-Unis  DW Nachrichten.de.txt
# Base name for matching: angriff auf dem golan - sorge vor einem größeren krieg  dw nachrichten
# No metadata found for: angriff auf dem golan - sorge vor einem größeren krieg  dw nachrichten
# Extracted text saved to: data/de_DW\Angriff auf dem Golan - Sorge vor einem größeren Krieg  DW Nachrichten.de.txt
# Base name for matching: angriff auf israel steckt der iran dahinter  dw nachrichten
# No metadata found for: angriff auf israel steckt der iran dahinter  dw nachrichten
# Extracted text saved to: data/de_DW\Angriff auf Israel Steckt der Iran dahinter  DW Nachrichten.de.txt
# Base name for matching: antisemitische ausschreitungen in dagestan  dw nachrichten
# No metadata found for: antisemitische ausschreitungen in dagestan  dw nachrichten
# Extracted text saved to: data/de_DW\Antisemitische Ausschreitungen in Dagestan  DW Nachrichten.de.txt
# Base name for matching: antisemitismus das schweigen der kulturszene  dw nachrichten
# No metadata found for: antisemitismus das schweigen der kulturszene  dw nachrichten
# Extracted text saved to: data/de_DW\Antisemitismus Das Schweigen der Kulturszene  DW Nachrichten.de.txt
# Base name for matching: armeesprecher israelisches militär fand tunnelschacht im schifa-krankenhaus  dw nachrichten
# No metadata found for: armeesprecher israelisches militär fand tunnelschacht im schifa-krankenhaus  dw nachrichten
# Extracted text saved to: data/de_DW\Armeesprecher Israelisches Militär fand Tunnelschacht im Schifa-Krankenhaus  DW Nachrichten.de.txt
# Base name for matching: auch der süden von gaza ist nicht mehr sicher  dw nachrichten
# No metadata found for: auch der süden von gaza ist nicht mehr sicher  dw nachrichten
# Extracted text saved to: data/de_DW\Auch der Süden von Gaza ist nicht mehr sicher  DW Nachrichten.de.txt
# Base name for matching: baerbock fordert internationale verantwortung in gaza  dw nachrichten
# No metadata found for: baerbock fordert internationale verantwortung in gaza  dw nachrichten
# Extracted text saved to: data/de_DW\Baerbock fordert internationale Verantwortung in Gaza  DW Nachrichten.de.txt
# Base name for matching: begrenzter israelischer panzervorstoß im gazastreifen  dw nachrichten
# No metadata found for: begrenzter israelischer panzervorstoß im gazastreifen  dw nachrichten
# Extracted text saved to: data/de_DW\Begrenzter israelischer Panzervorstoß im Gazastreifen  DW Nachrichten.de.txt
# Base name for matching: bundespräsident deutschland ist gefordert wie lange nicht  dw nachrichten
# No metadata found for: bundespräsident deutschland ist gefordert wie lange nicht  dw nachrichten
# Extracted text saved to: data/de_DW\Bundespräsident Deutschland ist gefordert wie lange nicht  DW Nachrichten.de.txt
# Base name for matching: bäckerei in gaza-stadt eröffnet zum ersten mal seit kriegsbeginn  dw nachrichten
# No metadata found for: bäckerei in gaza-stadt eröffnet zum ersten mal seit kriegsbeginn  dw nachrichten
# Extracted text saved to: data/de_DW\Bäckerei in Gaza-Stadt eröffnet zum ersten Mal seit Kriegsbeginn  DW Nachrichten.de.txt
# Base name for matching: das freiheitstheater von dschenin  dw nachrichten
# No metadata found for: das freiheitstheater von dschenin  dw nachrichten
# Extracted text saved to: data/de_DW\Das Freiheitstheater von Dschenin  DW Nachrichten.de.txt
# Base name for matching: deutsch-französische besatzung fliegt hilfe zu den menschen in den gazastreifen  dw nachrichten
# No metadata found for: deutsch-französische besatzung fliegt hilfe zu den menschen in den gazastreifen  dw nachrichten
# Extracted text saved to: data/de_DW\Deutsch-französische Besatzung fliegt Hilfe zu den Menschen in den Gazastreifen  DW Nachrichten.de.txt
# Base name for matching: deutschland sorge über krieg im nahen osten  dw nachrichten
# No metadata found for: deutschland sorge über krieg im nahen osten  dw nachrichten
# Extracted text saved to: data/de_DW\Deutschland Sorge über Krieg im Nahen Osten  DW Nachrichten.de.txt
# Base name for matching: die einzigartigkeit deutsch-israelischer beziehungen  dw nachrichten
# No metadata found for: die einzigartigkeit deutsch-israelischer beziehungen  dw nachrichten
# Extracted text saved to: data/de_DW\Die Einzigartigkeit deutsch-israelischer Beziehungen  DW Nachrichten.de.txt
# Base name for matching: die eu-kommission ist für die ukraine in der eu, was spricht noch dagegen  dw nachrichten
# No metadata found for: die eu-kommission ist für die ukraine in der eu, was spricht noch dagegen  dw nachrichten
# Extracted text saved to: data/de_DW\Die EU-Kommission ist für die Ukraine in der EU, was spricht noch dagegen  DW Nachrichten.de.txt
# Base name for matching: drei tote bei attentat in jerusalem  dw nachrichten
# No metadata found for: drei tote bei attentat in jerusalem  dw nachrichten
# Extracted text saved to: data/de_DW\Drei Tote bei Attentat in Jerusalem  DW Nachrichten.de.txt
# Base name for matching: droht jetzt der flächenbrand in nahost  dw nachrichten
# No metadata found for: droht jetzt der flächenbrand in nahost  dw nachrichten
# Extracted text saved to: data/de_DW\Droht jetzt der Flächenbrand in Nahost  DW Nachrichten.de.txt
# Base name for matching: entsetzen und proteste nach raketeneinschlag auf klinikgelände in gaza  dw nachrichten
# No metadata found for: entsetzen und proteste nach raketeneinschlag auf klinikgelände in gaza  dw nachrichten
# Extracted text saved to: data/de_DW\Entsetzen und Proteste nach Raketeneinschlag auf Klinikgelände in Gaza  DW Nachrichten.de.txt
# Base name for matching: es ist eine katastrophe, die nicht zu erklären ist  dw nachrichten
# No metadata found for: es ist eine katastrophe, die nicht zu erklären ist  dw nachrichten
# Extracted text saved to: data/de_DW\Es ist eine Katastrophe, die nicht zu erklären ist  DW Nachrichten.de.txt
# Base name for matching: eu ringt um haltung zum nahost-konflikt  dw nachrichten
# No metadata found for: eu ringt um haltung zum nahost-konflikt  dw nachrichten
# Extracted text saved to: data/de_DW\EU ringt um Haltung zum Nahost-Konflikt  DW Nachrichten.de.txt
# Base name for matching: ex-geheimagent über die herausforderung bei verhandlungen zur geiselbefreiung  dw nachrichten
# No metadata found for: ex-geheimagent über die herausforderung bei verhandlungen zur geiselbefreiung  dw nachrichten
# Extracted text saved to: data/de_DW\Ex-Geheimagent über die Herausforderung bei Verhandlungen zur Geiselbefreiung  DW Nachrichten.de.txt
# Base name for matching: extremisten in deutschland wann ausweisungen und abschiebungen möglich sind  dw nachrichten
# No metadata found for: extremisten in deutschland wann ausweisungen und abschiebungen möglich sind  dw nachrichten
# Extracted text saved to: data/de_DW\Extremisten in Deutschland Wann Ausweisungen und Abschiebungen möglich sind  DW Nachrichten.de.txt
# Base name for matching: faktencheck wie man desinformation im nahost-krieg erkennt  dw nachrichten
# No metadata found for: faktencheck wie man desinformation im nahost-krieg erkennt  dw nachrichten
# Extracted text saved to: data/de_DW\Faktencheck Wie man Desinformation im Nahost-Krieg erkennt  DW Nachrichten.de.txt
# Base name for matching: fdp-politiker semet iran will konflikt mit israel nicht eskalieren lassen  dw nachrichten
# No metadata found for: fdp-politiker semet iran will konflikt mit israel nicht eskalieren lassen  dw nachrichten
# Extracted text saved to: data/de_DW\FDP-Politiker Semet Iran will Konflikt mit Israel nicht eskalieren lassen  DW Nachrichten.de.txt
# Base name for matching: fortschritte bei verhandlungen über geiselbefreiung  dw nachrichten
# No metadata found for: fortschritte bei verhandlungen über geiselbefreiung  dw nachrichten
# Extracted text saved to: data/de_DW\Fortschritte bei Verhandlungen über Geiselbefreiung  DW Nachrichten.de.txt
# Base name for matching: gaza apelle für humanitäre hilfe, hamas lässt erste geiseln frei  dw nachrichten
# No metadata found for: gaza apelle für humanitäre hilfe, hamas lässt erste geiseln frei  dw nachrichten
# Extracted text saved to: data/de_DW\Gaza Apelle für humanitäre Hilfe, Hamas lässt erste Geiseln frei  DW Nachrichten.de.txt
# Base name for matching: gaza das israelische militär rückt weiter vor, warum kommt keine humanitäre pause  dw nachrichten
# No metadata found for: gaza das israelische militär rückt weiter vor, warum kommt keine humanitäre pause  dw nachrichten
# Extracted text saved to: data/de_DW\Gaza Das israelische Militär rückt weiter vor, warum kommt keine humanitäre Pause  DW Nachrichten.de.txt
# Base name for matching: gaza kaum informationen über entführte geiseln  dw nachrichten
# No metadata found for: gaza kaum informationen über entführte geiseln  dw nachrichten
# Extracted text saved to: data/de_DW\Gaza Kaum Informationen über entführte Geiseln  DW Nachrichten.de.txt
# Base name for matching: gaza krankenhäuser zwischen den fronten  dw nachrichten
# No metadata found for: gaza krankenhäuser zwischen den fronten  dw nachrichten
# Extracted text saved to: data/de_DW\Gaza Krankenhäuser zwischen den Fronten  DW Nachrichten.de.txt
# Base name for matching: gazastreifen fast eine halbe million menschen leiden unter hunger  dw nachrichten
# No metadata found for: gazastreifen fast eine halbe million menschen leiden unter hunger  dw nachrichten
# Extracted text saved to: data/de_DW\Gazastreifen Fast eine halbe Million Menschen leiden unter Hunger  DW Nachrichten.de.txt
# Base name for matching: geisel-vereinbarung warum katar ein wichtiger teil der verhandlungen war  dw nachrichten
# No metadata found for: geisel-vereinbarung warum katar ein wichtiger teil der verhandlungen war  dw nachrichten
# Extracted text saved to: data/de_DW\Geisel-Vereinbarung Warum Katar ein wichtiger Teil der Verhandlungen war  DW Nachrichten.de.txt
# Base name for matching: gewalt gegen palästinenser im westjordanland nimmt zu  dw nachrichten
# No metadata found for: gewalt gegen palästinenser im westjordanland nimmt zu  dw nachrichten
# Extracted text saved to: data/de_DW\Gewalt gegen Palästinenser im Westjordanland nimmt zu  DW Nachrichten.de.txt
# Base name for matching: haft­be­fehle gegen net­anyahu und hamas-führer bean­tragt  dw nachrichten
# No metadata found for: haft­be­fehle gegen net­anyahu und hamas-führer bean­tragt  dw nachrichten
# Extracted text saved to: data/de_DW\Haft­be­fehle gegen Net­anyahu und Hamas-Führer bean­tragt  DW Nachrichten.de.txt
# Base name for matching: hamas-terror gegen israel wie der konflikt die region weiter spaltet  auf den punkt
# No metadata found for: hamas-terror gegen israel wie der konflikt die region weiter spaltet  auf den punkt
# Extracted text saved to: data/de_DW\Hamas-Terror gegen Israel Wie der Konflikt die Region weiter spaltet  Auf den Punkt.de.txt
# Base name for matching: idf eine mögliche offensive im süden gazas steht bevor  dw nachrichten
# No metadata found for: idf eine mögliche offensive im süden gazas steht bevor  dw nachrichten
# Extracted text saved to: data/de_DW\IDF Eine mögliche Offensive im Süden Gazas steht bevor  DW Nachrichten.de.txt
# Base name for matching: igh beginnt anhörung zur besetzung der palästinensergebiete  dw nachrichten
# No metadata found for: igh beginnt anhörung zur besetzung der palästinensergebiete  dw nachrichten
# Extracted text saved to: data/de_DW\IGH beginnt Anhörung zur Besetzung der Palästinensergebiete  DW Nachrichten.de.txt
# Base name for matching: informationskrieg in gaza  dw nachrichten
# No metadata found for: informationskrieg in gaza  dw nachrichten
# Extracted text saved to: data/de_DW\Informationskrieg in Gaza  DW Nachrichten.de.txt
# Base name for matching: israel billigt deal zur geiselfreilassung  dw nachrichten
# No metadata found for: israel billigt deal zur geiselfreilassung  dw nachrichten
# Extracted text saved to: data/de_DW\Israel billigt Deal zur Geiselfreilassung  DW Nachrichten.de.txt
# Base name for matching: israel fordert menschen im gazastreifen zur flucht nach süd-gaza auf  dw nachrichten
# No metadata found for: israel fordert menschen im gazastreifen zur flucht nach süd-gaza auf  dw nachrichten
# Extracted text saved to: data/de_DW\Israel fordert Menschen im Gazastreifen zur Flucht nach Süd-Gaza auf  DW Nachrichten.de.txt
# Base name for matching: israel hat sich nach angaben der usa zu täglichen feuerpausen bereiterklärt  dw nachrichten
# No metadata found for: israel hat sich nach angaben der usa zu täglichen feuerpausen bereiterklärt  dw nachrichten
# Extracted text saved to: data/de_DW\Israel hat sich nach Angaben der USA zu täglichen Feuerpausen bereiterklärt  DW Nachrichten.de.txt
# Base name for matching: israel mobilisiert für potentielle bodenoffensive in gaza  dw nachrichten
# No metadata found for: israel mobilisiert für potentielle bodenoffensive in gaza  dw nachrichten
# Extracted text saved to: data/de_DW\Israel mobilisiert für potentielle Bodenoffensive in Gaza  DW Nachrichten.de.txt
# Base name for matching: israel unternimmt weiteren panzervorstoß nach gaza  dw nachrichten
# No metadata found for: israel unternimmt weiteren panzervorstoß nach gaza  dw nachrichten
# Extracted text saved to: data/de_DW\Israel unternimmt weiteren Panzervorstoß nach Gaza  DW Nachrichten.de.txt
# Base name for matching: israel vorbereitungen auf einsatz im gazastreifen laufen weiter  dw nachrichten
# No metadata found for: israel vorbereitungen auf einsatz im gazastreifen laufen weiter  dw nachrichten
# Extracted text saved to: data/de_DW\Israel Vorbereitungen auf Einsatz im Gazastreifen laufen weiter  DW Nachrichten.de.txt
# Base name for matching: israel will begrenzte hilfslieferungen in den gazastreifen zulassen  dw nachrichten
# No metadata found for: israel will begrenzte hilfslieferungen in den gazastreifen zulassen  dw nachrichten
# Extracted text saved to: data/de_DW\Israel will begrenzte Hilfslieferungen in den Gazastreifen zulassen  DW Nachrichten.de.txt
# Base name for matching: israeli ruft nach dem verlust seiner eltern durch hamas-anschlag zum frieden auf  dw #shorts
# No metadata found for: israeli ruft nach dem verlust seiner eltern durch hamas-anschlag zum frieden auf  dw #shorts
# Extracted text saved to: data/de_DW\Israeli ruft nach dem Verlust seiner Eltern durch Hamas-Anschlag zum Frieden auf  DW #Shorts.de.txt
# Base name for matching: israelische amee hamas-geiseln waren zeitweise in schifa-klinik  dw nachrichten
# No metadata found for: israelische amee hamas-geiseln waren zeitweise in schifa-klinik  dw nachrichten
# Extracted text saved to: data/de_DW\Israelische Amee Hamas-Geiseln waren zeitweise in Schifa-Klinik  DW Nachrichten.de.txt
# Base name for matching: israelische armee verstärkt offensive gegen hamas  dw nachrichten
# No metadata found for: israelische armee verstärkt offensive gegen hamas  dw nachrichten
# Extracted text saved to: data/de_DW\Israelische Armee verstärkt Offensive gegen Hamas  DW Nachrichten.de.txt
# Base name for matching: israelische militäroperation in gazas größtem krankenhaus  dw nachrichten
# No metadata found for: israelische militäroperation in gazas größtem krankenhaus  dw nachrichten
# Extracted text saved to: data/de_DW\Israelische Militäroperation in Gazas größtem Krankenhaus  DW Nachrichten.de.txt
# Base name for matching: israelische reservisten wollen nicht wieder in den krieg  dw nachrichten
# No metadata found for: israelische reservisten wollen nicht wieder in den krieg  dw nachrichten
# Extracted text saved to: data/de_DW\Israelische Reservisten wollen nicht wieder in den Krieg  DW Nachrichten.de.txt
# Base name for matching: kann der große krieg im nahen osten noch verhindert werden  dw nachrichten
# No metadata found for: kann der große krieg im nahen osten noch verhindert werden  dw nachrichten
# Extracted text saved to: data/de_DW\Kann der große Krieg im Nahen Osten noch verhindert werden  DW Nachrichten.de.txt
# Base name for matching: kann israel die terrororganisation hamas in gaza vollständig zerstören  dw nachrichten
# No metadata found for: kann israel die terrororganisation hamas in gaza vollständig zerstören  dw nachrichten
# Extracted text saved to: data/de_DW\Kann Israel die Terrororganisation Hamas in Gaza vollständig zerstören  DW Nachrichten.de.txt
# Base name for matching: krieg in nahost birgt gefahr eines flächenbrandes  dw nachrichten
# No metadata found for: krieg in nahost birgt gefahr eines flächenbrandes  dw nachrichten
# Extracted text saved to: data/de_DW\Krieg in Nahost birgt Gefahr eines Flächenbrandes  DW Nachrichten.de.txt
# Base name for matching: kritik am besuch des emirs scholz trifft sponsor der hamas  dw nachrichten
# No metadata found for: kritik am besuch des emirs scholz trifft sponsor der hamas  dw nachrichten
# Extracted text saved to: data/de_DW\Kritik am Besuch des Emirs Scholz trifft Sponsor der Hamas  DW Nachrichten.de.txt
# Base name for matching: können die 199 geiseln in den händen der hamas gerettet werden  dw nachrichten
# No metadata found for: können die 199 geiseln in den händen der hamas gerettet werden  dw nachrichten
# Extracted text saved to: data/de_DW\Können die 199 Geiseln in den Händen der Hamas gerettet werden  DW Nachrichten.de.txt
# Base name for matching: leben im luxus die hamas-führung in katar  dw nachrichten
# No metadata found for: leben im luxus die hamas-führung in katar  dw nachrichten
# Extracted text saved to: data/de_DW\Leben im Luxus Die Hamas-Führung in Katar  DW Nachrichten.de.txt
# Base name for matching: libanon wie geht es den menschen unter der hisbollah  dw deutsch
# No metadata found for: libanon wie geht es den menschen unter der hisbollah  dw deutsch
# Extracted text saved to: data/de_DW\Libanon Wie geht es den Menschen unter der Hisbollah  DW Deutsch.de.txt
# Base name for matching: mehr als 90 tote in gaza nach israelischem luftschlag  dw nachrichten
# No metadata found for: mehr als 90 tote in gaza nach israelischem luftschlag  dw nachrichten
# Extracted text saved to: data/de_DW\Mehr als 90 Tote in Gaza nach israelischem Luftschlag  DW Nachrichten.de.txt
# Base name for matching: mehr als eine million menschen im gazastreifen von hungersnot bedroht  dw nachrichten
# No metadata found for: mehr als eine million menschen im gazastreifen von hungersnot bedroht  dw nachrichten
# Extracted text saved to: data/de_DW\Mehr als eine Million Menschen im Gazastreifen von Hungersnot bedroht  DW Nachrichten.de.txt
# Base name for matching: nach der freilassung könnten weitere feuerpausen folgen  dw nachrichten
# No metadata found for: nach der freilassung könnten weitere feuerpausen folgen  dw nachrichten
# Extracted text saved to: data/de_DW\Nach der Freilassung Könnten weitere Feuerpausen folgen  DW Nachrichten.de.txt
# Base name for matching: nach israels luftschlag gegen ngo hilfslieferungen nach gaza vorerst gestoppt  dw nachrichten
# No metadata found for: nach israels luftschlag gegen ngo hilfslieferungen nach gaza vorerst gestoppt  dw nachrichten
# Extracted text saved to: data/de_DW\Nach Israels Luftschlag gegen NGO Hilfslieferungen nach Gaza vorerst gestoppt  DW Nachrichten.de.txt
# Base name for matching: nahost-konflikt auch thema beim seidenstraßen-gipfel in peking  dw nachrichten
# No metadata found for: nahost-konflikt auch thema beim seidenstraßen-gipfel in peking  dw nachrichten
# Extracted text saved to: data/de_DW\Nahost-Konflikt Auch Thema beim Seidenstraßen-Gipfel in Peking  DW Nachrichten.de.txt
# Base name for matching: nahost-konflikt biden wünscht sich pause  dw nachrichten
# No metadata found for: nahost-konflikt biden wünscht sich pause  dw nachrichten
# Extracted text saved to: data/de_DW\Nahost-Konflikt Biden wünscht sich Pause  DW Nachrichten.de.txt
# Base name for matching: nahost-konflikt ukraine fürchtet um militärhilfen  dw nachrichten
# No metadata found for: nahost-konflikt ukraine fürchtet um militärhilfen  dw nachrichten
# Extracted text saved to: data/de_DW\Nahost-Konflikt Ukraine fürchtet um Militärhilfen  DW Nachrichten.de.txt
# Base name for matching: palästinensische geflüchtete berichten über ihr leid  dw nachrichten
# No metadata found for: palästinensische geflüchtete berichten über ihr leid  dw nachrichten
# Extracted text saved to: data/de_DW\Palästinensische Geflüchtete berichten über ihr Leid  DW Nachrichten.de.txt
# Base name for matching: scharfe reaktionen auf iranischen drohnenangriff auf israel  dw nachrichten
# No metadata found for: scharfe reaktionen auf iranischen drohnenangriff auf israel  dw nachrichten
# Extracted text saved to: data/de_DW\Scharfe Reaktionen auf iranischen Drohnenangriff auf Israel  DW Nachrichten.de.txt
# Base name for matching: scholz besucht israel 10 tage nach terroranschlag  dw nachrichten
# No metadata found for: scholz besucht israel 10 tage nach terroranschlag  dw nachrichten
# Extracted text saved to: data/de_DW\Scholz besucht Israel 10 Tage nach Terroranschlag  DW Nachrichten.de.txt
# Base name for matching: sderot, grenzort zum gazastreifen, ist angeblich wieder sicher  dw nachrichten
# No metadata found for: sderot, grenzort zum gazastreifen, ist angeblich wieder sicher  dw nachrichten
# Extracted text saved to: data/de_DW\Sderot, Grenzort zum Gazastreifen, ist angeblich wieder sicher  DW Nachrichten.de.txt
# Base name for matching: studentenproteste wann wird aus pro-palästinensischem aktivismus antisemitismus  dw nachrichten
# No metadata found for: studentenproteste wann wird aus pro-palästinensischem aktivismus antisemitismus  dw nachrichten
# Extracted text saved to: data/de_DW\Studentenproteste Wann wird aus pro-palästinensischem Aktivismus Antisemitismus  DW Nachrichten.de.txt
# Base name for matching: tote journalisten nichtregierungs-organisationen schlagen alarm  dw nachrichten
# No metadata found for: tote journalisten nichtregierungs-organisationen schlagen alarm  dw nachrichten
# Extracted text saved to: data/de_DW\Tote Journalisten Nichtregierungs-Organisationen schlagen Alarm  DW Nachrichten.de.txt
# Base name for matching: türkischer präsident stellt vor berlin-reise israels existenzrecht in frage  dw nachrichten
# No metadata found for: türkischer präsident stellt vor berlin-reise israels existenzrecht in frage  dw nachrichten
# Extracted text saved to: data/de_DW\Türkischer Präsident stellt vor Berlin-Reise Israels Existenzrecht in Frage  DW Nachrichten.de.txt
# Base name for matching: us-außenminister blinken erneut in israel   dw nachrichten
# No metadata found for: us-außenminister blinken erneut in israel   dw nachrichten
# Extracted text saved to: data/de_DW\US-Außenminister Blinken erneut in Israel   DW Nachrichten.de.txt
# Base name for matching: usa pro-palästinensische proteste an unis weiten sich aus  dw nachrichten
# No metadata found for: usa pro-palästinensische proteste an unis weiten sich aus  dw nachrichten
# Extracted text saved to: data/de_DW\USA Pro-palästinensische Proteste an Unis weiten sich aus  DW Nachrichten.de.txt
# Base name for matching: verfassungsschutz viele radikale gruppen in deutschland pro-hamas  dw nachrichten
# No metadata found for: verfassungsschutz viele radikale gruppen in deutschland pro-hamas  dw nachrichten
# Extracted text saved to: data/de_DW\Verfassungsschutz Viele radikale Gruppen in Deutschland pro-Hamas  DW Nachrichten.de.txt
# Base name for matching: vergewaltigung, misshandlung, demütigung - sexualisierte gewalt in bewaffneten konflikten
# Metadata found for: vergewaltigung, misshandlung, demütigung - sexualisierte gewalt in bewaffneten konflikten
# Extracted text saved to: data/de_DW\Vergewaltigung, Misshandlung, Demütigung - Sexualisierte Gewalt in bewaffneten Konflikten.de.txt
# Base name for matching: versuchter brandanschlag auf jüdisches zentrum in berlin  dw nachrichten
# No metadata found for: versuchter brandanschlag auf jüdisches zentrum in berlin  dw nachrichten
# Extracted text saved to: data/de_DW\Versuchter Brandanschlag auf jüdisches Zentrum in Berlin  DW Nachrichten.de.txt
# Base name for matching: warum nimmt im westjordanland die gewalt zu  nachrichten
# No metadata found for: warum nimmt im westjordanland die gewalt zu  nachrichten
# Extracted text saved to: data/de_DW\Warum nimmt im Westjordanland die Gewalt zu  Nachrichten.de.txt
# Base name for matching: was führte zum ende des waffenstillstands zwischen israel und hamas  dw nachrichten
# No metadata found for: was führte zum ende des waffenstillstands zwischen israel und hamas  dw nachrichten
# Extracted text saved to: data/de_DW\Was führte zum Ende des Waffenstillstands zwischen Israel und Hamas  DW Nachrichten.de.txt
# Base name for matching: was passiert mit dem gazastreifen, wenn der krieg vorbei ist  dw nachrichten
# No metadata found for: was passiert mit dem gazastreifen, wenn der krieg vorbei ist  dw nachrichten
# Extracted text saved to: data/de_DW\Was passiert mit dem Gazastreifen, wenn der Krieg vorbei ist  DW Nachrichten.de.txt
# Base name for matching: was sagen die konfliktparteien zur verlängerung  dw nachrichten
# No metadata found for: was sagen die konfliktparteien zur verlängerung  dw nachrichten
# Extracted text saved to: data/de_DW\Was sagen die Konfliktparteien zur Verlängerung  DW Nachrichten.de.txt
# Base name for matching: welches ziel hat die hamas verfolgt mit dem terroranschlag auf israel  dw nachrichten
# No metadata found for: welches ziel hat die hamas verfolgt mit dem terroranschlag auf israel  dw nachrichten
# Extracted text saved to: data/de_DW\Welches Ziel hat die Hamas verfolgt mit dem Terroranschlag auf Israel  DW Nachrichten.de.txt
# Base name for matching: wenn humanitäre hilfe für gaza blockiert wird  dw nachrichten
# No metadata found for: wenn humanitäre hilfe für gaza blockiert wird  dw nachrichten
# Extracted text saved to: data/de_DW\Wenn humanitäre Hilfe für Gaza blockiert wird  DW Nachrichten.de.txt
# Base name for matching: wer deutscher werden will, soll sich zum existenzrecht israels bekennen  dw nachrichten
# No metadata found for: wer deutscher werden will, soll sich zum existenzrecht israels bekennen  dw nachrichten
# Extracted text saved to: data/de_DW\Wer Deutscher werden will, soll sich zum Existenzrecht Israels bekennen  DW Nachrichten.de.txt
# Base name for matching: wie der iran den nahen osten anzündet  dw nachrichten
# No metadata found for: wie der iran den nahen osten anzündet  dw nachrichten
# Extracted text saved to: data/de_DW\Wie der Iran den Nahen Osten anzündet  DW Nachrichten.de.txt
# Base name for matching: wie der nahost-konflikt das leben in deutschland spaltet  fokus europa
# No metadata found for: wie der nahost-konflikt das leben in deutschland spaltet  fokus europa
# Extracted text saved to: data/de_DW\Wie der Nahost-Konflikt das Leben in Deutschland spaltet  Fokus Europa.de.txt
# Base name for matching: wie die huthi-miliz im jemen preise in europa hochtreiben  dw nachrichten
# No metadata found for: wie die huthi-miliz im jemen preise in europa hochtreiben  dw nachrichten
# Extracted text saved to: data/de_DW\Wie die Huthi-Miliz im Jemen Preise in Europa hochtreiben  DW Nachrichten.de.txt
# Base name for matching: wie eine israelische frau das massaker der hamas überlebte  dw nachrichten
# No metadata found for: wie eine israelische frau das massaker der hamas überlebte  dw nachrichten
# Extracted text saved to: data/de_DW\Wie eine Israelische Frau das Massaker der Hamas überlebte  DW Nachrichten.de.txt
# Base name for matching: wie eine israelische mutter um die freilassung ihres verschleppten sohnes kämpft  dw nachrichten
# No metadata found for: wie eine israelische mutter um die freilassung ihres verschleppten sohnes kämpft  dw nachrichten
# Extracted text saved to: data/de_DW\Wie eine israelische Mutter um die Freilassung ihres verschleppten Sohnes kämpft  DW Nachrichten.de.txt
# Base name for matching: wie gut gerüstet sieht sich die nato in einer zeit der unsicherheit  dw nachrichten
# No metadata found for: wie gut gerüstet sieht sich die nato in einer zeit der unsicherheit  dw nachrichten
# Extracted text saved to: data/de_DW\Wie gut gerüstet sieht sich die NATO in einer Zeit der Unsicherheit  DW Nachrichten.de.txt
# Base name for matching: wie internationale kräfte an einer verlängerung des waffenstillstands arbeiten  dw nachrichten
# No metadata found for: wie internationale kräfte an einer verlängerung des waffenstillstands arbeiten  dw nachrichten
# Extracted text saved to: data/de_DW\Wie internationale Kräfte an einer Verlängerung des Waffenstillstands arbeiten  DW Nachrichten.de.txt
# Base name for matching: wie israel sich vor raketen aus iran und libanon schützt  dw nachrichten
# No metadata found for: wie israel sich vor raketen aus iran und libanon schützt  dw nachrichten
# Extracted text saved to: data/de_DW\Wie Israel sich vor Raketen aus Iran und Libanon schützt  DW Nachrichten.de.txt
# Base name for matching: wie juden aus israel nach ungarn fliehen  fokus europa
# No metadata found for: wie juden aus israel nach ungarn fliehen  fokus europa
# Extracted text saved to: data/de_DW\Wie Juden aus Israel nach Ungarn fliehen  Fokus Europa.de.txt
# Base name for matching: wie können menschen in deutschland den terror der hamas gutheißen  dw nachrichten
# No metadata found for: wie können menschen in deutschland den terror der hamas gutheißen  dw nachrichten
# Extracted text saved to: data/de_DW\Wie können Menschen in Deutschland den Terror der Hamas gutheißen  DW Nachrichten.de.txt
# Base name for matching: wo steht israel einen monat nach dem terror-angriff der hamas  dw nachrichten
# No metadata found for: wo steht israel einen monat nach dem terror-angriff der hamas  dw nachrichten
# Extracted text saved to: data/de_DW\Wo steht Israel einen Monat nach dem Terror-Angriff der Hamas  DW Nachrichten.de.txt
# Base name for matching: ägypten lässt erste verletzte uns ausländer aus dem gazastreifen einreisen  dw news
# No metadata found for: ägypten lässt erste verletzte uns ausländer aus dem gazastreifen einreisen  dw news
# Extracted text saved to: data/de_DW\Ägypten lässt erste Verletzte uns Ausländer aus dem Gazastreifen einreisen  DW News.de.txt
# Base name for matching: „vom fluss bis zum meer“ warum stellen bundesländer die parole unter strafe  dw nachrichten
# No metadata found for: „vom fluss bis zum meer“ warum stellen bundesländer die parole unter strafe  dw nachrichten
# Extracted text saved to: data/de_DW\„Vom Fluss bis zum Meer“ Warum stellen Bundesländer die Parole unter Strafe  DW Nachrichten.de.txt
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: de_ZDFheute
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# No matching metadata CSV for: en_DW
# ...
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
# No matching metadata CSV for: es_DW
