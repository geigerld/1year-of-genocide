# %%
import os
import re
import subprocess

def list_txt_files(directory):
    # Find all .txt files in the directory (non-recursively)
    txt_files = []
    for file in os.listdir(directory):
        file_path = os.path.join(directory, file)
        if os.path.isfile(file_path) and file.endswith('.txt'):
            txt_files.append(file_path)
    return txt_files
    
# Function to extract text between <doc> and </doc> tags
def extract_text_from_file(file_path, encoding='utf-8'):
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        # Use regular expressions to find the text between <doc> and </doc>
        #match = re.search(r'<doc>(.*?)</doc>', content, re.DOTALL)
        #if match:
        #    return match.group(1).strip()
        #else:
            return content
    except UnicodeDecodeError as e:
        print(f"Error reading file {file_path}: {e}")
        return None

# Function to write words to a new file with each word on a new line
def write_words_to_file(text, output_path, encoding='utf-8'):
    try:
        words = text.split()
        with open(output_path, 'w', encoding=encoding) as file:
            for word in words:
                file.write(word + '\n')
        print(f"Words have been successfully written to {output_path}")
    except UnicodeEncodeError as e:
        print(f"Error writing file {output_path}: {e}")

# Function to execute TreeTagger and process the output
def run_treetagger(input_path, output_path):
    treetagger_path = 'tree-tagger-windows-3.2.3a/TreeTagger/bin/tree-tagger.exe'  # Replace with the path to your TreeTagger executable
    parameter_path = 'tree-tagger-windows-3.2.3a/TreeTagger/lib/english.par'  # Replace with the path to your TreeTagger parameter file
    cmd = [treetagger_path, parameter_path, '-token', '-lemma', '-no-unknown', input_path]
    
    try:
        # Run TreeTagger and capture the output
        result = subprocess.run(cmd, capture_output=True, text=True, encoding='utf-8')
        
        if result.returncode == 0:
            if result.stdout:  # Check if stdout is not None
                with open(output_path, 'w', encoding='utf-8') as file:
                    file.write(result.stdout)
                print(f"TreeTagger output has been written to {output_path}")
            else:
                print(f"No output from TreeTagger for file: {input_path}")
        else:
            print(f"Error running TreeTagger: {result.stderr}")
    
    except Exception as e:
        print(f"An exception occurred: {e}")

def process_files(directory):
    # Find all .txt files
    txt_files = list_txt_files(directory)
    
    for txt_file in txt_files:
        # Define file paths
        base_dir = os.path.dirname(txt_file)
        base_name = os.path.splitext(os.path.basename(txt_file))[0]
        temp_text_file_path = os.path.join(base_dir, f'{base_name}_words.txt')
        treetagger_output_dir = os.path.join(base_dir, 'treetagger_output')
        treetagger_output_path = os.path.join(treetagger_output_dir, f'{base_name}_treetagger_output.txt')

        # Create output directory if it doesn't exist
        if not os.path.exists(treetagger_output_dir):
            os.makedirs(treetagger_output_dir)
        
        # Extract text and write to new file
        text = extract_text_from_file(txt_file)
        if text:
            write_words_to_file(text, temp_text_file_path)
            print(f"Words have been written to {temp_text_file_path}")

            # Run TreeTagger
            run_treetagger(temp_text_file_path, treetagger_output_path)

            # Clean up temporary file
            os.remove(temp_text_file_path)
        else:
            print(f"No text found in <doc> tags for file: {txt_file}")


# Example usage
directory_path = 'data/en_DW/'  # Root directory containing subfolders with .txt files
process_files(directory_path)
# Out:
# Words have been successfully written to data/en_DW\'Chaos' & 'despair' at Gaza hospital after Israeli strike on 'safe zone' - UN eyewitness  DW News.en_words.txt
# Words have been written to data/en_DW\'Chaos' & 'despair' at Gaza hospital after Israeli strike on 'safe zone' - UN eyewitness  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\'Chaos' & 'despair' at Gaza hospital after Israeli strike on 'safe zone' - UN eyewitness  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\'It is time for this war to end' Kamala Harris speaks after meeting Israeli PM Netanyahu  DW News.en_words.txt
# Words have been written to data/en_DW\'It is time for this war to end' Kamala Harris speaks after meeting Israeli PM Netanyahu  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\
DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Aid groups accuse Israel of targeting Gaza's water and sanitation services  DW News.en_words.txt
# Words have been written to data/en_DW\Aid groups accuse Israel of targeting Gaza's water and sanitation services  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Aid groups accuse Israel of targeting Gaza's water and sanitation services  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Aid organizations warn that the current heatwave deepens humanitarian crisis in Gaza  DW News.en_words.txt
# Words have been written to data/en_DW\Aid organizations warn that the current heatwave deepens humanitarian crisis in Gaza  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Aid organizations warn that the current heatwave deepens humanitarian crisis in Gaza  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Airlines suspend flights to Lebanon, Iran, and Israel over fears of intensifying regional conflict.en_words.txt
# Words have been written to data/en_DW\Airlines suspend flights to Lebanon, Iran, and Israel over fears of intensifying regional conflict.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Airlines suspend flights to Lebanon, Iran, and Israel over fears of intensifying regional conflict.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Al-Shifa hospital in Gaza raided while families of Hamas hostages march  DW News.en_words.txt
# Words have been written to data/en_DW\Al-Shifa hospital in Gaza raided while families of Hamas hostages march  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Al-Shifa hospital in Gaza raided while families of Hamas hostages march  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\All you need to know about the killing of Hamas political leader Haniyeh  DW News.en_words.txt
# Words have been written to data/en_DW\All you need to know about the killing of Hamas political leader Haniyeh  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\All you need to know about the killing of Hamas political leader Haniyeh  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Amid fears of Israeli offensive, parents struggle to provide for their children in Rafah  DW News.en_words.txt
# Words have been written to data/en_DW\Amid fears of Israeli offensive, parents struggle to provide for their children in Rafah  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Amid fears of Israeli offensive, parents struggle to provide for their children in Rafah  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\An Israeli and a Palestinian state Will the two sides listen to the EU  DW News.en_words.txt
# Words have been written to data/en_DW\An Israeli and a Palestinian state Will the two sides listen to the EU  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\An Israeli and a Palestinian state Will the two sides listen to the EU  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Another strike reported at Jabaliya refugee camp in Gaza  DW News.en_words.txt
# Words have been written to data/en_DW\Another strike reported at Jabaliya refugee camp in Gaza  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Another strike reported at Jabaliya refugee camp in Gaza  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Anti-war protesters interrupt Biden's campaign speech  DW News.en_words.txt
# Words have been written to data/en_DW\Anti-war protesters interrupt Biden's campaign speech  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Anti-war protesters interrupt Biden's campaign speech  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Antony Blinken visits Israel, reiterates US support I DW News.en_words.txt
# Words have been written to data/en_DW\Antony Blinken visits Israel, reiterates US support I DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Antony Blinken visits Israel, reiterates US support I DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Appeal to avoid an escalation of the conflict  DW News.en_words.txt
# Words have been written to data/en_DW\Appeal to avoid an escalation of the conflict  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Appeal to avoid an escalation of the conflict  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Are Israel and Lebanon inching closer to a full-scale war  DW News.en_words.txt
# Words have been written to data/en_DW\Are Israel and Lebanon inching closer to a full-scale war  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Are Israel and Lebanon inching closer to a full-scale war  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Are we already in the midst of a regional war in the Middle East.en_words.txt
# Words have been written to data/en_DW\Are we already in the midst of a regional war in the Middle East.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Are we already in the midst of a regional war in the Middle East.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Are we getting an accurate picture of what is happening in Gaza  DW News.en_words.txt
# Words have been written to data/en_DW\Are we getting an accurate picture of what is happening in Gaza  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Are we getting an accurate picture of what is happening in Gaza  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Army chief Iran's missile attack on Israel's territory will be met with a response  DW News.en_words.txt
# Words have been written to data/en_DW\Army chief Iran's missile attack on Israel's territory will be met with a response  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Army chief Iran's missile attack on Israel's territory will be met with a response  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Assessing the war's impact on the Israeli economy  DW Business.en_words.txt
# Words have been written to data/en_DW\Assessing the war's impact on the Israeli economy  DW Business.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Assessing the war's impact on the Israeli economy  DW Business.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\At least 1 dead after ramming, stabbing incident near Tel Aviv  DW News.en_words.txt
# Words have been written to data/en_DW\At least 1 dead after ramming, stabbing incident near Tel Aviv  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output
DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Can Israel stand alone without weapons deliveries from the US  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Can social media shape the course of the Israel-Hamas conflict  DW News.en_words.txt
# Words have been written to data/en_DW\Can social media shape the course of the Israel-Hamas conflict  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Can social media shape the course of the Israel-Hamas conflict  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Can the EU help hostages in Gaza  DW News.en_words.txt
# Words have been written to data/en_DW\Can the EU help hostages in Gaza  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Can the EU help hostages in Gaza  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Can the Gaza cease-fire talks be salvaged  DW News.en_words.txt
# Words have been written to data/en_DW\Can the Gaza cease-fire talks be salvaged  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Can the Gaza cease-fire talks be salvaged  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Can the ICJ stop Israel's blockade of food deliveries into Gaza  DW News.en_words.txt
# Words have been written to data/en_DW\Can the ICJ stop Israel's blockade of food deliveries into Gaza  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Can the ICJ stop Israel's blockade of food deliveries into Gaza  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Can the International Court of Justice stop the war in Gaza  DW Analysis.en_words.txt
# Words have been written to data/en_DW\Can the International Court of Justice stop the war in Gaza  DW Analysis.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Can the International Court of Justice stop the war in Gaza  DW Analysis.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Cease-fire negotiations resume for Israel-Hamas war  DW News.en_words.txt
# Words have been written to data/en_DW\Cease-fire negotiations resume for Israel-Hamas war  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Cease-fire negotiations resume for Israel-Hamas war  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Cease-fire talks continue amid warnings on internally displaced Palestinians  DW News.en_words.txt
# Words have been written to data/en_DW\Cease-fire talks continue amid warnings on internally displaced Palestinians  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Cease-fire talks continue amid warnings on internally displaced Palestinians  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Challenges facing Palestinian men seeking asylum in Europe as they flee the war in Gaza   DW News.en_words.txt
# Words have been written to data/en_DW\Challenges facing Palestinian men seeking asylum in Europe as they flee the war in Gaza   DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Challenges facing Palestinian men seeking asylum in Europe as they flee the war in Gaza   DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Chaos in the Israeli parliament  DW News.en_words.txt
# Words have been written to data/en_DW\Chaos in the Israeli parliament  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Chaos in the Israeli parliament  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Civilian casualties prompt protests as Israel continues to pound Gaza  DW News.en_words.txt
# Words have been written to data/en_DW\Civilian casualties prompt protests as Israel continues to pound Gaza  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Civilian casualties prompt protests as Israel continues to pound Gaza  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Civilians killed and abducted How are Israelis dealing with the horror  DW News.en_words.txt
# Words have been written to data/en_DW\Civilians killed and abducted How are Israelis dealing with the horror  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Civilians killed and abducted How are Israelis dealing with the horror  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Concern mounts for civilians as Israel orders Rafah evacuation  DW News.en_words.txt
# Words have been written to data/en_DW\Concern mounts for civilians as Israel orders Rafah evacuation  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Concern mounts for civilians as Israel orders Rafah evacuation  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Concerns grow over possible Iranian attack on Israel  DW News.en_words.txt
# Words have been written to data/en_DW\Concerns grow over possible Iranian attack on Israel  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Concerns grow over possible Iranian attack on Israel  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Conflicting reports about what happened in Gaza – what we do and don't know  DW News.en_words.txt
# Words have been written to data/en_DW\Conflicting reports about what happened in Gaza – what we do and don't know  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Conflicting reports about what happened in Gaza – what we do and don't know  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Could Blinken broker a humanitarian pause in Gaza  DW News.en_words.txt
# Words have been written to data/en_DW\Could Blinken broker a humanitarian pause in Gaza  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Could Blinken broker a humanitarian pause in Gaza  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Could further European countries recognize Palestinian statehood  DW News.en_words.txt
# Words have been written to data/en_DW\Could further European countries recognize Palestinian statehood  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Could further European countries recognize Palestinian statehood  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Could Hezbollah drag Lebanon into a war with Israel  DW News.en_words.txt
# Words have been written to data/en_DW\Could Hezbollah drag Lebanon into a war with Israel  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Could Hezbollah drag Lebanon into a war with Israel  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Could Israel's large-scale West Bank operation backfire   DW News.en_words.txt
# Words have been written to data/en_DW\Could Israel's large-scale West Bank operation backfire   DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Could Israel's large-scale West Bank operation backfire   DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\
en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Egyptian media Cease-fire talks to resume in Cairo  DW News.en_words.txt
# Words have been written to data/en_DW\Egyptian media Cease-fire talks to resume in Cairo  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Egyptian media Cease-fire talks to resume in Cairo  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Erez border crossing opens, allowing more humanitarian aid in  DW News.en_words.txt
# Words have been written to data/en_DW\Erez border crossing opens, allowing more humanitarian aid in  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Erez border crossing opens, allowing more humanitarian aid in  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Escalating attacks on Israel by Hezbollah  DW News.en_words.txt
# Words have been written to data/en_DW\Escalating attacks on Israel by Hezbollah  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Escalating attacks on Israel by Hezbollah  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\EU leaders divided on ICC arrest warrant bid for Netanyahu  DW News.en_words.txt
# Words have been written to data/en_DW\EU leaders divided on ICC arrest warrant bid for Netanyahu  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\EU leaders divided on ICC arrest warrant bid for Netanyahu  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\EU leaders issue first unified call on immediate humanitarian pause in Gaza  DW News.en_words.txt
# Words have been written to data/en_DW\EU leaders issue first unified call on immediate humanitarian pause in Gaza  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\EU leaders issue first unified call on immediate humanitarian pause in Gaza  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\EU leaders meeting in Brussels called for a humanitarian 'pauses' in Gaza  DW News.en_words.txt
# Words have been written to data/en_DW\EU leaders meeting in Brussels called for a humanitarian 'pauses' in Gaza  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\EU leaders meeting in Brussels called for a humanitarian 'pauses' in Gaza  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\EU ministers meet with Israeli and Palestinian counterparts  DW News.en_words.txt
# Words have been written to data/en_DW\EU ministers meet with Israeli and Palestinian counterparts  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\EU ministers meet with Israeli and Palestinian counterparts  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\EU Socialists deputy leader – Israeli pauses in Gaza not enough  DW News.en_words.txt
# Words have been written to data/en_DW\EU Socialists deputy leader – Israeli pauses in Gaza not enough  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\EU Socialists deputy leader – Israeli pauses in Gaza not enough  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\EU's Borrell warns of greater humanitarian catastrophe  DW News.en_words.txt
# Words have been written to data/en_DW\EU's Borrell warns of greater humanitarian catastrophe  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\EU's Borrell warns of greater humanitarian catastrophe  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\European Union calls for permanent cease-fire in Gaza  DW News.en_words.txt
# Words have been written to data/en_DW\European Union calls for permanent cease-fire in Gaza  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\European Union calls for permanent cease-fire in Gaza  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Eurovision Thousands of pro-Palestinian demonstrators march through Malmö  DW News.en_words.txt
# Words have been written to data/en_DW\Eurovision Thousands of pro-Palestinian demonstrators march through Malmö  DW News.en_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Eurovision Thousands of pro-Palestinian demonstrators march through Malmö  DW News.en_treetagger_output.txt
# Words have been successfully written to data/en_DW\Ex-General Hodges Russia working with Iran over Middle East conflict  DW News.ar_words.txt
# Words have been written to data/en_DW\Ex-General Hodges Russia working with Iran over Middle East conflict  DW News.ar_words.txt
# Exception in thread Thread-1376 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Program Files\Python312\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Lorenz\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python312\Lib\threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Program Files\Python312\Lib\subprocess.py", line 1597, in _readerthread
#     buffer.append(fh.read())
#                   ^^^^^^^^^
#   File "C:\Program Files\Python312\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1686: character maps to <undefined>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 89
#      87 # Example usage
#      88 directory_path = 'data/en_DW/'  # Root directory containing subfolders with .txt files
# ---> 89 process_files(directory_path)
#
# Cell In[14], line 79, in process_files(directory)
#      76 print(f"Words have been written to {temp_text_file_path}")
#      78 # Run TreeTagger
# ---> 79 run_treetagger(temp_text_file_path, treetagger_output_path)
#      81 # Clean up temporary file
#      82 os.remove(temp_text_file_path)
#
# Cell In[14], line 51, in run_treetagger(input_path, output_path)
#      49 if result.returncode == 0:
#      50     with open(output_path, 'w') as file:
# ---> 51         file.write(result.stdout)
#      52     print(f"TreeTagger output has been written to {output_path}")
#      53 else:
#
# TypeError: write() argument must be str, not None
