# %%
import os
import re
import subprocess

def list_txt_files(directory):
    # Find all .txt files in the directory (non-recursively)
    txt_files = []
    for file in os.listdir(directory):
        file_path = os.path.join(directory, file)
        if os.path.isfile(file_path) and file.endswith('.txt'):
            txt_files.append(file_path)
    return txt_files
    
# Function to extract text between <doc> and </doc> tags
def extract_text_from_file(file_path, encoding='utf-8'):
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        # Use regular expressions to find the text between <doc> and </doc>
        #match = re.search(r'<doc>(.*?)</doc>', content, re.DOTALL)
        #if match:
        #    return match.group(1).strip()
        #else:
            return content
    except UnicodeDecodeError as e:
        print(f"Error reading file {file_path}: {e}")
        return None

# Function to write words to a new file with each word on a new line
def write_words_to_file(text, output_path, encoding='utf-8'):
    try:
        words = text.split()
        with open(output_path, 'w', encoding=encoding) as file:
            for word in words:
                file.write(word + '\n')
        print(f"Words have been successfully written to {output_path}")
    except UnicodeEncodeError as e:
        print(f"Error writing file {output_path}: {e}")

# Function to execute TreeTagger and process the output
def run_treetagger(input_path, output_path):
    treetagger_path = 'tree-tagger-windows-3.2.3a/TreeTagger/bin/tree-tagger.exe'  # Replace with the path to your TreeTagger executable
    parameter_path = 'tree-tagger-windows-3.2.3a/TreeTagger/lib/english.par'  # Replace with the path to your TreeTagger parameter file
    cmd = [treetagger_path, parameter_path, '-token', '-lemma', '-no-unknown', input_path]
    
    try:
        # Run TreeTagger and capture the output
        result = subprocess.run(cmd, capture_output=True, text=True, encoding='utf-8')
        
        if result.returncode == 0:
            if result.stdout:  # Check if stdout is not None
                with open(output_path, 'w', encoding='utf-8') as file:
                    file.write(result.stdout)
                print(f"TreeTagger output has been written to {output_path}")
            else:
                print(f"No output from TreeTagger for file: {input_path}")
        else:
            print(f"Error running TreeTagger: {result.stderr}")
    
    except Exception as e:
        print(f"An exception occurred: {e}")

def process_files(directory):
    # Find all .txt files
    txt_files = list_txt_files(directory)
    for txt_file in txt_files:
        # Ensure the directory for TreeTagger output exists
        treetagger_output_dir = os.path.join(os.path.dirname(txt_file), 'treetagger_output')
        os.makedirs(treetagger_output_dir, exist_ok=True)
        
        # Define paths
        temp_text_file_path = os.path.join(treetagger_output_dir, os.path.basename(txt_file).replace('.txt', '_words.txt'))
        treetagger_output_path = os.path.join(treetagger_output_dir, os.path.basename(txt_file).replace('.txt', '_treetagger_output.txt'))

        # Extract text and write to new file
        text = extract_text_from_file(txt_file)
        if text:
            write_words_to_file(text, temp_text_file_path)
            print(f"Words have been written to {temp_text_file_path}")

            # Run TreeTagger
            run_treetagger(temp_text_file_path, treetagger_output_path)

            # Clean up temporary file
            os.remove(temp_text_file_path)
        else:
            print(f"No text found in <doc> tags for file: {txt_file}")


# Example usage
directory_path = 'data/en_BBCNews/'  # Root directory containing subfolders with .txt files
process_files(directory_path)
# Out:
# Words have been successfully written to data/en_BBCNews\treetagger_output\'gaza children killed as they slept' in un-run school - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\'gaza children killed as they slept' in un-run school - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\'gaza children killed as they slept' in un-run school - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\'hamas has destroyed the chance of humanitarian aid for gaza' says mark regev - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\'hamas has destroyed the chance of humanitarian aid for gaza' says mark regev - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\'hamas has destroyed the chance of humanitarian aid for gaza' says mark regev - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\'hamas wants to destroy israel' says mayor of jerusalem nir barkat - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\'hamas wants to destroy israel' says mayor of jerusalem nir barkat - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\'hamas wants to destroy israel' says mayor of jerusalem nir barkat - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\'how many israelis need to die to gain your sympathy' asks naftali bennett - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\'how many israelis need to die to gain your sympathy' asks naftali bennett - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\'how many israelis need to die to gain your sympathy' asks naftali bennett - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\'israel has found rockets in un school' says tzipi hotolevy - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\'israel has found rockets in un school' says tzipi hotolevy - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\'israel has found rockets in un school' says tzipi hotolevy - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\'miracle' survivor of gaza blast dies in hospital - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\'miracle' survivor of gaza blast dies in hospital - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\'miracle' survivor of gaza blast dies in hospital - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\'this is our 911' says israel, as israel-gaza fighting continues - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\'this is our 911' says israel, as israel-gaza fighting continues - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\'this is our 911' says israel, as israel-gaza fighting continues - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\'we haven't got any rockets in west bank yet israel kills everyday' - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\'we haven't got any rockets in west bank yet israel kills everyday' - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\'we haven't got any rockets in west bank yet israel kills everyday' - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\'we're hosting over 220,000 internally displaced people in gaza' unrwa - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\'we're hosting over 220,000 internally displaced people in gaza' unrwa - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\'we're hosting over 220,000 internally displaced people in gaza' unrwa - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\1,400 dead in gaza airstrikes the humanitarian crisis - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\1,400 dead in gaza airstrikes the humanitarian crisis - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\1,400 dead in gaza airstrikes the humanitarian crisis - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\7 members of hamas leader’s family killed in israeli airstrike - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\7 members of hamas leader’s family killed in israeli airstrike - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\7 members of hamas leader’s family killed in israeli airstrike - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\700 dead in israel as it “declares war” on hamas - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\700 dead in israel as it “declares war” on hamas - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\700 dead in israel as it “declares war” on hamas - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\8-year-old shot dead by israeli forces in west bank  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\8-year-old shot dead by israeli forces in west bank  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\8-year-old shot dead by israeli forces in west bank  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\airstrike hits area of rafah crossing at gaza-egypt border - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\airstrike hits area of rafah crossing at gaza-egypt border - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\airstrike hits area of rafah crossing at gaza-egypt border - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\al jazeera office in israel raided and channel taken off air in country  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\al jazeera office in israel raided and channel taken off air in country  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\al jazeera office in israel raided and channel taken off air in country  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\anthony blinken pushes us israel-gaza ceasefire plan in middle east  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\anthony blinken pushes us israel-gaza ceasefire plan in middle east  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\anthony blinken pushes us israel-gaza ceasefire plan in middle east  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\are  israel and hezbollah edging closer to all-out war  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\are  israel and hezbollah edging closer to all-out war  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\are  israel and hezbollah edging closer to all-out war  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\are israeli air strike warnings effective - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\are israeli air strike warnings effective - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\are israeli air strike warnings effective - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\at least 10 dead in huge israeli military operation in west bank  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\at least 10 dead in huge israeli military operation in west bank  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\at least 10 dead in huge israeli military operation in west bank  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\at least 19 killed in israeli strike on gaza ‘safe zone’ for displaced people  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\at least 19 killed in israeli strike on gaza ‘safe zone’ for displaced people  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\at least 19 killed in israeli strike on gaza ‘safe zone’ for displaced people  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\at least 29 palestinians killed in airstrike on camp for displaced people  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\at least 29 palestinians killed in airstrike on camp for displaced people  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\at least 29 palestinians killed in airstrike on camp for displaced people  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\baby contracts gaza's first case of polio in 25 years  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\baby contracts gaza's first case of polio in 25 years  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\baby contracts gaza's first case of polio in 25 years  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\baby saved from dead mother's womb in gaza dies  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\baby saved from dead mother's womb in gaza dies  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\baby saved from dead mother's womb in gaza dies  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\bbc exclusive  us doctor’s shocking video from frontline hospital in gaza  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\bbc exclusive  us doctor’s shocking video from frontline hospital in gaza  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\bbc exclusive  us doctor’s shocking video from frontline hospital in gaza  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\bbc follows red crescent paramedics during first month of israel-gaza war  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\bbc follows red crescent paramedics during first month of israel-gaza war  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\bbc follows red crescent paramedics during first month of israel-gaza war  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\bbc goes inside al-shifa hospital with the israeli army -bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\bbc goes inside al-shifa hospital with the israeli army -bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\bbc goes inside al-shifa hospital with the israeli army -bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\bbc investigation israeli troops accused of beating and humiliating gaza hospital staff  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\bbc investigation israeli troops accused of beating and humiliating gaza hospital staff  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\bbc investigation israeli troops accused of beating and humiliating gaza hospital staff  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\bbc investigation suggests dozens of civilians killed during israeli hostage rescue   bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\bbc investigation suggests dozens of civilians killed during israeli hostage rescue   bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\bbc investigation suggests dozens of civilians killed during israeli hostage rescue   bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\bbc reporter reveals emotional toll of covering war in gaza  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\bbc reporter reveals emotional toll of covering war in gaza  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\bbc reporter reveals emotional toll of covering war in gaza  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\bbc verify looks at how rafah became home to 1_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\bbc verify looks at how rafah became home to 1_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\bbc verify looks at how rafah became home to 1_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\benjamin netanyahu defends gaza war as protesters rally outside us congress  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\benjamin netanyahu defends gaza war as protesters rally outside us congress  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\benjamin netanyahu defends gaza war as protesters rally outside us congress  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\biden seeks war aid for israel and ukraine from congress - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\biden seeks war aid for israel and ukraine from congress - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\biden seeks war aid for israel and ukraine from congress - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\biden warns israel against rafah assault without protecting civilians  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\biden warns israel against rafah assault without protecting civilians  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\biden warns israel against rafah assault without protecting civilians  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\biden warns israel gaza hospital must be protected” - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\biden warns israel gaza hospital must be protected” - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\biden warns israel gaza hospital must be protected” - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\biggest coalition aid airdrop into gaza marks end of ramadan  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\biggest coalition aid airdrop into gaza marks end of ramadan  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\biggest coalition aid airdrop into gaza marks end of ramadan  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\breaking iran launches “mass drone and missile attack” on israel  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\breaking iran launches “mass drone and missile attack” on israel  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\breaking iran launches “mass drone and missile attack” on israel  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\breaking israel may have used us-supplied weapons in breach of international law in gaza  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\breaking israel may have used us-supplied weapons in breach of international law in gaza  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\breaking israel may have used us-supplied weapons in breach of international law in gaza  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\british teen missing in hamas attack confirmed dead - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\british teen missing in hamas attack confirmed dead - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\british teen missing in hamas attack confirmed dead - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\british teenage sisters missing after hamas attacks - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\british teenage sisters missing after hamas attacks - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\british teenage sisters missing after hamas attacks - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\cancer patients stopped from leaving gaza for treatment  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\cancer patients stopped from leaving gaza for treatment  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\cancer patients stopped from leaving gaza for treatment  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\charity suspends gaza aid work after staff killed in israeli strike  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\charity suspends gaza aid work after staff killed in israeli strike  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\charity suspends gaza aid work after staff killed in israeli strike  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\china asks iran to rein in houthi attacks in red sea, according to iranian officials  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\china asks iran to rein in houthi attacks in red sea, according to iranian officials  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\china asks iran to rein in houthi attacks in red sea, according to iranian officials  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\clashes in jerusalem hours after israel-palestinian ceasefire - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\clashes in jerusalem hours after israel-palestinian ceasefire - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\clashes in jerusalem hours after israel-palestinian ceasefire - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\commercial ships avoiding red sea over attack fears  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\commercial ships avoiding red sea over attack fears  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\commercial ships avoiding red sea over attack fears  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\death of us-turkish citizen in west bank should be 'fully investigated', says un  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\death of us-turkish citizen in west bank should be 'fully investigated', says un  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\death of us-turkish citizen in west bank should be 'fully investigated', says un  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\debate verdict  defensive trump rattled by confident harris  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\debate verdict  defensive trump rattled by confident harris  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\debate verdict  defensive trump rattled by confident harris  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\devastation after air strike on khan younis, gaza - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\devastation after air strike on khan younis, gaza - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\devastation after air strike on khan younis, gaza - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\doctor’s video diary shows reality inside gaza hospital  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\doctor’s video diary shows reality inside gaza hospital  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\doctor’s video diary shows reality inside gaza hospital  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\dozens reported killed in gaza as blinken urges protection for civilians  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\dozens reported killed in gaza as blinken urges protection for civilians  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\dozens reported killed in gaza as blinken urges protection for civilians  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\dozens reported killed in gaza refugee camp blast  – bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\dozens reported killed in gaza refugee camp blast  – bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\dozens reported killed in gaza refugee camp blast  – bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\dozens reported killed in israeli strike on gaza school building  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\dozens reported killed in israeli strike on gaza school building  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\dozens reported killed in israeli strike on gaza school building  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\dozens reported killed in israeli strike on rafah  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\dozens reported killed in israeli strike on rafah  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\dozens reported killed in israeli strike on rafah  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\elon musk’s ai chatbot generated disinformation about iran-israel on x  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\elon musk’s ai chatbot generated disinformation about iran-israel on x  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\elon musk’s ai chatbot generated disinformation about iran-israel on x  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\escape from gaza tala and yazid reach safety in egypt  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\escape from gaza tala and yazid reach safety in egypt  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\escape from gaza tala and yazid reach safety in egypt  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\evidence that israel is using starvation as weapon of war in gaza says un   bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\evidence that israel is using starvation as weapon of war in gaza says un   bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\evidence that israel is using starvation as weapon of war in gaza says un   bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\exit of foreign nationals from gaza temporarily stopped – bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\exit of foreign nationals from gaza temporarily stopped – bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\exit of foreign nationals from gaza temporarily stopped – bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\explosion hits beirut suburb as israel says it has 'targeted' hezbollah commander  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\explosion hits beirut suburb as israel says it has 'targeted' hezbollah commander  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\explosion hits beirut suburb as israel says it has 'targeted' hezbollah commander  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\explosion in gaza stops bbc journalist live on air_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\explosion in gaza stops bbc journalist live on air_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\explosion in gaza stops bbc journalist live on air_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\families of israeli hostages face unbearable trauma  - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\families of israeli hostages face unbearable trauma  - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\families of israeli hostages face unbearable trauma  - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\families of israeli hostages storm knesset parliament meeting  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\families of israeli hostages storm knesset parliament meeting  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\families of israeli hostages storm knesset parliament meeting  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\families on the run in gaza - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\families on the run in gaza - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\families on the run in gaza - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\father trapped in gaza’s jabalia refugee camp records video diaries - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\father trapped in gaza’s jabalia refugee camp records video diaries - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\father trapped in gaza’s jabalia refugee camp records video diaries - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\fear of war between israel and hezbollah after fatal golan heights air strike  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\fear of war between israel and hezbollah after fatal golan heights air strike  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\fear of war between israel and hezbollah after fatal golan heights air strike  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\fears grow of wider war as israel sends more troops to lebanon border  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\fears grow of wider war as israel sends more troops to lebanon border  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\fears grow of wider war as israel sends more troops to lebanon border  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\fighting between israel and palestinian militants continues – bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\fighting between israel and palestinian militants continues – bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\fighting between israel and palestinian militants continues – bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\first british nationals cross from gaza into egypt, uk foreign office says - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\first british nationals cross from gaza into egypt, uk foreign office says - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\first british nationals cross from gaza into egypt, uk foreign office says - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\fleeing north gaza ‘it was a journey through hell’  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\fleeing north gaza ‘it was a journey through hell’  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\fleeing north gaza ‘it was a journey through hell’  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\french president macron calls on israel to stop killing gaza's women and babies – bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\french president macron calls on israel to stop killing gaza's women and babies – bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\french president macron calls on israel to stop killing gaza's women and babies – bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\french president macron visits israel in solidarity visit – bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\french president macron visits israel in solidarity visit – bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\french president macron visits israel in solidarity visit – bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\frontline report  israel kills senior hamas commander in west bank  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\frontline report  israel kills senior hamas commander in west bank  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\frontline report  israel kills senior hamas commander in west bank  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\frontline report us drone strike in baghdad kills iran-backed militia leader  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\frontline report us drone strike in baghdad kills iran-backed militia leader  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\frontline report us drone strike in baghdad kills iran-backed militia leader  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza aid ship expected to set sail from cyprus  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza aid ship expected to set sail from cyprus  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza aid ship expected to set sail from cyprus  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza aid twenty trucks expected to enter through egypt border crossing - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza aid twenty trucks expected to enter through egypt border crossing - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza aid twenty trucks expected to enter through egypt border crossing - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza baby delivered from dead mother - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza baby delivered from dead mother - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza baby delivered from dead mother - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza bombing “end this god-awful nightmare” says united nations - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza bombing “end this god-awful nightmare” says united nations - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza bombing “end this god-awful nightmare” says united nations - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza ceasefire deal in balance as israel “demands list of hostages” bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza ceasefire deal in balance as israel “demands list of hostages” bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza ceasefire deal in balance as israel “demands list of hostages” bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza ceasefire talks in doubt after hamas leader killed in iran  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza ceasefire talks in doubt after hamas leader killed in iran  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza ceasefire talks in doubt after hamas leader killed in iran  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza ceasefire talks might be ‘last chance’ to free hostages, says blinken  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza ceasefire talks might be ‘last chance’ to free hostages, says blinken  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza ceasefire talks might be ‘last chance’ to free hostages, says blinken  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza ceasefire talks resume for second day in qatar  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza ceasefire talks resume for second day in qatar  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza ceasefire talks resume for second day in qatar  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza civilians attack red cross - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza civilians attack red cross - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza civilians attack red cross - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza conflict israel & hamas face allegations of war crimes - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza conflict israel & hamas face allegations of war crimes - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza conflict israel & hamas face allegations of war crimes - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza crisis '15 killed' in un school - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza crisis '15 killed' in un school - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza crisis '15 killed' in un school - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza crisis 'accountability & justice for both sides' says un chief ban ki-moon- bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza crisis 'accountability & justice for both sides' says un chief ban ki-moon- bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza crisis 'accountability & justice for both sides' says un chief ban ki-moon- bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza crisis 'hamas are against peace' says shimon peres - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza crisis 'hamas are against peace' says shimon peres - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza crisis 'hamas are against peace' says shimon peres - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza crisis 10 israeli soldiers killed in hams attacks - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza crisis 10 israeli soldiers killed in hams attacks - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza crisis 10 israeli soldiers killed in hams attacks - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza crisis are we any closer to a solution bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza crisis are we any closer to a solution bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza crisis are we any closer to a solution bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza crisis deadly strike outside un school in rafah - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza crisis deadly strike outside un school in rafah - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza crisis deadly strike outside un school in rafah - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza crisis inside a hamas tunnel - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza crisis inside a hamas tunnel - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza crisis inside a hamas tunnel - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza crisis israel releases 'aborted airstrike' video - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza crisis israel releases 'aborted airstrike' video - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza crisis israel releases 'aborted airstrike' video - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza crisis rocket strikes israeli petrol station - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza crisis rocket strikes israeli petrol station - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza crisis rocket strikes israeli petrol station - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza death toll exceeds 30,000, hamas-run health ministry says  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza death toll exceeds 30,000, hamas-run health ministry says  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza death toll exceeds 30,000, hamas-run health ministry says  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza evacuation israel warns people must leave north - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza evacuation israel warns people must leave north - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza evacuation israel warns people must leave north - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza evacuation warnings from idf contain many errors, bbc finds  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza evacuation warnings from idf contain many errors, bbc finds  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza evacuation warnings from idf contain many errors, bbc finds  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza fighting continues despite un security council resolution calling for ceasefire  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza fighting continues despite un security council resolution calling for ceasefire  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza fighting continues despite un security council resolution calling for ceasefire  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza fighting israeli troops “storm heart of gaza city” - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza fighting israeli troops “storm heart of gaza city” - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza fighting israeli troops “storm heart of gaza city” - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza frontline an israeli artillery unit prepares for battle - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza frontline an israeli artillery unit prepares for battle - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza frontline an israeli artillery unit prepares for battle - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza frontline report  horrific aftermath of hospital explosion - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza frontline report  horrific aftermath of hospital explosion - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza frontline report  horrific aftermath of hospital explosion - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza frontline report israel confirms airstrike on ambulance - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza frontline report israel confirms airstrike on ambulance - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza frontline report israel confirms airstrike on ambulance - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza ground war  israeli troops surround gaza city - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza ground war  israeli troops surround gaza city - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza ground war  israeli troops surround gaza city - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza has israel taken enough action to prevent incitement to genocide  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza has israel taken enough action to prevent incitement to genocide  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza has israel taken enough action to prevent incitement to genocide  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza health ministry says israeli hostage rescue killed 274 palestinians  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza health ministry says israeli hostage rescue killed 274 palestinians  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza health ministry says israeli hostage rescue killed 274 palestinians  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza hospital attack ‘appears to have been done by the other team’, joe biden says - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza hospital attack ‘appears to have been done by the other team’, joe biden says - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza hospital attack ‘appears to have been done by the other team’, joe biden says - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\gaza hospital joe biden backs israel account of explosion - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\gaza hospital joe biden backs israel account of explosion - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\gaza hospital joe biden backs israel account of explosion - bbc news_treetagger_output.txt
# ...
# Words have been successfully written to data/en_BBCNews\treetagger_output\us steps up criticism of israel’s military offensive in gaza - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\us steps up criticism of israel’s military offensive in gaza - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\us steps up criticism of israel’s military offensive in gaza - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\us support for israel is ‘rock solid’, president joe biden says – bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\us support for israel is ‘rock solid’, president joe biden says – bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\us support for israel is ‘rock solid’, president joe biden says – bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\us to send jets and warships as iran threatens israel  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\us to send jets and warships as iran threatens israel  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\us to send jets and warships as iran threatens israel  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\us to set up port on gaza coast for aid delivery  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\us to set up port on gaza coast for aid delivery  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\us to set up port on gaza coast for aid delivery  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\us troops killed and dozens injured in drone attack on syria-jordan border  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\us troops killed and dozens injured in drone attack on syria-jordan border  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\us troops killed and dozens injured in drone attack on syria-jordan border  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\us urges israel to be transparent over gaza school strike  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\us urges israel to be transparent over gaza school strike  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\us urges israel to be transparent over gaza school strike  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\us vetoes call for immediate gaza ceasefire at un  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\us vetoes call for immediate gaza ceasefire at un  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\us vetoes call for immediate gaza ceasefire at un  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\us warns of “dangerous moment” as it prepares to strike iranian targets  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\us warns of “dangerous moment” as it prepares to strike iranian targets  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\us warns of “dangerous moment” as it prepares to strike iranian targets  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\us ‘hopeful’ hamas will accept new israel ceasefire offer  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\us ‘hopeful’ hamas will accept new israel ceasefire offer  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\us ‘hopeful’ hamas will accept new israel ceasefire offer  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\video shows israeli airstrikes on gaza strip - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\video shows israeli airstrikes on gaza strip - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\video shows israeli airstrikes on gaza strip - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\video shows us and israeli hostages alive in gaza  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\video shows us and israeli hostages alive in gaza  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\video shows us and israeli hostages alive in gaza  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\violent clashes in west bank as palestinians protest over israeli air strikes in gaza - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\violent clashes in west bank as palestinians protest over israeli air strikes in gaza - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\violent clashes in west bank as palestinians protest over israeli air strikes in gaza - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\war in ukraine us to send new aid within 'hours', joe biden says  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\war in ukraine us to send new aid within 'hours', joe biden says  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\war in ukraine us to send new aid within 'hours', joe biden says  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\warnings of famine in northern gaza  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\warnings of famine in northern gaza  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\warnings of famine in northern gaza  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\west bank palestinian families living in fear of extremist israeli settlers  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\west bank palestinian families living in fear of extremist israeli settlers  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\west bank palestinian families living in fear of extremist israeli settlers  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\what does gaza hospital blast evidence show - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\what does gaza hospital blast evidence show - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\what does gaza hospital blast evidence show - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\what does the journey through the gaza evacuation corridor look like - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\what does the journey through the gaza evacuation corridor look like - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\what does the journey through the gaza evacuation corridor look like - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\what is happening in israel and gaza strip and other questions – bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\what is happening in israel and gaza strip and other questions – bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\what is happening in israel and gaza strip and other questions – bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\what is iran's 'axis of resistance’  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\what is iran's 'axis of resistance’  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\what is iran's 'axis of resistance’  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\what is israel's gaza ceasfire proposal outlined by us president biden i bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\what is israel's gaza ceasfire proposal outlined by us president biden i bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\what is israel's gaza ceasfire proposal outlined by us president biden i bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\what next for gaza ceasefire plan and hostage release deal  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\what next for gaza ceasefire plan and hostage release deal  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\what next for gaza ceasefire plan and hostage release deal  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\what will end the israel-palestinian violence - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\what will end the israel-palestinian violence - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\what will end the israel-palestinian violence - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\what's happening in israel and why now - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\what's happening in israel and why now - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\what's happening in israel and why now - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\where are palestinian rockets being fired towards bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\where are palestinian rockets being fired towards bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\where are palestinian rockets being fired towards bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\who exceeds target for gaza polio vaccinations as campaign continues  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\who exceeds target for gaza polio vaccinations as campaign continues  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\who exceeds target for gaza polio vaccinations as campaign continues  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\why has israel-gaza conflict flared - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\why has israel-gaza conflict flared - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\why has israel-gaza conflict flared - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\why us believes israel and saudi arabia negotiations could be factor in hamas attacks - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\why us believes israel and saudi arabia negotiations could be factor in hamas attacks - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\why us believes israel and saudi arabia negotiations could be factor in hamas attacks - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\will israel reoccupy gaza bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\will israel reoccupy gaza bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\will israel reoccupy gaza bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\world cup qualifiers palestinian football team play australia in kuwait - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\world cup qualifiers palestinian football team play australia in kuwait - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\world cup qualifiers palestinian football team play australia in kuwait - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\world health organization says gaza's main hospital no longer functioning – bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\world health organization says gaza's main hospital no longer functioning – bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\world health organization says gaza's main hospital no longer functioning – bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\yemen houthis to be re-designated as terror group by us  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\yemen houthis to be re-designated as terror group by us  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\yemen houthis to be re-designated as terror group by us  bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\your questions answered why are israel and gaza at war – bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\your questions answered why are israel and gaza at war – bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\your questions answered why are israel and gaza at war – bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\your questions answered why is biden going to israel – bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\your questions answered why is biden going to israel – bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\your questions answered why is biden going to israel – bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\“700 killed in 24 hours” as un accuses israel of breaking international law - bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\“700 killed in 24 hours” as un accuses israel of breaking international law - bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\“700 killed in 24 hours” as un accuses israel of breaking international law - bbc news_treetagger_output.txt
# Words have been successfully written to data/en_BBCNews\treetagger_output\“90 killed and 300 injured” in israeli strike on gaza “humanitarian area”  bbc news_words.txt
# Words have been written to data/en_BBCNews\treetagger_output\“90 killed and 300 injured” in israeli strike on gaza “humanitarian area”  bbc news_words.txt
# TreeTagger output has been written to data/en_BBCNews\treetagger_output\“90 killed and 300 injured” in israeli strike on gaza “humanitarian area”  bbc news_treetagger_output.txt
