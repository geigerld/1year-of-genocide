# %%
import os
import re
import subprocess

def list_txt_files(directory):
    # Find all .txt files in the directory (non-recursively)
    txt_files = []
    for file in os.listdir(directory):
        file_path = os.path.join(directory, file)
        if os.path.isfile(file_path) and file.endswith('.txt'):
            txt_files.append(file_path)
    return txt_files
    
# Function to extract text between <doc> and </doc> tags
def extract_text_from_file(file_path, encoding='utf-8'):
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        # Use regular expressions to find the text between <doc> and </doc>
        #match = re.search(r'<doc>(.*?)</doc>', content, re.DOTALL)
        #if match:
        #    return match.group(1).strip()
        #else:
            return content
    except UnicodeDecodeError as e:
        print(f"Error reading file {file_path}: {e}")
        return None

# Function to tokenize text into words and punctuation
def tokenize(text):
    # Regex to split words and punctuation
    # \w+ matches word characters (including numbers and underscores)
    # [^\w\s] matches punctuation (anything that's not a word or whitespace)
    tokens = re.findall(r'\w+|[^\w\s]', text, re.UNICODE)
    return tokens

# Function to write tokens to a new file with each token on a new line
def write_words_to_file(text, output_path, encoding='utf-8'):
    try:
        # Tokenize the text using the tokenizer
        tokens = tokenize(text)
        with open(output_path, 'w', encoding=encoding) as file:
            for token in tokens:
                file.write(token + '\n')
        print(f"Tokens have been successfully written to {output_path}")
    except UnicodeEncodeError as e:
        print(f"Error writing file {output_path}: {e}")

# Function to execute TreeTagger and process the output
def run_treetagger(input_path, output_path):
    treetagger_path = 'tree-tagger-windows-3.2.3a/TreeTagger/bin/tree-tagger.exe'  # Replace with the path to your TreeTagger executable
    parameter_path = 'tree-tagger-windows-3.2.3a/TreeTagger/lib/english.par'  # Replace with the path to your TreeTagger parameter file
    cmd = [treetagger_path, parameter_path, '-token', '-lemma', '-no-unknown', input_path]
    
    try:
        # Run TreeTagger and capture the output
        result = subprocess.run(cmd, capture_output=True, text=True, encoding='utf-8')
        
        if result.returncode == 0:
            if result.stdout:  # Check if stdout is not None
                with open(output_path, 'w', encoding='utf-8') as file:
                    file.write(result.stdout)
                print(f"TreeTagger output has been written to {output_path}")
            else:
                print(f"No output from TreeTagger for file: {input_path}")
        else:
            print(f"Error running TreeTagger: {result.stderr}")
    
    except Exception as e:
        print(f"An exception occurred: {e}")

def process_files(directory):
    # Find all .txt files
    txt_files = list_txt_files(directory)
    for txt_file in txt_files:
        # Ensure the directory for TreeTagger output exists
        treetagger_output_dir = os.path.join(os.path.dirname(txt_file), 'treetagger_output')
        os.makedirs(treetagger_output_dir, exist_ok=True)
        
        # Define paths
        temp_text_file_path = os.path.join(treetagger_output_dir, os.path.basename(txt_file).replace('.txt', '_words.txt'))
        treetagger_output_path = os.path.join(treetagger_output_dir, os.path.basename(txt_file).replace('.txt', '_treetagger_output.txt'))

        # Extract text and write to new file
        text = extract_text_from_file(txt_file)
        if text:
            write_words_to_file(text, temp_text_file_path)
            print(f"Words have been written to {temp_text_file_path}")

            # Run TreeTagger
            run_treetagger(temp_text_file_path, treetagger_output_path)

            # Clean up temporary file
            os.remove(temp_text_file_path)
        else:
            print(f"No text found in <doc> tags for file: {txt_file}")


# Example usage
directory_path = 'data/en_CNN/'  # Root directory containing subfolders with .txt files
process_files(directory_path)
# Out:
# Tokens have been successfully written to data/en_CNN\treetagger_output\'a bird in heaven' grandfather cradles 7-year-old granddaughter killed in southern gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\'a bird in heaven' grandfather cradles 7-year-old granddaughter killed in southern gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'a bird in heaven' grandfather cradles 7-year-old granddaughter killed in southern gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'a mistake' biden warns against israel occupying gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\'a mistake' biden warns against israel occupying gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'a mistake' biden warns against israel occupying gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'dangerous and unhinged' white house reacts to trump complimenting hezbollah_words.txt
# Words have been written to data/en_CNN\treetagger_output\'dangerous and unhinged' white house reacts to trump complimenting hezbollah_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'dangerous and unhinged' white house reacts to trump complimenting hezbollah_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'death was a blessing' father on learning fate of daughter_words.txt
# Words have been written to data/en_CNN\treetagger_output\'death was a blessing' father on learning fate of daughter_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'death was a blessing' father on learning fate of daughter_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'i don't know if we're going to make it' palestinian-american stuck in gaza speaks out_words.txt
# Words have been written to data/en_CNN\treetagger_output\'i don't know if we're going to make it' palestinian-american stuck in gaza speaks out_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'i don't know if we're going to make it' palestinian-american stuck in gaza speaks out_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'i was so shocked' mom who broke down on dnc stage speaks out_words.txt
# Words have been written to data/en_CNN\treetagger_output\'i was so shocked' mom who broke down on dnc stage speaks out_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'i was so shocked' mom who broke down on dnc stage speaks out_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'israelis are bombing the crap out of gaza' tapper presses biden official on american hostages_words.txt
# Words have been written to data/en_CNN\treetagger_output\'israelis are bombing the crap out of gaza' tapper presses biden official on american hostages_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'israelis are bombing the crap out of gaza' tapper presses biden official on american hostages_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'it was animal slaughter' israeli festival survivor describes horror_words.txt
# Words have been written to data/en_CNN\treetagger_output\'it was animal slaughter' israeli festival survivor describes horror_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'it was animal slaughter' israeli festival survivor describes horror_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'it was like that place didn't exist' see doctors' journey leaving gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\'it was like that place didn't exist' see doctors' journey leaving gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'it was like that place didn't exist' see doctors' journey leaving gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'it's a very big deal' petraeus on the significance of iran's attack_words.txt
# Words have been written to data/en_CNN\treetagger_output\'it's a very big deal' petraeus on the significance of iran's attack_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'it's a very big deal' petraeus on the significance of iran's attack_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'mind-boggling' retired general on hamas tunnel in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\'mind-boggling' retired general on hamas tunnel in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'mind-boggling' retired general on hamas tunnel in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'nobody can win a war like this' jewish student reflects on israeli-hamas war_words.txt
# Words have been written to data/en_CNN\treetagger_output\'nobody can win a war like this' jewish student reflects on israeli-hamas war_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'nobody can win a war like this' jewish student reflects on israeli-hamas war_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'orders of magnitude more difficult' petraeus on urban combat_words.txt
# Words have been written to data/en_CNN\treetagger_output\'orders of magnitude more difficult' petraeus on urban combat_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'orders of magnitude more difficult' petraeus on urban combat_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'shocking' watch blinken react to footage of hamas terrorist attack on family_words.txt
# Words have been written to data/en_CNN\treetagger_output\'shocking' watch blinken react to footage of hamas terrorist attack on family_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'shocking' watch blinken react to footage of hamas terrorist attack on family_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'soap has become a luxury item' aid official describes anguish in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\'soap has become a luxury item' aid official describes anguish in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'soap has become a luxury item' aid official describes anguish in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'they bombed an entire street' child in gaza who pulled brother from rubble_words.txt
# Words have been written to data/en_CNN\treetagger_output\'they bombed an entire street' child in gaza who pulled brother from rubble_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'they bombed an entire street' child in gaza who pulled brother from rubble_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'they told us this area was safe' designated gaza safe zone targeted by israeli airstrike_words.txt
# Words have been written to data/en_CNN\treetagger_output\'they told us this area was safe' designated gaza safe zone targeted by israeli airstrike_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'they told us this area was safe' designated gaza safe zone targeted by israeli airstrike_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'we have 3 minutes' cnn goes inside one of most dangerous places in northern israel_words.txt
# Words have been written to data/en_CNN\treetagger_output\'we have 3 minutes' cnn goes inside one of most dangerous places in northern israel_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'we have 3 minutes' cnn goes inside one of most dangerous places in northern israel_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'who takes over' tapper presses netanyahu adviser on the future of gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\'who takes over' tapper presses netanyahu adviser on the future of gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'who takes over' tapper presses netanyahu adviser on the future of gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\'you don't compliment any of them' haley responds to trump's hamas comment_words.txt
# Words have been written to data/en_CNN\treetagger_output\'you don't compliment any of them' haley responds to trump's hamas comment_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\'you don't compliment any of them' haley responds to trump's hamas comment_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\104 civilians killed trying to access food aid trucks in gaza, palestinian health ministry says_words.txt
# Words have been written to data/en_CNN\treetagger_output\104 civilians killed trying to access food aid trucks in gaza, palestinian health ministry says_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\104 civilians killed trying to access food aid trucks in gaza, palestinian health ministry says_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\300,000 israeli troops stand at ready after hamas attack_words.txt
# Words have been written to data/en_CNN\treetagger_output\300,000 israeli troops stand at ready after hamas attack_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\300,000 israeli troops stand at ready after hamas attack_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\85-year-old grandmother freed by hamas describes being kidnapped_words.txt
# Words have been written to data/en_CNN\treetagger_output\85-year-old grandmother freed by hamas describes being kidnapped_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\85-year-old grandmother freed by hamas describes being kidnapped_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\alleged leaked netanyahu audio reveals he might be angry with the us_words.txt
# Words have been written to data/en_CNN\treetagger_output\alleged leaked netanyahu audio reveals he might be angry with the us_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\alleged leaked netanyahu audio reveals he might be angry with the us_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\american nurse who got out of gaza describes desperation she saw_words.txt
# Words have been written to data/en_CNN\treetagger_output\american nurse who got out of gaza describes desperation she saw_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\american nurse who got out of gaza describes desperation she saw_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\analyst how hamas is using cryptocurrency to raise funds_words.txt
# Words have been written to data/en_CNN\treetagger_output\analyst how hamas is using cryptocurrency to raise funds_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\analyst how hamas is using cryptocurrency to raise funds_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\analyst weighs in on hamas hostage video release_words.txt
# Words have been written to data/en_CNN\treetagger_output\analyst weighs in on hamas hostage video release_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\analyst weighs in on hamas hostage video release_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\anderson cooper had a realization about a hostage during a live interview with his parents_words.txt
# Words have been written to data/en_CNN\treetagger_output\anderson cooper had a realization about a hostage during a live interview with his parents_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\anderson cooper had a realization about a hostage during a live interview with his parents_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\anderson cooper's connection to the parents of hostage hersh goldberg-polin, who was killed by hamas_words.txt
# Words have been written to data/en_CNN\treetagger_output\anderson cooper's connection to the parents of hostage hersh goldberg-polin, who was killed by hamas_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\anderson cooper's connection to the parents of hostage hersh goldberg-polin, who was killed by hamas_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\at least 45 dead as israel strikes rafah, gazan officials say_words.txt
# Words have been written to data/en_CNN\treetagger_output\at least 45 dead as israel strikes rafah, gazan officials say_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\at least 45 dead as israel strikes rafah, gazan officials say_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\attacks on us military in middle east stoke fear of regional war_words.txt
# Words have been written to data/en_CNN\treetagger_output\attacks on us military in middle east stoke fear of regional war_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\attacks on us military in middle east stoke fear of regional war_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\before and after satellite images show destruction in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\before and after satellite images show destruction in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\before and after satellite images show destruction in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\benjamin netanyahu disbands israeli war cabinet_words.txt
# Words have been written to data/en_CNN\treetagger_output\benjamin netanyahu disbands israeli war cabinet_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\benjamin netanyahu disbands israeli war cabinet_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\bernie sanders rips netanyahu ahead of high-stakes speech to congress_words.txt
# Words have been written to data/en_CNN\treetagger_output\bernie sanders rips netanyahu ahead of high-stakes speech to congress_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\bernie sanders rips netanyahu ahead of high-stakes speech to congress_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\bernie sanders us should not give netanyahu 'another nickel'_words.txt
# Words have been written to data/en_CNN\treetagger_output\bernie sanders us should not give netanyahu 'another nickel'_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\bernie sanders us should not give netanyahu 'another nickel'_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\biden and netanyahu to speak for the first time since 7 aid workers killed in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\biden and netanyahu to speak for the first time since 7 aid workers killed in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\biden and netanyahu to speak for the first time since 7 aid workers killed in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\biden confirms 4-year-old abigail edan among hostages released_words.txt
# Words have been written to data/en_CNN\treetagger_output\biden confirms 4-year-old abigail edan among hostages released_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\biden confirms 4-year-old abigail edan among hostages released_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\biden downplaying hamas' october 7 attack must stop_words.txt
# Words have been written to data/en_CNN\treetagger_output\biden downplaying hamas' october 7 attack must stop_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\biden downplaying hamas' october 7 attack must stop_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\biden hamas attack on israel is ‘an act of sheer evil’_words.txt
# Words have been written to data/en_CNN\treetagger_output\biden hamas attack on israel is ‘an act of sheer evil’_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\biden hamas attack on israel is ‘an act of sheer evil’_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\biden hostage release 'only a start'_words.txt
# Words have been written to data/en_CNN\treetagger_output\biden hostage release 'only a start'_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\biden hostage release 'only a start'_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\biden to netanyahu protect civilians or else_words.txt
# Words have been written to data/en_CNN\treetagger_output\biden to netanyahu protect civilians or else_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\biden to netanyahu protect civilians or else_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\biden warns that netanyahu needs to change his government_words.txt
# Words have been written to data/en_CNN\treetagger_output\biden warns that netanyahu needs to change his government_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\biden warns that netanyahu needs to change his government_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\blinken describes how the israel-hamas war affects him personally_words.txt
# Words have been written to data/en_CNN\treetagger_output\blinken describes how the israel-hamas war affects him personally_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\blinken describes how the israel-hamas war affects him personally_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\blinken gives update on release of 2 american hostages held by hamas_words.txt
# Words have been written to data/en_CNN\treetagger_output\blinken gives update on release of 2 american hostages held by hamas_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\blinken gives update on release of 2 american hostages held by hamas_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\blinken on why international community slow to address sexual violence committed by hamas_words.txt
# Words have been written to data/en_CNN\treetagger_output\blinken on why international community slow to address sexual violence committed by hamas_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\blinken on why international community slow to address sexual violence committed by hamas_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\blogger leaves haunting words in final video from gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\blogger leaves haunting words in final video from gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\blogger leaves haunting words in final video from gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\bolton says icc actions show it’s not ‘tethered to rule of law itself’_words.txt
# Words have been written to data/en_CNN\treetagger_output\bolton says icc actions show it’s not ‘tethered to rule of law itself’_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\bolton says icc actions show it’s not ‘tethered to rule of law itself’_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\breaking down what biden said in israel amid deadly gaza hospital strike_words.txt
# Words have been written to data/en_CNN\treetagger_output\breaking down what biden said in israel amid deadly gaza hospital strike_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\breaking down what biden said in israel amid deadly gaza hospital strike_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\brother of released american hostage speaks out_words.txt
# Words have been written to data/en_CNN\treetagger_output\brother of released american hostage speaks out_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\brother of released american hostage speaks out_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\burnett confronts top israeli official about october 7 intelligence failure_words.txt
# Words have been written to data/en_CNN\treetagger_output\burnett confronts top israeli official about october 7 intelligence failure_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\burnett confronts top israeli official about october 7 intelligence failure_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\catch up on netanyahu’s speech to congress and analysis_words.txt
# Words have been written to data/en_CNN\treetagger_output\catch up on netanyahu’s speech to congress and analysis_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\catch up on netanyahu’s speech to congress and analysis_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cheers erupt as red cross convoy passes through rafah crossing_words.txt
# Words have been written to data/en_CNN\treetagger_output\cheers erupt as red cross convoy passes through rafah crossing_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cheers erupt as red cross convoy passes through rafah crossing_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\chilling audio from israeli medic reveals last moments_words.txt
# Words have been written to data/en_CNN\treetagger_output\chilling audio from israeli medic reveals last moments_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\chilling audio from israeli medic reveals last moments_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\chris christie on what he thinks is top priority in israel-hamas war_words.txt
# Words have been written to data/en_CNN\treetagger_output\chris christie on what he thinks is top priority in israel-hamas war_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\chris christie on what he thinks is top priority in israel-hamas war_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\clarissa ward explains what aid has made it into gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\clarissa ward explains what aid has made it into gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\clarissa ward explains what aid has made it into gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn anchor asks idf spokesman where palestinians were supposed to go after strike_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn anchor asks idf spokesman where palestinians were supposed to go after strike_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn anchor asks idf spokesman where palestinians were supposed to go after strike_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn anchor asks idf spokesperson if airstrikes have accomplished all they can_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn anchor asks idf spokesperson if airstrikes have accomplished all they can_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn anchor asks idf spokesperson if airstrikes have accomplished all they can_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn anchor breaks down questions surrounding 'tragic errors' in israel's war against hamas_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn anchor breaks down questions surrounding 'tragic errors' in israel's war against hamas_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn anchor breaks down questions surrounding 'tragic errors' in israel's war against hamas_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn anchor presses netanyahu adviser on civilian deaths at jabalya camp_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn anchor presses netanyahu adviser on civilian deaths at jabalya camp_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn anchor presses netanyahu adviser on civilian deaths at jabalya camp_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn asked us national security adviser about israel using ‘dumb bombs’ in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn asked us national security adviser about israel using ‘dumb bombs’ in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn asked us national security adviser about israel using ‘dumb bombs’ in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn asks netanyahu, ‘how much is too much’ hear his response_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn asks netanyahu, ‘how much is too much’ hear his response_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn asks netanyahu, ‘how much is too much’ hear his response_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn correspondent breaks down new idf report on wck strike_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn correspondent breaks down new idf report on wck strike_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn correspondent breaks down new idf report on wck strike_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn forensic analysis suggests what may have caused gaza hospital blast_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn forensic analysis suggests what may have caused gaza hospital blast_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn forensic analysis suggests what may have caused gaza hospital blast_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn goes into underground tunnel that idf claims was under gaza cemetery_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn goes into underground tunnel that idf claims was under gaza cemetery_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn goes into underground tunnel that idf claims was under gaza cemetery_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn presses idf spokesperson on firing at civilians seeking aid_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn presses idf spokesperson on firing at civilians seeking aid_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn presses idf spokesperson on firing at civilians seeking aid_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn presses idf spokesperson on the ratio of civilian casualties_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn presses idf spokesperson on the ratio of civilian casualties_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn presses idf spokesperson on the ratio of civilian casualties_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn producer tried to cross from gaza into egypt_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn producer tried to cross from gaza into egypt_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn producer tried to cross from gaza into egypt_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn reporter embeds with idf in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn reporter embeds with idf in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn reporter embeds with idf in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn reporter lays out israel's evaluation of iran's alleged involvement in the hamas attacks_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn reporter lays out israel's evaluation of iran's alleged involvement in the hamas attacks_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn reporter lays out israel's evaluation of iran's alleged involvement in the hamas attacks_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn reporter takes a look inside gaza hospitals 'on the brink of collapse'_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn reporter takes a look inside gaza hospitals 'on the brink of collapse'_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn reporter takes a look inside gaza hospitals 'on the brink of collapse'_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn tours israeli military base filled with seized hamas weapons_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn tours israeli military base filled with seized hamas weapons_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn tours israeli military base filled with seized hamas weapons_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn video shows palestinian detainees blindfolded and barefoot near gaza border_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn video shows palestinian detainees blindfolded and barefoot near gaza border_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn video shows palestinian detainees blindfolded and barefoot near gaza border_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn visited a gaza hospital_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn visited a gaza hospital_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn visited a gaza hospital_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cnn witnessed first-hand results of israel's bulldozing of graveyards in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\cnn witnessed first-hand results of israel's bulldozing of graveyards in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cnn witnessed first-hand results of israel's bulldozing of graveyards in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\conditions at gaza hospital deteriorate amid israel’s military operation_words.txt
# Words have been written to data/en_CNN\treetagger_output\conditions at gaza hospital deteriorate amid israel’s military operation_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\conditions at gaza hospital deteriorate amid israel’s military operation_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\cousin of hostage killed by hamas netanyahu's decisions made it impossible for hostages to return_words.txt
# Words have been written to data/en_CNN\treetagger_output\cousin of hostage killed by hamas netanyahu's decisions made it impossible for hostages to return_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\cousin of hostage killed by hamas netanyahu's decisions made it impossible for hostages to return_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\dad wants the world to hear this chilling call of his daughter being kidnapped_words.txt
# Words have been written to data/en_CNN\treetagger_output\dad wants the world to hear this chilling call of his daughter being kidnapped_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\dad wants the world to hear this chilling call of his daughter being kidnapped_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\deadly strike in golan heights raises fears of major escalation_words.txt
# Words have been written to data/en_CNN\treetagger_output\deadly strike in golan heights raises fears of major escalation_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\deadly strike in golan heights raises fears of major escalation_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\dramatic video shows rockets fired into gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\dramatic video shows rockets fired into gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\dramatic video shows rockets fired into gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\drone footage of war-torn gaza shows immense destruction_words.txt
# Words have been written to data/en_CNN\treetagger_output\drone footage of war-torn gaza shows immense destruction_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\drone footage of war-torn gaza shows immense destruction_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\ex-cia director weighs in on the use of drones to locate hostages held by hamas_words.txt
# Words have been written to data/en_CNN\treetagger_output\ex-cia director weighs in on the use of drones to locate hostages held by hamas_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\ex-cia director weighs in on the use of drones to locate hostages held by hamas_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\ex-federal official explains why she resigned over us approach to gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\ex-federal official explains why she resigned over us approach to gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\ex-federal official explains why she resigned over us approach to gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\ex-us defense secy_words.txt
# Words have been written to data/en_CNN\treetagger_output\ex-us defense secy_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\ex-us defense secy_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\exclusive cnn meets israeli troops as tensions rise on lebanon border_words.txt
# Words have been written to data/en_CNN\treetagger_output\exclusive cnn meets israeli troops as tensions rise on lebanon border_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\exclusive cnn meets israeli troops as tensions rise on lebanon border_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\exclusive icc prosecutor seeks arrest warrants against sinwar and netanyahu for war crimes_words.txt
# Words have been written to data/en_CNN\treetagger_output\exclusive icc prosecutor seeks arrest warrants against sinwar and netanyahu for war crimes_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\exclusive icc prosecutor seeks arrest warrants against sinwar and netanyahu for war crimes_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\explosion heard in hezbollah stronghold in beirut_words.txt
# Words have been written to data/en_CNN\treetagger_output\explosion heard in hezbollah stronghold in beirut_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\explosion heard in hezbollah stronghold in beirut_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\explosion interrupts live gaza interview_words.txt
# Words have been written to data/en_CNN\treetagger_output\explosion interrupts live gaza interview_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\explosion interrupts live gaza interview_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\explosions go off during interview with american doctor trapped in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\explosions go off during interview with american doctor trapped in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\explosions go off during interview with american doctor trapped in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\family members of hamas hostages storm into israeli parliament_words.txt
# Words have been written to data/en_CNN\treetagger_output\family members of hamas hostages storm into israeli parliament_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\family members of hamas hostages storm into israeli parliament_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\family members of hostages held in gaza desperate to be reunited_words.txt
# Words have been written to data/en_CNN\treetagger_output\family members of hostages held in gaza desperate to be reunited_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\family members of hostages held in gaza desperate to be reunited_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\fareed shares what the 'severest setback' would be for hamas now_words.txt
# Words have been written to data/en_CNN\treetagger_output\fareed shares what the 'severest setback' would be for hamas now_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\fareed shares what the 'severest setback' would be for hamas now_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\fareed zakaria does anyone believe in free speech anymore_words.txt
# Words have been written to data/en_CNN\treetagger_output\fareed zakaria does anyone believe in free speech anymore_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\fareed zakaria does anyone believe in free speech anymore_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\fareed's take the scope of the israel-hamas war is widening_words.txt
# Words have been written to data/en_CNN\treetagger_output\fareed's take the scope of the israel-hamas war is widening_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\fareed's take the scope of the israel-hamas war is widening_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\father of 8-year-old girl believed to be taken by hamas describes relentless search for daughter_words.txt
# Words have been written to data/en_CNN\treetagger_output\father of 8-year-old girl believed to be taken by hamas describes relentless search for daughter_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\father of 8-year-old girl believed to be taken by hamas describes relentless search for daughter_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\father of 9-year-old hostage reveals what daughter told him after her release_words.txt
# Words have been written to data/en_CNN\treetagger_output\father of 9-year-old hostage reveals what daughter told him after her release_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\father of 9-year-old hostage reveals what daughter told him after her release_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\flags burned, monuments graffitied and us flags replaced with palestinian ones by protesters_words.txt
# Words have been written to data/en_CNN\treetagger_output\flags burned, monuments graffitied and us flags replaced with palestinian ones by protesters_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\flags burned, monuments graffitied and us flags replaced with palestinian ones by protesters_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\former defense secretary discusses the role the us plays in middle east tensions_words.txt
# Words have been written to data/en_CNN\treetagger_output\former defense secretary discusses the role the us plays in middle east tensions_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\former defense secretary discusses the role the us plays in middle east tensions_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\former idf soldier believes israel is making 'a catastrophic mistake' in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\former idf soldier believes israel is making 'a catastrophic mistake' in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\former idf soldier believes israel is making 'a catastrophic mistake' in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\former us general says it will be 'exceedingly difficult' to destroy hamas_words.txt
# Words have been written to data/en_CNN\treetagger_output\former us general says it will be 'exceedingly difficult' to destroy hamas_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\former us general says it will be 'exceedingly difficult' to destroy hamas_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\freed israeli mother asked what she feared most in captivity_words.txt
# Words have been written to data/en_CNN\treetagger_output\freed israeli mother asked what she feared most in captivity_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\freed israeli mother asked what she feared most in captivity_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\gaza needs 640,000 polio vaccines_words.txt
# Words have been written to data/en_CNN\treetagger_output\gaza needs 640,000 polio vaccines_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\gaza needs 640,000 polio vaccines_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\gaza's only power station runs out of fuel_words.txt
# Words have been written to data/en_CNN\treetagger_output\gaza's only power station runs out of fuel_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\gaza's only power station runs out of fuel_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\gaza's second largest hospital collapses under israeli bombardment_words.txt
# Words have been written to data/en_CNN\treetagger_output\gaza's second largest hospital collapses under israeli bombardment_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\gaza's second largest hospital collapses under israeli bombardment_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\graphic video shows scale of devastation in rafah_words.txt
# Words have been written to data/en_CNN\treetagger_output\graphic video shows scale of devastation in rafah_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\graphic video shows scale of devastation in rafah_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\gunfire breaks out at key gaza crossing for aid trucks_words.txt
# Words have been written to data/en_CNN\treetagger_output\gunfire breaks out at key gaza crossing for aid trucks_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\gunfire breaks out at key gaza crossing for aid trucks_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\hamas announces yahya sinwar as head of political bureau_words.txt
# Words have been written to data/en_CNN\treetagger_output\hamas announces yahya sinwar as head of political bureau_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\hamas announces yahya sinwar as head of political bureau_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\hamas attack survivor details escape from terrorists_words.txt
# Words have been written to data/en_CNN\treetagger_output\hamas attack survivor details escape from terrorists_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\hamas attack survivor details escape from terrorists_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\hamas fires hundreds of rockets at israeli city_words.txt
# Words have been written to data/en_CNN\treetagger_output\hamas fires hundreds of rockets at israeli city_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\hamas fires hundreds of rockets at israeli city_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\hamas leader was killed by explosive device planted months before explosion, source says_words.txt
# Words have been written to data/en_CNN\treetagger_output\hamas leader was killed by explosive device planted months before explosion, source says_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\hamas leader was killed by explosive device planted months before explosion, source says_treetagger_output.txt
# ...
# TreeTagger output has been written to data/en_CNN\treetagger_output\us has 'reason to believe' american will be released by hamas during exchange_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\us intel hezbollah could be getting russian missile system_words.txt
# Words have been written to data/en_CNN\treetagger_output\us intel hezbollah could be getting russian missile system_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\us intel hezbollah could be getting russian missile system_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\us intelligence warned of potential for gaza clash in days before attack_words.txt
# Words have been written to data/en_CNN\treetagger_output\us intelligence warned of potential for gaza clash in days before attack_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\us intelligence warned of potential for gaza clash in days before attack_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\veteran reporter shows what it's like inside hamas tunnels under gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\veteran reporter shows what it's like inside hamas tunnels under gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\veteran reporter shows what it's like inside hamas tunnels under gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\video appears to show children among palestinian men stripped and detained by idf_words.txt
# Words have been written to data/en_CNN\treetagger_output\video appears to show children among palestinian men stripped and detained by idf_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\video appears to show children among palestinian men stripped and detained by idf_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\video shows chaos and horror following israel's latest airstrike to refugee camp in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\video shows chaos and horror following israel's latest airstrike to refugee camp in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\video shows chaos and horror following israel's latest airstrike to refugee camp in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\video shows extensive airstrikes on gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\video shows extensive airstrikes on gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\video shows extensive airstrikes on gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\video shows helicopter rescue of israeli hostages_words.txt
# Words have been written to data/en_CNN\treetagger_output\video shows helicopter rescue of israeli hostages_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\video shows helicopter rescue of israeli hostages_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\video shows journey one woman took to escape shooting at music festival_words.txt
# Words have been written to data/en_CNN\treetagger_output\video shows journey one woman took to escape shooting at music festival_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\video shows journey one woman took to escape shooting at music festival_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\video shows palestinians fighting to get hold of ration packs_words.txt
# Words have been written to data/en_CNN\treetagger_output\video shows palestinians fighting to get hold of ration packs_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\video shows palestinians fighting to get hold of ration packs_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\video shows rocket strike about 100 meters from cnn reporter_words.txt
# Words have been written to data/en_CNN\treetagger_output\video shows rocket strike about 100 meters from cnn reporter_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\video shows rocket strike about 100 meters from cnn reporter_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\videos show civilian hostages released by hamas_words.txt
# Words have been written to data/en_CNN\treetagger_output\videos show civilian hostages released by hamas_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\videos show civilian hostages released by hamas_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\videos show impact of strikes on children in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\videos show impact of strikes on children in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\videos show impact of strikes on children in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\viral video of usc professor's encounter with pro-palestinian students sparks controversy_words.txt
# Words have been written to data/en_CNN\treetagger_output\viral video of usc professor's encounter with pro-palestinian students sparks controversy_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\viral video of usc professor's encounter with pro-palestinian students sparks controversy_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\volunteer israeli medic recounts horror of hamas attack_words.txt
# Words have been written to data/en_CNN\treetagger_output\volunteer israeli medic recounts horror of hamas attack_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\volunteer israeli medic recounts horror of hamas attack_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\watch as iron dome intercepts hamas' rockets over cnn correspondent's head_words.txt
# Words have been written to data/en_CNN\treetagger_output\watch as iron dome intercepts hamas' rockets over cnn correspondent's head_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\watch as iron dome intercepts hamas' rockets over cnn correspondent's head_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\weapons used by hamas militants appear to be russian or chinese made_words.txt
# Words have been written to data/en_CNN\treetagger_output\weapons used by hamas militants appear to be russian or chinese made_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\weapons used by hamas militants appear to be russian or chinese made_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\wesley clark israeli’s militarily have to do this_words.txt
# Words have been written to data/en_CNN\treetagger_output\wesley clark israeli’s militarily have to do this_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\wesley clark israeli’s militarily have to do this_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\what might be giving israel pause before incursion expert lays out possible factors_words.txt
# Words have been written to data/en_CNN\treetagger_output\what might be giving israel pause before incursion expert lays out possible factors_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\what might be giving israel pause before incursion expert lays out possible factors_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\when hamas attacked, this group of volunteers fought back and won_words.txt
# Words have been written to data/en_CNN\treetagger_output\when hamas attacked, this group of volunteers fought back and won_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\when hamas attacked, this group of volunteers fought back and won_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\white house says it is watching iranian threat ‘very, very closely’_words.txt
# Words have been written to data/en_CNN\treetagger_output\white house says it is watching iranian threat ‘very, very closely’_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\white house says it is watching iranian threat ‘very, very closely’_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\white house warns israel over post-war plans for gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\white house warns israel over post-war plans for gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\white house warns israel over post-war plans for gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\who is the leader of hamas in gaza_words.txt
# Words have been written to data/en_CNN\treetagger_output\who is the leader of hamas in gaza_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\who is the leader of hamas in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\why gaetz doesn't regret ousting mccarthy, even amid israel-hamas conflict_words.txt
# Words have been written to data/en_CNN\treetagger_output\why gaetz doesn't regret ousting mccarthy, even amid israel-hamas conflict_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\why gaetz doesn't regret ousting mccarthy, even amid israel-hamas conflict_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\why retired general thinks hostage exchange is a 'net loss' for israel_words.txt
# Words have been written to data/en_CNN\treetagger_output\why retired general thinks hostage exchange is a 'net loss' for israel_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\why retired general thinks hostage exchange is a 'net loss' for israel_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\why some ultra-orthodox jews are enlisting in the idf_words.txt
# Words have been written to data/en_CNN\treetagger_output\why some ultra-orthodox jews are enlisting in the idf_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\why some ultra-orthodox jews are enlisting in the idf_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\why this expert thinks everyone's mental health is 'at risk' from israel-hamas war_words.txt
# Words have been written to data/en_CNN\treetagger_output\why this expert thinks everyone's mental health is 'at risk' from israel-hamas war_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\why this expert thinks everyone's mental health is 'at risk' from israel-hamas war_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\woman recalls being told her sister was killed by hamas at nova festival_words.txt
# Words have been written to data/en_CNN\treetagger_output\woman recalls being told her sister was killed by hamas at nova festival_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\woman recalls being told her sister was killed by hamas at nova festival_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\woman's daughter was killed by hamas_words.txt
# Words have been written to data/en_CNN\treetagger_output\woman's daughter was killed by hamas_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\woman's daughter was killed by hamas_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\young girl exits ambulance at rafah crossing amid hostage release_words.txt
# Words have been written to data/en_CNN\treetagger_output\young girl exits ambulance at rafah crossing amid hostage release_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\young girl exits ambulance at rafah crossing amid hostage release_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\‘inconceivable’ bernie sanders slams netanyahu’s approach to war against hamas_words.txt
# Words have been written to data/en_CNN\treetagger_output\‘inconceivable’ bernie sanders slams netanyahu’s approach to war against hamas_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\‘inconceivable’ bernie sanders slams netanyahu’s approach to war against hamas_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\‘iran’s useful idiots’ netanyahu calls out protesters during speech to congress_words.txt
# Words have been written to data/en_CNN\treetagger_output\‘iran’s useful idiots’ netanyahu calls out protesters during speech to congress_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\‘iran’s useful idiots’ netanyahu calls out protesters during speech to congress_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\‘it wont be hezbollah alone’ lebanon’s fm warns against israeli invasion_words.txt
# Words have been written to data/en_CNN\treetagger_output\‘it wont be hezbollah alone’ lebanon’s fm warns against israeli invasion_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\‘it wont be hezbollah alone’ lebanon’s fm warns against israeli invasion_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\‘no nation is liberated without sacrifices’ how hamas frames casualties of war_words.txt
# Words have been written to data/en_CNN\treetagger_output\‘no nation is liberated without sacrifices’ how hamas frames casualties of war_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\‘no nation is liberated without sacrifices’ how hamas frames casualties of war_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\‘that sounds like ethnic cleansing’ cnn questions lead figure in israel’s settler movement_words.txt
# Words have been written to data/en_CNN\treetagger_output\‘that sounds like ethnic cleansing’ cnn questions lead figure in israel’s settler movement_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\‘that sounds like ethnic cleansing’ cnn questions lead figure in israel’s settler movement_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\‘we feel alone’ schumer addresses antisemitism_words.txt
# Words have been written to data/en_CNN\treetagger_output\‘we feel alone’ schumer addresses antisemitism_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\‘we feel alone’ schumer addresses antisemitism_treetagger_output.txt
# Tokens have been successfully written to data/en_CNN\treetagger_output\‘you decided to still drop a bomb’ wolf presses idf spokesman on israeli airstrike on refugee camp_words.txt
# Words have been written to data/en_CNN\treetagger_output\‘you decided to still drop a bomb’ wolf presses idf spokesman on israeli airstrike on refugee camp_words.txt
# TreeTagger output has been written to data/en_CNN\treetagger_output\‘you decided to still drop a bomb’ wolf presses idf spokesman on israeli airstrike on refugee camp_treetagger_output.txt
