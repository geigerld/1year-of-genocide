# %%
import os
import re
import subprocess
import json
import pandas as pd

# Function to extract metadata and content between <doc> and </doc> tags, including video_title
def extract_metadata_and_content(df):
    video_id = None
    publish_date = None
    video_title = None
    content_start = None
    content_end = None

    # Fill NaN values with an empty string to prevent issues with `in` checks
    df = df.fillna('')

    # Iterate through the DataFrame to find metadata and content boundaries
    for index, row in df.iterrows():
        row_content = row.iloc[0]
        if '<video_id>' in row_content:
            video_id = re.search(r'<video_id>(.*?)</video_id>', row_content).group(1)
        if '<publish_date>' in row_content:
            publish_date = re.search(r'<publish_date>(.*?)</publish_date>', row_content).group(1)
        if '<video_title>' in row_content:
            video_title = re.search(r'<video_title>(.*?)</video_title>', row_content).group(1)
        if '<doc>' in row_content:
            content_start = index + 1  # Start after <doc> tag
        if '</doc>' in row_content:
            content_end = index  # End before </doc> tag
            break  # Exit loop once end tag is found

    return video_id, publish_date, video_title, content_start, content_end

def list_txt_files(directory):
    # Find all .txt files in the directory (non-recursively)
    txt_files = []
    for file in os.listdir(directory):
        file_path = os.path.join(directory, file)
        if os.path.isfile(file_path) and file.endswith('.txt'):
            txt_files.append(file_path)
    return txt_files

# Function to extract text from file and return DataFrame (for metadata extraction)
def extract_text_from_file(file_path, encoding='utf-8'):
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.readlines()  # Reading file line by line
        df = pd.DataFrame(content)
        return df
    except UnicodeDecodeError as e:
        print(f"Error reading file {file_path}: {e}")
        return None

# Function to tokenize text into words and punctuation
def tokenize(text):
    tokens = re.findall(r'\w+|[^\w\s]', text, re.UNICODE)
    return tokens

# Function to write tokens to a new file with each token on a new line
def write_words_to_file(text, output_path, encoding='utf-8'):
    try:
        tokens = tokenize(text)
        with open(output_path, 'w', encoding=encoding) as file:
            for token in tokens:
                file.write(token + '\n')
        print(f"Tokens have been successfully written to {output_path}")
    except UnicodeEncodeError as e:
        print(f"Error writing file {output_path}: {e}")

# Function to execute TreeTagger and process the output
def run_treetagger(input_path, output_path):
    treetagger_path = 'tree-tagger-windows-3.2.3a/TreeTagger/bin/tree-tagger.exe'  # Replace with the path to your TreeTagger executable
    parameter_path = 'tree-tagger-windows-3.2.3a/TreeTagger/lib/english.par'  # Replace with the path to your TreeTagger parameter file
    cmd = [treetagger_path, parameter_path, '-token', '-lemma', '-no-unknown', input_path]
    
    try:
        # Run TreeTagger and capture the output
        result = subprocess.run(cmd, capture_output=True, text=True, encoding='utf-8')
        
        if result.returncode == 0:
            if result.stdout:  # Check if stdout is not None
                with open(output_path, 'w', encoding='utf-8') as file:
                    file.write(result.stdout)
                print(f"TreeTagger output has been written to {output_path}")
            else:
                print(f"No output from TreeTagger for file: {input_path}")
        else:
            print(f"Error running TreeTagger: {result.stderr}")
    
    except Exception as e:
        print(f"An exception occurred: {e}")

# Function to parse TreeTagger output into structured format (Token, Tag, Lemma)
def parse_treetagger_output(tt_output_path):
    structured_output = []
    try:
        with open(tt_output_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
            for line in lines:
                parts = line.strip().split('\t')
                if len(parts) == 3:
                    token, tag, lemma = parts
                    structured_output.append({
                        "Token": token,
                        "Tag": tag,
                        "Lemma": lemma
                    })
    except Exception as e:
        print(f"Error parsing TreeTagger output: {e}")
    
    return structured_output

# Function to save the metadata and structured TreeTagger output as JSON
def save_as_json(metadata, treetagger_data, json_output_path):
    try:
        data = {
            'video_id': metadata['video_id'],
            'publish_date': metadata['publish_date'],
            'video_title': metadata['video_title'],
            'treetagger_output': treetagger_data  # Structured output here
        }
        with open(json_output_path, 'w', encoding='utf-8') as json_file:
            json.dump(data, json_file, ensure_ascii=False, indent=4)
        print(f"Data has been successfully written to {json_output_path}")
    except Exception as e:
        print(f"Error saving JSON file: {e}")

# Function to process files and extract metadata, tokenize, and run TreeTagger
def process_files(directory):
    # Find all .txt files
    txt_files = list_txt_files(directory)
    for txt_file in txt_files:
        # Ensure the directory for TreeTagger output exists
        treetagger_output_dir = os.path.join(os.path.dirname(txt_file), 'treetagger_output')
        os.makedirs(treetagger_output_dir, exist_ok=True)
        
        # Define paths
        temp_text_file_path = os.path.join(treetagger_output_dir, os.path.basename(txt_file).replace('.txt', '_words.txt'))
        treetagger_output_path = os.path.join(treetagger_output_dir, os.path.basename(txt_file).replace('.txt', '_treetagger_output.txt'))
        json_output_path = os.path.join(treetagger_output_dir, os.path.basename(txt_file).replace('.txt', '_output.json'))

        # Extract text and metadata
        df = extract_text_from_file(txt_file)
        if df is not None:
            video_id, publish_date, video_title, content_start, content_end = extract_metadata_and_content(df)
            if content_start is not None and content_end is not None:
                # Extract the content between <doc> and </doc>
                content = ' '.join(df.iloc[content_start:content_end][0].tolist())

                # Write words to file
                write_words_to_file(content, temp_text_file_path)

                # Run TreeTagger
                run_treetagger(temp_text_file_path, treetagger_output_path)

                # Parse TreeTagger output
                treetagger_data = parse_treetagger_output(treetagger_output_path)

                # Save metadata and structured TreeTagger output as JSON
                metadata = {
                    'video_id': video_id,
                    'publish_date': publish_date,
                    'video_title': video_title
                }
                save_as_json(metadata, treetagger_data, json_output_path)

                # Clean up temporary file
                os.remove(temp_text_file_path)
            else:
                print(f"No content found between <doc> tags in file: {txt_file}")
        else:
            print(f"Error processing file: {txt_file}")

# Example usage
directory_path = 'data/en_AJ/'  # Root directory containing subfolders with .txt files
process_files(directory_path)
# Out:
# Tokens have been successfully written to data/en_AJ\treetagger_output\'apocalyptic' conditions aid agencies warn of humanitarian catastrophe_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'apocalyptic' conditions aid agencies warn of humanitarian catastrophe_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'apocalyptic' conditions aid agencies warn of humanitarian catastrophe_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'blood on his hands' palestine supporters gatecrash biden event_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'blood on his hands' palestine supporters gatecrash biden event_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'blood on his hands' palestine supporters gatecrash biden event_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'bombing all around us', says gaza’s nasser hospital doctor_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'bombing all around us', says gaza’s nasser hospital doctor_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'bombing all around us', says gaza’s nasser hospital doctor_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'carpet bombing' in jabalia dozens buried under debris after israeli attacks_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'carpet bombing' in jabalia dozens buried under debris after israeli attacks_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'carpet bombing' in jabalia dozens buried under debris after israeli attacks_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'extreme fear and endless anxiety' as israel moves into rafah_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'extreme fear and endless anxiety' as israel moves into rafah_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'extreme fear and endless anxiety' as israel moves into rafah_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'for blinken, the us doesn't have double standards, only one israeli standard' marwan bishara_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'for blinken, the us doesn't have double standards, only one israeli standard' marwan bishara_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'for blinken, the us doesn't have double standards, only one israeli standard' marwan bishara_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'for israel, gaza is the greater challenge, west bank is the bigger prize' marwan bishara_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'for israel, gaza is the greater challenge, west bank is the bigger prize' marwan bishara_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'for israel, gaza is the greater challenge, west bank is the bigger prize' marwan bishara_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'i am so proud to be from gaza' resident_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'i am so proud to be from gaza' resident_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'i am so proud to be from gaza' resident_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'i'm not just a number’ doha art installation commemorates over 15,000 children killed in gaza_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'i'm not just a number’ doha art installation commemorates over 15,000 children killed in gaza_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'i'm not just a number’ doha art installation commemorates over 15,000 children killed in gaza_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'it’s immoral' un special rapporteur on unrwa funding cuts  upfront_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'it’s immoral' un special rapporteur on unrwa funding cuts  upfront_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'it’s immoral' un special rapporteur on unrwa funding cuts  upfront_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'make no mistake, the full-scale assault on rafah would be a human catastrophe' guterres_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'make no mistake, the full-scale assault on rafah would be a human catastrophe' guterres_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'make no mistake, the full-scale assault on rafah would be a human catastrophe' guterres_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'our home destroyed, education disrupted' gaza student's struggle during war_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'our home destroyed, education disrupted' gaza student's struggle during war_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'our home destroyed, education disrupted' gaza student's struggle during war_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'systematically' violating war laws un rights office report examines six israeli attacks_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'systematically' violating war laws un rights office report examines six israeli attacks_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'systematically' violating war laws un rights office report examines six israeli attacks_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'the most dangerous words for a middle easterner are the american words trust us' marwan bishara_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'the most dangerous words for a middle easterner are the american words trust us' marwan bishara_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'the most dangerous words for a middle easterner are the american words trust us' marwan bishara_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'this war must stop, palestinian right to self-determination must be recognised’ un chief_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'this war must stop, palestinian right to self-determination must be recognised’ un chief_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'this war must stop, palestinian right to self-determination must be recognised’ un chief_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'unparalleled & unprecedented' un secretary general condemns civilian deaths_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'unparalleled & unprecedented' un secretary general condemns civilian deaths_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'unparalleled & unprecedented' un secretary general condemns civilian deaths_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'we europeans created the problem' analyst holds europe accountable for israel-gaza war_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'we europeans created the problem' analyst holds europe accountable for israel-gaza war_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'we europeans created the problem' analyst holds europe accountable for israel-gaza war_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'we will never leave our house, even if they kill us' gaza resident_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'we will never leave our house, even if they kill us' gaza resident_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'we will never leave our house, even if they kill us' gaza resident_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'western leaders exposed as netanyahu's 'useful idiots' in backing genocidal war' bishara_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'western leaders exposed as netanyahu's 'useful idiots' in backing genocidal war' bishara_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'western leaders exposed as netanyahu's 'useful idiots' in backing genocidal war' bishara_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\'you don't know if you're going to live or die' gaza resident_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\'you don't know if you're going to live or die' gaza resident_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\'you don't know if you're going to live or die' gaza resident_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\1,030 of the palestinians killed in gaza are children, more than a third of total deaths_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\1,030 of the palestinians killed in gaza are children, more than a third of total deaths_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\1,030 of the palestinians killed in gaza are children, more than a third of total deaths_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\1,200 children still buried under debris ministry_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\1,200 children still buried under debris ministry_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\1,200 children still buried under debris ministry_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\100 days of war on gaza displaced palestinians feel forgotten_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\100 days of war on gaza displaced palestinians feel forgotten_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output
words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\a third convoy of aid trucks carrying food & medical supplies is entering gaza from egypt_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\a third convoy of aid trucks carrying food & medical supplies is entering gaza from egypt_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\a very difficult scene in southern gaza after killing of aid seekers_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\a very difficult scene in southern gaza after killing of aid seekers_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\a very difficult scene in southern gaza after killing of aid seekers_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\a young israeli man has been jailed for refusing mandatory service_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\a young israeli man has been jailed for refusing mandatory service_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\a young israeli man has been jailed for refusing mandatory service_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\abbas lays down condition for palestinian authority to return to gaza_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\abbas lays down condition for palestinian authority to return to gaza_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\abbas lays down condition for palestinian authority to return to gaza_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\abbas’s meeting with qatari emir is an attempt to maintain relevancy analysis_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\abbas’s meeting with qatari emir is an attempt to maintain relevancy analysis_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\abbas’s meeting with qatari emir is an attempt to maintain relevancy analysis_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\accelerated israeli settler land grabs since the start of israel's war on gaza in october_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\accelerated israeli settler land grabs since the start of israel's war on gaza in october_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\accelerated israeli settler land grabs since the start of israel's war on gaza in october_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\activists challenge claims of anti-semitism_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\activists challenge claims of anti-semitism_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\activists challenge claims of anti-semitism_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\activist’s killing likely to complicate ties between turkey and israel political analyst_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\activist’s killing likely to complicate ties between turkey and israel political analyst_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\activist’s killing likely to complicate ties between turkey and israel political analyst_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aerial strikes target jabalia  mosque and houses hit in latest israeli raid_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aerial strikes target jabalia  mosque and houses hit in latest israeli raid_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aerial strikes target jabalia  mosque and houses hit in latest israeli raid_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aftermath of israeli air strike on gaza's al-tabin school destruction, grief and desperation_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aftermath of israeli air strike on gaza's al-tabin school destruction, grief and desperation_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aftermath of israeli air strike on gaza's al-tabin school destruction, grief and desperation_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aftermath of israeli bombs central gaza devastated by relentless air strikes_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aftermath of israeli bombs central gaza devastated by relentless air strikes_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aftermath of israeli bombs central gaza devastated by relentless air strikes_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aftermath of overnight israeli strike children rescued from gaza rubble_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aftermath of overnight israeli strike children rescued from gaza rubble_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aftermath of overnight israeli strike children rescued from gaza rubble_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\ahed tamimi released prominent palestinian activist among those free_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\ahed tamimi released prominent palestinian activist among those free_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\ahed tamimi released prominent palestinian activist among those free_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aid agencies land routes are more effective_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aid agencies land routes are more effective_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aid agencies land routes are more effective_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aid agencies say the flow of humanitarian aid through the rafah crossing has been halted_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aid agencies say the flow of humanitarian aid through the rafah crossing has been halted_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aid agencies say the flow of humanitarian aid through the rafah crossing has been halted_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aid convoy strike israeli army says two officers dismissed_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aid convoy strike israeli army says two officers dismissed_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aid convoy strike israeli army says two officers dismissed_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aid corridor a ‘convenient second choice’ for biden_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aid corridor a ‘convenient second choice’ for biden_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aid corridor a ‘convenient second choice’ for biden_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aid for israeli captives and palestinian civilians arrives in gaza_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aid for israeli captives and palestinian civilians arrives in gaza_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aid for israeli captives and palestinian civilians arrives in gaza_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aid group fears famine-like conditions may already be present in south gaza_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aid group fears famine-like conditions may already be present in south gaza_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aid group fears famine-like conditions may already be present in south gaza_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\aid ship delayed israel creates 'administrative roadblock'_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\aid ship delayed israel creates 'administrative roadblock'_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\aid ship delayed israel creates 'administrative roadblock'_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\a
treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\al jazeera journalist ismail abu omar was seriously injured by an israeli drone on tuesday_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\al jazeera journalists wounded in khan younis_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\al jazeera journalists wounded in khan younis_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\al jazeera journalists wounded in khan younis_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\al jazeera reporter, cameraman, critically injured by israeli drone strike in rafah_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\al jazeera reporter, cameraman, critically injured by israeli drone strike in rafah_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\al jazeera reporter, cameraman, critically injured by israeli drone strike in rafah_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\al jazeera reporter’s family receives israeli threat to leave gaza home_words.txt
# ...
# TreeTagger output has been written to data/en_AJ\treetagger_output\top un court issues ruling icj orders israel to end its rafah offensive_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\top un court issues ruling icj orders israel to end its rafah offensive_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\top un court orders action on aid israel told to ensure unhindered food delivery_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\top un court orders action on aid israel told to ensure unhindered food delivery_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\top un court orders action on aid israel told to ensure unhindered food delivery_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\tor wennesland gaza talks in doha key for palestinians and israelis  talk to al jazeera_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\tor wennesland gaza talks in doha key for palestinians and israelis  talk to al jazeera_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\tor wennesland gaza talks in doha key for palestinians and israelis  talk to al jazeera_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\trauma of war will have long-term impact on gaza, says ngo_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\trauma of war will have long-term impact on gaza, says ngo_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\trauma of war will have long-term impact on gaza, says ngo_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\treacherous journey south mother and her newborn displaced from home_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\treacherous journey south mother and her newborn displaced from home_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\treacherous journey south mother and her newborn displaced from home_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\treating gaza's injured doctor says he witnessed israeli war crimes_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\treating gaza's injured doctor says he witnessed israeli war crimes_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\treating gaza's injured doctor says he witnessed israeli war crimes_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\tribal aid workers targeted in gaza city, 23 killed_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\tribal aid workers targeted in gaza city, 23 killed_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\tribal aid workers targeted in gaza city, 23 killed_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\troops and heavy weaponry mass at gaza border_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\troops and heavy weaponry mass at gaza border_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\troops and heavy weaponry mass at gaza border_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\truce respite palestinians reflect on life in conflict_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\truce respite palestinians reflect on life in conflict_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\truce respite palestinians reflect on life in conflict_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\turkey buries us activist killed by israel in occupied west bank_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\turkey buries us activist killed by israel in occupied west bank_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\turkey buries us activist killed by israel in occupied west bank_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\turkey imposes export restrictions; israel threatens retaliation_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\turkey imposes export restrictions; israel threatens retaliation_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\turkey imposes export restrictions; israel threatens retaliation_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\turkey might enter israel to help palestinians erdogan_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\turkey might enter israel to help palestinians erdogan_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\turkey might enter israel to help palestinians erdogan_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\turkey protest demonstration against us support for israel_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\turkey protest demonstration against us support for israel_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\turkey protest demonstration against us support for israel_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\turkey submits request to join south africa's icj genocide case against israel_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\turkey submits request to join south africa's icj genocide case against israel_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\turkey submits request to join south africa's icj genocide case against israel_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\turkey, iran agree on need to avoid escalating mideast tensions -erdogan_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\turkey, iran agree on need to avoid escalating mideast tensions -erdogan_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\turkey, iran agree on need to avoid escalating mideast tensions -erdogan_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\turkey’s erdogan tells pro-palestinian rally israel is ‘an occupier’_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\turkey’s erdogan tells pro-palestinian rally israel is ‘an occupier’_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\turkey’s erdogan tells pro-palestinian rally israel is ‘an occupier’_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\turkish president calls for two-state solution_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\turkish president calls for two-state solution_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\turkish president calls for two-state solution_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\turkish president recep tayyip erdogan calls for immediate ceasefire in gaza_words.txt
# TreeTagger output has been written to data/en_AJ\treetagger_output\turkish president recep tayyip erdogan calls for immediate ceasefire in gaza_treetagger_output.txt
# Data has been successfully written to data/en_AJ\treetagger_output\turkish president recep tayyip erdogan calls for immediate ceasefire in gaza_output.json
# Tokens have been successfully written to data/en_AJ\treetagger_output\tur