# %%
import os
import pandas as pd
import re
from collections import Counter

# Path to the folder containing the .txt files
folder_path = "data/en_DW/treetagger_output/"

# Define the column you're interested in and the terms you're looking for
column_index = 1  # Adjusted to the second column
first_term = r'VBD|VBN'
second_term = r'VVN'

# Function to extract metadata (video_id and publish_date)
def extract_metadata(df):
    video_id = None
    publish_date = None

    # Iterate through the first few rows to find metadata
    for index, row in df.iterrows():
        if '<video_id>' in row.iloc[0]:
            video_id = re.search(r'<video_id>(.*?)</video_id>', row.iloc[0]).group(1)
        if '<publish_date>' in row.iloc[0]:
            publish_date = re.search(r'<publish_date>(.*?)</publish_date>', row.iloc[0]).group(1)
        # Break out once both are found
        if video_id and publish_date:
            break

    return video_id, publish_date

# Dictionary to store the results for each file
results = []

# Variables to accumulate totals
total_passive_voice_count = 0
total_rows = 0

# Counters to store the frequency of strings in VVN and VBD/VBN sequences
vvn_strings_counter = Counter()
preceding_strings_counter = Counter()  # For the strings before VBD/VBN

# Loop through all files in the folder
for file_name in os.listdir(folder_path):
    # Check if the file is a .txt file
    if file_name.endswith(".txt"):
        # Construct the full file path
        file_path = os.path.join(folder_path, file_name)

        # Read the .txt file (tab-delimited) with no headers and assign column names
        df = pd.read_csv(file_path, delimiter="\t", header=None, names=["col1", "col2", "col3"])

        # Extract metadata (video_id, publish_date)
        video_id, publish_date = extract_metadata(df)

        # Count occurrences of the sequence VBD/VBN followed by VVN (indicating passive voice)
        file_total_rows = len(df)  # Total number of rows in the file
        file_passive_voice_count = 0
        vvn_strings = []  # List to store the strings in column 3 of the VVN rows
        preceding_strings = []  # List to store the preceding strings based on VBD/VBN rules

        # Iterate through the DataFrame to find the sequence
        for i in range(file_total_rows - 1):  # Loop through each row except the last one
            # Safely convert the values to strings and avoid NaN values
            current_value = str(df.iloc[i, column_index]) if pd.notna(df.iloc[i, column_index]) else ""
            next_value = str(df.iloc[i + 1, column_index]) if pd.notna(df.iloc[i + 1, column_index]) else ""

            # Check if the current row matches VBD or VBN, and the next row matches VVN (indicating passive voice)
            if re.match(first_term, current_value) and re.match(second_term, next_value):
                file_passive_voice_count += 1

                # Collect the string from the row of VVN
                vvn_strings.append(df.iloc[i + 1, 0])  # Store the string from column 1 of the VVN row

                # Collect the preceding string based on whether it's VBD or VBN
                if re.match(r'VBD', current_value):  # For VBD: 1 row and 1 column before
                    if i - 1 >= 0:
                        preceding_strings.append(df.iloc[i - 1, 0])  # String 1 row and 1 column before
                elif re.match(r'VBN', current_value):  # For VBN: 2 rows and 1 column before
                    if i - 2 >= 0:
                        preceding_strings.append(df.iloc[i - 2, 0])  # String 2 rows and 1 column before

        # Calculate instances per million (IPM)
        file_relative_frequency_ipm = (file_passive_voice_count / file_total_rows) * 1_000_000 if file_total_rows > 0 else 0

        # Accumulate totals
        total_passive_voice_count += file_passive_voice_count
        total_rows += file_total_rows

        # Update the counters for VVN strings and preceding strings
        vvn_strings_counter.update(vvn_strings)
        preceding_strings_counter.update(preceding_strings)

        # Store the result in a list
        results.append({
            "video_id": video_id,
            "publish_date": publish_date,
            "passive_voice_count": file_passive_voice_count,
            "relative_frequency_ipm": file_relative_frequency_ipm,
            "vvn_strings": vvn_strings,  # Add the list of VVN strings for this file
            "preceding_strings": preceding_strings  # Add the list of preceding strings for VBD/VBN
        })

# Calculate total relative frequency in IPM
total_relative_frequency_ipm = (total_passive_voice_count / total_rows) * 1_000_000 if total_rows > 0 else 0

# Create a DataFrame to store the results
results_df = pd.DataFrame(results)

# Convert list of VVN strings and preceding strings into comma-separated strings for easier viewing in the DataFrame
results_df['vvn_strings'] = results_df['vvn_strings'].apply(lambda x: ', '.join(x))
results_df['preceding_strings'] = results_df['preceding_strings'].apply(lambda x: ', '.join(x))

# Save the DataFrame to a CSV file
csv_output_path = "passive_voice_results_with_vvn_and_preceding_strings.csv"
results_df.to_csv(csv_output_path, index=False)  # This will include both VVN and preceding strings

# Print out the results for each file
for result in results:
    print(f"Video ID: {result['video_id']}, "
          f"Publish Date: {result['publish_date']}, Passive Voice Count: {result['passive_voice_count']}, "
          f"Relative Frequency (IPM): {result['relative_frequency_ipm']:.2f}, VVN Strings: {result['vvn_strings']}, "
          f"Preceding Strings: {result['preceding_strings']}")

# Print total counts and frequencies
print(f"\nTotal Passive Voice Count: {total_passive_voice_count}")
print(f"Total Relative Frequency (IPM): {total_relative_frequency_ipm:.2f}")

# Print the top 10 most common VVN strings
print("\nTop 10 most common VVN strings and their frequencies:")
for string, count in vvn_strings_counter.most_common(10):
    print(f"{string}: {count}")

# Print the top 10 most common preceding strings
print("\nTop 10 most common preceding strings and their frequencies:")
for string, count in preceding_strings_counter.most_common(10):
    print(f"{string}: {count}")
# Out:
# Video ID: _7NksAcG_l8, Publish Date: 20240714, Passive Voice Count: 5, Relative Frequency (IPM): 4901.96, VVN Strings: ['taken', 'impacted', 'killed', 'taken', 'bombed'], Preceding Strings: ['casualties', 'children', 'one', 'they', 'attack']
# Video ID: RDLZkqqOaLM, Publish Date: 20240726, Passive Voice Count: 3, Relative Frequency (IPM): 1515.92, VVN Strings: ['glued', 'set', 'supposed'], Preceding Strings: ['stores', 'negotiations', 'That']
# Video ID: cSMPo4XCSYU, Publish Date: 20231117, Passive Voice Count: 12, Relative Frequency (IPM): 3538.78, VVN Strings: ['prepared', 'released', 'hidden', 'confirmed', 'told', 'taken', 'taken', 'killed', 'killed', 'killed', 'found', 'butchered'], Preceding Strings: ['that', 'footage', 'says', "that's", 'north', '7th', 'she', 'people', 'Palestinians', 'that', 'that', 'that']
# Video ID: fhwhQhoKVhk, Publish Date: 20231220, Passive Voice Count: 11, Relative Frequency (IPM): 3378.38, VVN Strings: ['made', 'killed', 'killed', 'killed', 'killed', 'circulated', 'circulated', 'suspended', 'believed', 'confirmed', 'called'], Preceding Strings: ['that', 'Palestinians', 'civilians', 'grandkids', 'Palestinians', 'detainees', 'that', 'video', 'who', 'has', 'that']
# Video ID: QG9QSHEgX6E, Publish Date: 20231107, Passive Voice Count: 11, Relative Frequency (IPM): 4066.54, VVN Strings: ['described', 'killed', 'mentioned', 'mentioned', 'killed', 'displaced', 'killed', 'killed', 'restored', 'reconnected', 'noted'], Preceding Strings: ['as', 'people', 'this', 'this', 'people', "You'", 'children', 'who', 'Communications', 'it', 'that']
# Video ID: l5pL2DhnjEE, Publish Date: 20231121, Passive Voice Count: 8, Relative Frequency (IPM): 3796.87, VVN Strings: ['killed', 'taken', 'taken', 'murdered', 'found', 'confined', 'released', 'rescued'], Preceding Strings: ['family', 'members', 'they', 'mother', 'bodies', 'terror', 'hostages', 'one']
# Video ID: o0arAFe0WmE, Publish Date: 20231103, Passive Voice Count: 16, Relative Frequency (IPM): 5079.37, VVN Strings: ['left', 'taken', 'started', 'held', 'released', 'killed', 'released', 'released', 'born', 'murdered', 'kidnapped', 'managed', 'dismembered', 'injured', 'built', 'created'], Preceding Strings: ['bear', 'they', 'there', 'who', 'sharit', 'hostage', 'who', 'they', 'she', 'daughter', 'to', 'gal', 'they', 'they', 'country', 'beings']
# Video ID: FYck1QG52I0, Publish Date: 20231019, Passive Voice Count: 1, Relative Frequency (IPM): 1049.32, VVN Strings: ['agreed'], Preceding Strings: ["shouldn't"]
# Video ID: xSgxVYaNfXg, Publish Date: 20231120, Passive Voice Count: 12, Relative Frequency (IPM): 5167.96, VVN Strings: ['killed', 'heard', 'seen', 'fired', 'told', 'asked', 'taken', 'trapped', 'brought', 'reassured', 'shifted', 'brought'], Preceding Strings: ['people', 'fighting', 'flares', 'sh', 'had', 'I', 'they', 'babies', 'babies', 'I', 'them', 'that']
# Video ID: 7qxY2fjvGhE, Publish Date: 20231027, Passive Voice Count: 2, Relative Frequency (IPM): 1937.98, VVN Strings: ['received', 'held'], Preceding Strings: ['terror', 'who']
# Video ID: lH3jvaO1wXc, Publish Date: 20240221, Passive Voice Count: 6, Relative Frequency (IPM): 8064.52, VVN Strings: ['killed', 'targeted', 'killed', 'held', 'accused', 'bombed'], Preceding Strings: ['journalists', "they've", 'journalists', 'had', 'Israel', 'have']
# Video ID: we2YBYfeL58, Publish Date: 20231015, Passive Voice Count: 4, Relative Frequency (IPM): 3868.47, VVN Strings: ['flattened', 'sent', 'held', 'caught'], Preceding Strings: ['buildings', 'we', 'militants', 'military']
# Video ID: xjeZ0ot9I_Q, Publish Date: 20240103, Passive Voice Count: 7, Relative Frequency (IPM): 4281.35, VVN Strings: ['killed', 'carried', 'known', 'told', 'planned', 'killed', 'killed'], Preceding Strings: ['others', 'attack', 'uh', 'Parliament', 'that', 'that', 'who']
# Video ID: JwTjZs1kkzI, Publish Date: 20231205, Passive Voice Count: 11, Relative Frequency (IPM): 6037.32, VVN Strings: ['told', 'driven', 'engaged', 'asked', 'released', 'bombed', 'bombed', 'pushed', 'bombed', 'killed', 'killed'], Preceding Strings: ['gazin', 'population', 'they', 'uh', 'who', 'we', 'um', 'that', 'people', 'been', 'colleagues']
# Video ID: BIF4B4s1WWk, Publish Date: 20240406, Passive Voice Count: 4, Relative Frequency (IPM): 3536.69, VVN Strings: ['affected', 'displaced', 'permitted', 'banned'], Preceding Strings: ['aid', 'we', 'that', 'we']
# Video ID: EEMrHbVn-x4, Publish Date: 20231110, Passive Voice Count: 6, Relative Frequency (IPM): 1479.29, VVN Strings: ['attacked', 'pushed', 'designated', 'injured', 'subjected', 'offered'], Preceding Strings: ['forces', 'that', 'that', 'drivers', 'have', 'that']
# Video ID: 2S1Jq58-Krs, Publish Date: 20240407, Passive Voice Count: 22, Relative Frequency (IPM): 10742.19, VVN Strings: ['killed', 'kidnapped', 'murdered', 'shot', 'appointed', 'kidnapped', 'kidnapped', 'murdered', 'kidnapped', 'kidnapped', 'released', 'done', 'Overjoyed', 'released', 'kidnapped', 'released', 'happened', 'murdered', 'locked', 'released', 'shut', 'saved'], Preceding Strings: ['kerit', 'yardan', 'them', 'misses', 'that', 'that', 'that', 'K', 'Kam', 'that', 'and', 'what', 'must', 'wife', 'that', 'that', 'that', 'that', 'they', 'they', 'door', 'could']
# Video ID: HkhyP7-LCw8, Publish Date: 20231124, Passive Voice Count: 18, Relative Frequency (IPM): 6147.54, VVN Strings: ['freed', 'freed', 'released', 'released', 'released', 'released', 'released', 'broken', 'released', 'released', 'taken', 'concerned', 'released', 'summoned', 'involved', 'convicted', 'agreed', 'held'], Preceding Strings: ['have', 'who', 'pictures', 'names', 'uh', 'that', 'they', 'that', 'that', 'citizens', 'some', 'author', 'hostages', 'they', 'who', 'Terror', 'will', 'who']
# Video ID: Cd4DHesX1sU, Publish Date: 20231126, Passive Voice Count: 3, Relative Frequency (IPM): 2676.18, VVN Strings: ['displaced', 'exposed', 'delivered'], Preceding Strings: ['many', 'we', 'trucks']
# Video ID: wzrFCDo-QXY, Publish Date: 20240702, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: D-W-DL3AJcI, Publish Date: 20240622, Passive Voice Count: 1, Relative Frequency (IPM): 1652.89, VVN Strings: ['destroyed'], Preceding Strings: ['infrastructure']
# Video ID: Y52gkXzJgtk, Publish Date: 20240803, Passive Voice Count: 4, Relative Frequency (IPM): 5354.75, VVN Strings: ['told', 'changed', 'killed', 'killed'], Preceding Strings: ['Nationals', 'have', 'Wing', 'Palestinians']
# Video ID: vuTUeoxRxKA, Publish Date: 20231115, Passive Voice Count: 7, Relative Frequency (IPM): 4572.18, VVN Strings: ['discovered', 'treated', 'invaded', 'exploded', 'used', 'taken', 'affected'], Preceding Strings: ['devices', 'who', 'Israeli', 'scan', 'hospital', 'hostages', 'who']
# Video ID: 8zB4HN2h01I, Publish Date: 20240731, Passive Voice Count: 8, Relative Frequency (IPM): 2060.79, VVN Strings: ['killed', 'supposed', 'killed', 'founded', 'arrested', 'exiled', 'seen', 'killed'], Preceding Strings: ['Hamas', 'It', 'bodyguard', 'it', 'and', 'Hano', 'Ania', 'grandchildren']
# Video ID: kdfIJyfhbwI, Publish Date: 20240220, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: PdVMtjFu5Uc, Publish Date: 20240123, Passive Voice Count: 6, Relative Frequency (IPM): 2429.15, VVN Strings: ['leveled', 'told', 'subjected', 'killed', 'focused', 'subjected'], Preceding Strings: ['accusation', 'I', 'hanun', 'people', 'military', 'Gaza']
# Video ID: ltul06q2pd0, Publish Date: 20231101, Passive Voice Count: 17, Relative Frequency (IPM): 9209.10, VVN Strings: ['targeted', 'killed', 'struck', 'allowed', 'injured', 'allowed', 'released', 'struck', 'created', 'struck', 'killed', 'injured', 'killed', 'injured', 'allowed', 'sent', 'approved'], Preceding Strings: ['Commander', 'people', 'what', 'have', 'civilians', 'gazin', 'that', 'it', 'that', 'it', 'people', 'hundreds', 'least', 'were', 'people', 'where', 'were']
# Video ID: lvhBl-GjKwA, Publish Date: 20240108, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: SB5_vNQgTKs, Publish Date: 20231012, Passive Voice Count: 11, Relative Frequency (IPM): 4504.50, VVN Strings: ['forced', 'killed', 'crushed', 'treated', 'displayed', 'taken', 'killed', 'touched', 'committed', 'killed', 'lost'], Preceding Strings: ['people', 'people', 'Isis', 'Isis', 'that', 'that', 'them', 'know', 'that', 'who', 'that']
# Video ID: P7vXJY21Fow, Publish Date: 20240419, Passive Voice Count: 1, Relative Frequency (IPM): 1015.23, VVN Strings: ['issued'], Preceding Strings: ['that']
# Video ID: DVTYyvQvLTM, Publish Date: 20240104, Passive Voice Count: 3, Relative Frequency (IPM): 3128.26, VVN Strings: ['killed', 'caused', 'evacuated'], Preceding Strings: ['official', 'it', 'that']
# Video ID: hQ4fJ1Ey4rU, Publish Date: 20240118, Passive Voice Count: 7, Relative Frequency (IPM): 2875.92, VVN Strings: ['loaded', 'lost', 'preserved', 'set', 'armed', 'set', 'floated'], Preceding Strings: ['that', '1,500', 'have', 'know', 'group', 'things', 'that']
# Video ID: BfMO5snTG2I, Publish Date: 20240221, Passive Voice Count: 2, Relative Frequency (IPM): 1759.01, VVN Strings: ['killed', 'displaced'], Preceding Strings: ['journalists', 'Gaza']
# Video ID: VrgBQlq9w_o, Publish Date: 20240416, Passive Voice Count: 5, Relative Frequency (IPM): 3103.66, VVN Strings: ['damaged', 'designed', 'seen', 'put', 'lifted'], Preceding Strings: ['ter', 'that', 'weekend', 'have', 'they']
# Video ID: SigTwH0T5KY, Publish Date: 20231117, Passive Voice Count: 2, Relative Frequency (IPM): 883.00, VVN Strings: ['cancelled', 'sponsored'], Preceding Strings: ['bookings', 'they']
# Video ID: KTJ38RPZlGs, Publish Date: 20240115, Passive Voice Count: 2, Relative Frequency (IPM): 5305.04, VVN Strings: ['killed', 'marked'], Preceding Strings: ['people', 'day']
# Video ID: bG1PL37OAiM, Publish Date: 20231130, Passive Voice Count: 9, Relative Frequency (IPM): 5813.95, VVN Strings: ['killed', 'posted', 'killed', 'extended', 'brought', 'released', 'treated', 'abducted', 'taken'], Preceding Strings: ['people', 'attack', 'suspects', 'militants', 'truth', 'dead', 'she', 'she', 'she']
# Video ID: onUWmPAb6Fw, Publish Date: 20240205, Passive Voice Count: 1, Relative Frequency (IPM): 524.38, VVN Strings: ['accused'], Preceding Strings: ['Iran']
# Video ID: HtIa2H9MU-4, Publish Date: 20240406, Passive Voice Count: 2, Relative Frequency (IPM): 7168.46, VVN Strings: ['seen', 'built'], Preceding Strings: ['had', 'which']
# Video ID: BqFOwduKHSA, Publish Date: 20240527, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: X7SqqvhmyaM, Publish Date: 20231222, Passive Voice Count: 9, Relative Frequency (IPM): 6401.14, VVN Strings: ['described', 'displaced', 'damaged', 'damaged', 'killed', 'injured', 'wiped', 'flattened', 'called'], Preceding Strings: ['7th', 'population', 'by', 'neighborhoods', 'people', 'course', 'Hamas', 'Gaza', 'past']
# Video ID: IUTqD0xWG5A, Publish Date: 20231026, Passive Voice Count: 4, Relative Frequency (IPM): 2196.60, VVN Strings: ['written', 'announced', 'exposed', 'taken'], Preceding Strings: ['mean', 'government', 'that', 'that']
# Video ID: V2IX9tnzhyI, Publish Date: 20240306, Passive Voice Count: 1, Relative Frequency (IPM): 964.32, VVN Strings: ['dropped'], Preceding Strings: ['meals']
# Video ID: 87jeUSQ8jHg, Publish Date: 20240610, Passive Voice Count: 2, Relative Frequency (IPM): 2906.98, VVN Strings: ['expected', 'displaced'], Preceding Strings: ['resignation', 'that']
# Video ID: sjbwH5MKwtI, Publish Date: 20231022, Passive Voice Count: 2, Relative Frequency (IPM): 1241.46, VVN Strings: ['taken', 'asked'], Preceding Strings: ['who', 'that']
# Video ID: Cjh8TtaifyY, Publish Date: 20240213, Passive Voice Count: 3, Relative Frequency (IPM): 1749.27, VVN Strings: ['compressed', 'made', 'destroyed'], Preceding Strings: ['Palestinians', 'nothing', 'strip']
# Video ID: YQCy4mFyH54, Publish Date: 20231020, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: _Uzi8jSAkE4, Publish Date: 20240817, Passive Voice Count: 4, Relative Frequency (IPM): 2450.98, VVN Strings: ['informed', 'targeted', 'released', 'killed'], Preceding Strings: ['they', 'leaders', 'which', 'people']
# Video ID: kQhahxoGMl0, Publish Date: 20240105, Passive Voice Count: 5, Relative Frequency (IPM): 2077.27, VVN Strings: ['caught', 'voiced', 'heard', 'brought', 'destroyed'], Preceding Strings: ['it', 'that', 'um', 'which', 'Israel']
# Video ID: QKweW3yiG-U, Publish Date: 20240818, Passive Voice Count: 3, Relative Frequency (IPM): 3198.29, VVN Strings: ['killed', 'fired', 'made'], Preceding Strings: ['people', 'Rockets', 'is']
# Video ID: 6CVqQiPDJzM, Publish Date: 20240109, Passive Voice Count: 1, Relative Frequency (IPM): 370.10, VVN Strings: ['displaced'], Preceding Strings: ['population']
# Video ID: J208Jszbnp0, Publish Date: 20240611, Passive Voice Count: 1, Relative Frequency (IPM): 1371.74, VVN Strings: ['concerned'], Preceding Strings: ['US']
# Video ID: XxCOzdpwKX8, Publish Date: 20231103, Passive Voice Count: 9, Relative Frequency (IPM): 2713.30, VVN Strings: ['strengthened', 'evacuated', 'forced', 'killed', 'hit', 'damaged', 'impacted', 'damaged', 'killed'], Preceding Strings: ["it's", 'who', 'people', 'she', "you've", 'infrastructure', 'they', 'people', 'who']
# Video ID: 8HPzQxnqNz0, Publish Date: 20231016, Passive Voice Count: 1, Relative Frequency (IPM): 965.25, VVN Strings: ['aimed'], Preceding Strings: ['that']
# Video ID: XDAVCAoFuto, Publish Date: 20240429, Passive Voice Count: 1, Relative Frequency (IPM): 809.06, VVN Strings: ['cancelled'], Preceding Strings: ['Rafa']
# Video ID: cAW0jx0WDOA, Publish Date: 20240819, Passive Voice Count: 5, Relative Frequency (IPM): 5219.21, VVN Strings: ['put', 'presented', 'closed', 'accused', 'asked'], Preceding Strings: ['that', 'that', 'that', 'Netanyahu', 'people']
# Video ID: 0rdutewdOB8, Publish Date: 20240107, Passive Voice Count: 1, Relative Frequency (IPM): 1219.51, VVN Strings: ['killed'], Preceding Strings: ['Palestinians']
# Video ID: MNl2XPJI1kc, Publish Date: 20240205, Passive Voice Count: 6, Relative Frequency (IPM): 6329.11, VVN Strings: ['killed', 'surprised', 'released', 'laid', 'set', 'set'], Preceding Strings: ['Palestinians', 'we', 'footage', 'that', 'uh', 'framework']
# Video ID: NC0G3GwQgTM, Publish Date: 20240321, Passive Voice Count: 1, Relative Frequency (IPM): 1024.59, VVN Strings: ['declared'], Preceding Strings: ['famine']
# Video ID: -SfSJIFcFsU, Publish Date: 20231106, Passive Voice Count: 1, Relative Frequency (IPM): 722.02, VVN Strings: ['heated'], Preceding Strings: ['has']
# Video ID: yXWX1P6Lc98, Publish Date: 20240429, Passive Voice Count: 4, Relative Frequency (IPM): 2230.90, VVN Strings: ['bombed', 'displaced', 'killed', 'closed'], Preceding Strings: ['house', 'Martyrs', 'displaced', 'portion']
# Video ID: fHDZbWWX-as, Publish Date: 20240725, Passive Voice Count: 4, Relative Frequency (IPM): 3303.06, VVN Strings: ['arrested', 'conducted', 'postponed', 'agreed'], Preceding Strings: ['several', 'that', 'trip', 'framework']
# Video ID: MUPktKGykPY, Publish Date: 20240730, Passive Voice Count: 3, Relative Frequency (IPM): 3293.08, VVN Strings: ['heard', 'targeted', 'killed'], Preceding Strings: ['uh', 'that', 'civilian']
# Video ID: YfCVbWKaqHQ, Publish Date: 20240205, Passive Voice Count: 1, Relative Frequency (IPM): 775.19, VVN Strings: ['mixed'], Preceding Strings: ['far']
# Video ID: GQVgo-d8I_Q, Publish Date: 20240818, Passive Voice Count: 1, Relative Frequency (IPM): 1256.28, VVN Strings: ['killed'], Preceding Strings: ['family']
# Video ID: vhIw-_FHGYg, Publish Date: 20231028, Passive Voice Count: 4, Relative Frequency (IPM): 6968.64, VVN Strings: ['solved', 'cancelled', 'thrown', 'detained'], Preceding Strings: ['that', 'groups', 'fireworks', 'people']
# Video ID: UFKgle1hpyA, Publish Date: 20240417, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: j5t7IF4yxQM, Publish Date: 20240626, Passive Voice Count: 26, Relative Frequency (IPM): 1777.29, VVN Strings: ['taken', 'involved', 'announced', 'killed', 'followed', 'formed', 'ramped', 'evacuated', 'evacuated', 'sent', 'relieved', 'conceived', 'founded', 'killed', 'killed', 'defeated', 'affected', 'killed', 'formed', 'ignored', 'used', 'killed', 'killed', 'killed', 'killed', 'killed'], Preceding Strings: ['so', 'um', 'this', 'Fighters', 'this', 'it', 'Ric', 'that', 'that', 'I', 'people', 'they', 'they', 'journalists', 'members', 'we', 'who', 'who', 'DNA', 'because', 'which', 'friend', 'friends', 'civilians', 'operatives', 'Israeli']
# Video ID: yIlEUF5Iqwc, Publish Date: 20240207, Passive Voice Count: 5, Relative Frequency (IPM): 3373.82, VVN Strings: ['rocked', 'handed', 'rushed', 'handed', 'raised'], Preceding Strings: ['agency', 'has', 'decision', 'list', 'issue']
# Video ID: fcST76QCRp8, Publish Date: 20240509, Passive Voice Count: 3, Relative Frequency (IPM): 1139.38, VVN Strings: ['martyred', 'accused', 'tied'], Preceding Strings: ['people', 'and', 'she']
# Video ID: EMCrICXrN3A, Publish Date: 20231020, Passive Voice Count: 1, Relative Frequency (IPM): 1090.51, VVN Strings: ['impacted'], Preceding Strings: ['who']
# Video ID: yb5HI5aZNvo, Publish Date: 20231109, Passive Voice Count: 7, Relative Frequency (IPM): 7478.63, VVN Strings: ['seen', 'driven', 'born', 'seen', 'heard', 'released', 'presented'], Preceding Strings: ['he', 'he', 'he', 'also', 'message', 'hostages', 'deal']
# Video ID: NM_kOaI3Nys, Publish Date: 20240823, Passive Voice Count: 1, Relative Frequency (IPM): 1317.52, VVN Strings: ['made'], Preceding Strings: ['any']
# Video ID: -nH9LYNAnKQ, Publish Date: 20240307, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: W6MfuI04tnM, Publish Date: 20240108, Passive Voice Count: 1, Relative Frequency (IPM): 1061.57, VVN Strings: ['adjudicated'], Preceding Strings: ['that']
# Video ID: tC6alA9utqg, Publish Date: 20240319, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: vUA6XrdH0Ig, Publish Date: 20240504, Passive Voice Count: 2, Relative Frequency (IPM): 1506.02, VVN Strings: ['described', 'quoted'], Preceding Strings: ['now', 'that']
# Video ID: ygao73eup5k, Publish Date: 20240715, Passive Voice Count: 3, Relative Frequency (IPM): 2325.58, VVN Strings: ['welcomed', 'offered', 'destroyed'], Preceding Strings: ['who', 'that', 'has']
# Video ID: 4VcIhEjQARk, Publish Date: 20240403, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: SiGusU0uu3c, Publish Date: 20231212, Passive Voice Count: 4, Relative Frequency (IPM): 5298.01, VVN Strings: ['sent', 'displaced', 'displaced', 'asked'], Preceding Strings: ['they', 'that', 'some', 'they']
# Video ID: MOUFa6Kr7VM, Publish Date: 20231011, Passive Voice Count: 19, Relative Frequency (IPM): 5504.06, VVN Strings: ['launched', 'abducted', 'taken', 'posted', 'dragged', 'closed', 'discovered', 'released', 'attacked', 'abducted', 'got', 'pulled', 'found', 'taken', 'created', 'programed', 'slaughtered', 'programed', 'bound'], Preceding Strings: ['Rockets', 'may', 'to', 'that', 'that', 'that', 'bodies', 'he', 'it', 'uh', 'he', 'also', 'relatives', 'that', 'state', 'that', 'movement', 'slaughtered', 'they']
# Video ID: RVMGvEvNr_A, Publish Date: 20240506, Passive Voice Count: 5, Relative Frequency (IPM): 3952.57, VVN Strings: ['told', 'promised', 'targeted', 'overtaken', 'made'], Preceding Strings: ['East', 'we', 'Rafa', 'building', 'that']
# Video ID: q7q4ifX3g4s, Publish Date: 20240813, Passive Voice Count: 1, Relative Frequency (IPM): 1175.09, VVN Strings: ['said'], Preceding Strings: ['on']
# Video ID: 8fk7a35sMP8, Publish Date: 20240229, Passive Voice Count: 5, Relative Frequency (IPM): 5133.47, VVN Strings: ['killed', 'injured', 'overwhelmed', 'overwhelmed', 'run'], Preceding Strings: ['people', 'others', 'and', 'trucks', 'people']
# Video ID: sllsUZSQ9Po, Publish Date: 20240204, Passive Voice Count: 3, Relative Frequency (IPM): 2538.07, VVN Strings: ['killed', 'shipped', 'released'], Preceding Strings: ['Palestinians', 'fuel', 'prisoners']
# Video ID: w1ev26-7uAw, Publish Date: 20240524, Passive Voice Count: 5, Relative Frequency (IPM): 3037.67, VVN Strings: ['announced', 'recalled', 'established', 'called', 'reached'], Preceding Strings: ['that', 'countries', 'and', 'that', 'conclusion']
# Video ID: rMiO3DoaudU, Publish Date: 20231023, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: 5wX7rtI-U2g, Publish Date: 20240903, Passive Voice Count: 3, Relative Frequency (IPM): 2597.40, VVN Strings: ['killed', 'bulldozed', 'left'], Preceding Strings: ['people', 'camp', 'Palestinians']
# Video ID: HcRbfI-BzEo, Publish Date: 20231108, Passive Voice Count: 1, Relative Frequency (IPM): 487.57, VVN Strings: ['tainted'], Preceding Strings: ['protests']
# Video ID: 9v_lhmFGzug, Publish Date: 20240809, Passive Voice Count: 6, Relative Frequency (IPM): 1694.92, VVN Strings: ['killed', 'killed', 'revived', 'released', 'killed', 'killed'], Preceding Strings: ['he', 'leader', 'deal', 'that', 'people', 'people']
# Video ID: OTsjNUHECyo, Publish Date: 20231122, Passive Voice Count: 11, Relative Frequency (IPM): 11099.90, VVN Strings: ['confirmed', 'injured', 'killed', 'buried', 'killed', 'killed', 'forced', 'killed', 'killed', 'killed', 'told'], Preceding Strings: ['workers', 'reporters', 'who', 'al-mamari', 'who', 'who', 'journalists', 'who', 'Gaza', 'they', 'they']
# Video ID: ZpS3rq4htyA, Publish Date: 20240402, Passive Voice Count: 5, Relative Frequency (IPM): 3092.15, VVN Strings: ['killed', 'killed', 'killed', 'killed', 'said'], Preceding Strings: ['commanders', 'said', 'Lebanon', 'that', 'that']
# Video ID: 75P2jJsxK5E, Publish Date: 20240707, Passive Voice Count: 14, Relative Frequency (IPM): 11226.94, VVN Strings: ['killed', 'killed', 'estimated', 'killed', 'rushed', 'treated', 'made', 'displaced', 'killed', 'injured', 'displaced', 'revived', 'put', 'dropped'], Preceding Strings: ['people', 'people', 'people', 'civilians', 'wounded', 'children', 'progress', 'who', 'people', 'who', 'who', 'efforts', 'US', 'demand']
# Video ID: 0qcrdGLFj_4, Publish Date: 20240703, Passive Voice Count: 1, Relative Frequency (IPM): 2777.78, VVN Strings: ['killed'], Preceding Strings: ['Palestinians']
# Video ID: RuAKfNWogg4, Publish Date: 20231108, Passive Voice Count: 10, Relative Frequency (IPM): 4514.67, VVN Strings: ['killed', 'limited', 'called', 'described', 'built', 'built', 'used', 'designed', 'collapsed', 'described'], Preceding Strings: ['soldiers', 'Warfare', 'have', 'militants', 'it', 'been', 'they', 'bombs', 'that', 'mentioning']
# Video ID: N59I35ug18o, Publish Date: 20231126, Passive Voice Count: 13, Relative Frequency (IPM): 9206.80, VVN Strings: ['delayed', 'held', 'released', 'killed', 'murdered', 'agreed', 'delayed', 'selected', 'released', 'handed', 'brought', 'agreed', 'talked'], Preceding Strings: ['release', 'who', 'captives', 'brother', 'who', 'that', 'were', 'uh', 'hostages', 'they', 'then', 'that', 'this']
# Video ID: lFqohsr2JUE, Publish Date: 20240816, Passive Voice Count: 10, Relative Frequency (IPM): 7898.89, VVN Strings: ['destroyed', 'destroyed', 'raised', 'put', 'put', 'destroyed', 'asked', 'told', 'sprayed', 'lost'], Preceding Strings: ['Farms', 'that', 'Earth', 'Roads', 'Earthworks', 'Gaza', 'we', 'we', 'herbicides', 'what']
# Video ID: EzuhWgbH-MM, Publish Date: 20231213, Passive Voice Count: 6, Relative Frequency (IPM): 2967.36, VVN Strings: ['bombed', 'displaced', 'asked', 'killed', 'displaced', 'killed'], Preceding Strings: ['home', 'population', 'I', 'people', 'people', 'they']
# Video ID: e28HUQemxro, Publish Date: 20231228, Passive Voice Count: 3, Relative Frequency (IPM): 2371.54, VVN Strings: ['killed', 'displaced', 'evacuated'], Preceding Strings: ['people', 'population', 'here']
# Video ID: JiARfFE_AiM, Publish Date: 20240131, Passive Voice Count: 4, Relative Frequency (IPM): 4395.60, VVN Strings: ['forced', 'forced', 'displaced', 'forced'], Preceding Strings: ['they', 'people', 'population', 'amilies']
# Video ID: K30VZ5-Iepo, Publish Date: 20240120, Passive Voice Count: 2, Relative Frequency (IPM): 2341.92, VVN Strings: ['concerned', 'reported'], Preceding Strings: ['that', 'that']
# Video ID: wh3QTVj8ta4, Publish Date: 20240407, Passive Voice Count: 1, Relative Frequency (IPM): 3584.23, VVN Strings: ['forced'], Preceding Strings: ['I']
# Video ID: dTRVE4lV_sc, Publish Date: 20240823, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: Ruq6YlmvXHU, Publish Date: 20231106, Passive Voice Count: 3, Relative Frequency (IPM): 1347.71, VVN Strings: ['involved', 'provided', 'surprised'], Preceding Strings: ['Iran', 'that', 'they']
# Video ID: u7UF4sooLEk, Publish Date: 20240215, Passive Voice Count: 1, Relative Frequency (IPM): 1273.89, VVN Strings: ['ordered'], Preceding Strings: ['troops']
# Video ID: WGmUq0UP5GQ, Publish Date: 20240225, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: 1CpJCOk17w4, Publish Date: 20240719, Passive Voice Count: 1, Relative Frequency (IPM): 1140.25, VVN Strings: ['supposed'], Preceding Strings: ['they']
# Video ID: NsNDr6Su65I, Publish Date: 20240821, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: cBSUICMFDiE, Publish Date: 20231031, Passive Voice Count: 8, Relative Frequency (IPM): 3664.68, VVN Strings: ['intercepted', 'displaced', 'killed', 'killed', 'martyred', 'killed', 'hit', 'stried'], Preceding Strings: ['that', 'they', 'people', 'have', 'he', 'children', 'Gaza', 'who']
# Video ID: QW-cWj7WatE, Publish Date: 20240710, Passive Voice Count: 9, Relative Frequency (IPM): 6574.14, VVN Strings: ['killed', 'fired', 'come', 'killed', 'harmed', 'harmed', 'hid', 'asked', 'seen'], Preceding Strings: ['dozens', 'Rockets', 'might', 'people', 'civilians', 'civilians', 'uh', 'Gaza', 'which']
# Video ID: YT3CV8T6_vY, Publish Date: 20240810, Passive Voice Count: 3, Relative Frequency (IPM): 4329.00, VVN Strings: ['reported', 'taken', 'trapped'], Preceding Strings: ['people', 'steps', 'that']
# Video ID: mex-jSmyh48, Publish Date: 20231225, Passive Voice Count: 6, Relative Frequency (IPM): 2376.24, VVN Strings: ['killed', 'produced', 'told', 'stolen', 'released', 'used'], Preceding Strings: ['people', 'weapons', 'I', 'dignity', 'that', 'that']
# Video ID: RaI0NwxzDWw, Publish Date: 20240102, Passive Voice Count: 10, Relative Frequency (IPM): 4990.02, VVN Strings: ['carried', 'killed', 'killed', 'engaged', 'launched', 'launched', 'cancelled', 'supposed', 'founded', 'killed'], Preceding Strings: ['and', 'people', 'identifyed', 'who', 'that', 'that', 'meeting', 'that', 'organization', 'he']
# Video ID: 3RRSZ-l4uGs, Publish Date: 20240129, Passive Voice Count: 5, Relative Frequency (IPM): 4149.38, VVN Strings: ['killed', 'killed', 'carried', 'conducted', 'coordinated'], Preceding Strings: ['troops', 'troops', 'it', 'attack', 'attack']
# Video ID: t1zqjgGKxzU, Publish Date: 20240129, Passive Voice Count: 1, Relative Frequency (IPM): 768.64, VVN Strings: ['killed'], Preceding Strings: ['forces']
# Video ID: L5wEjLNUGlc, Publish Date: 20231112, Passive Voice Count: 19, Relative Frequency (IPM): 5621.30, VVN Strings: ['displaced', 'displaced', 'shot', 'shot', 'suspended', 'exposed', 'bombarded', 'comped', 'attacked', 'attacked', 'killed', 'injured', 'inured', 'shot', 'destructed', 'killed', 'killed', 'killed', 'killed'], Preceding Strings: ['that', 'displaced', 'hospital', 'hospital', 'operations', 'sha', 'it', 'building', 'Building', 'building', 'people', 'many', 'team', 'team', 'building', 'people', 'who', 'who', 'people']
# Video ID: 6H5qelKTDew, Publish Date: 20240311, Passive Voice Count: 5, Relative Frequency (IPM): 3028.47, VVN Strings: ['given', 'granted', 'told', 'dented', 'predicted'], Preceding Strings: ['Aid', 'permissions', 'tons', 'politicians', 'this']
# Video ID: NslmiNi8g_8, Publish Date: 20240221, Passive Voice Count: 5, Relative Frequency (IPM): 3041.36, VVN Strings: ['banned', 'closed', 'held', 'shown', 'done'], Preceding Strings: ['them', 'street', 'hostages', 'Israel', 'we']
# Video ID: JgbVZq1BhI8, Publish Date: 20240216, Passive Voice Count: 3, Relative Frequency (IPM): 2379.06, VVN Strings: ['confirmed', 'told', 'displaced'], Preceding Strings: ['that', 'and', 'them']
# Video ID: fwV2P9PuWng, Publish Date: 20240304, Passive Voice Count: 6, Relative Frequency (IPM): 1456.31, VVN Strings: ['taken', 'moved', 'reported', 'destroyed', 'taken', 'asked'], Preceding Strings: ['they', 'people', 'know', 'what', '250', 'Egyptians']
# Video ID: wyqHuhmsA28, Publish Date: 20240331, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: dDFk9IBdRj0, Publish Date: 20240501, Passive Voice Count: 1, Relative Frequency (IPM): 767.46, VVN Strings: ['closed'], Preceding Strings: ['that']
# Video ID: KpiaMIhCmtQ, Publish Date: 20231026, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: Es8fY901Tbk, Publish Date: 20240521, Passive Voice Count: 1, Relative Frequency (IPM): 1062.70, VVN Strings: ['issued'], Preceding Strings: ['which']
# Video ID: 8PeQPFfDhi4, Publish Date: 20240321, Passive Voice Count: 3, Relative Frequency (IPM): 4815.41, VVN Strings: ['taken', 'kicked', 'put'], Preceding Strings: ['decision', 'that', 'that']
# Video ID: K7b9ZJUCmNc, Publish Date: 20231026, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: 6PMv_Z6a_yU, Publish Date: 20240122, Passive Voice Count: 1, Relative Frequency (IPM): 975.61, VVN Strings: ['leaked'], Preceding Strings: ['that']
# Video ID: W17RwKG33hQ, Publish Date: 20231111, Passive Voice Count: 5, Relative Frequency (IPM): 3021.15, VVN Strings: ['committed', 'committed', 'United', 'divided', 'supported'], Preceding Strings: ['crimes', 'might', 'also', 'Europe', 'Europe']
# Video ID: Q7v5BPloG10, Publish Date: 20240212, Passive Voice Count: 3, Relative Frequency (IPM): 6637.17, VVN Strings: ['involved', 'involved', 'founded'], Preceding Strings: ['workers', 'staffers', 'unra']
# Video ID: 9eUjeGQXpTQ, Publish Date: 20240119, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: 1WsLMJbbh2o, Publish Date: 20240510, Passive Voice Count: 3, Relative Frequency (IPM): 2958.58, VVN Strings: ['decided', 'met', 'started'], Preceding Strings: ['have', 'place', 'it']
# Video ID: aFAMlKG62hs, Publish Date: 20231024, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: aFAMlKG62hs, Publish Date: 20231024, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: Uar3I_LUSyM, Publish Date: 20231011, Passive Voice Count: 13, Relative Frequency (IPM): 3688.99, VVN Strings: ['involved', 'involved', 'inspired', 'confirmed', 'kidnapped', 'done', 'done', 'released', 'offered', 'released', 'made', 'financed', 'forced'], Preceding Strings: ['they', 'they', 'that', 'that', 'which', 'deals', 'swaps', 'prisoners', 'deal', 'that', 'it', 'Hamas', 'they']
# Video ID: 1BG-qGf7_-c, Publish Date: 20240522, Passive Voice Count: 10, Relative Frequency (IPM): 2403.85, VVN Strings: ['sought', 'done', 'faced', 'done', 'allowed', 'attacked', 'done', 'used', 'done', 'protected'], Preceding Strings: ['have', 'could', 'Israel', 'could&nbsp;&nbsp;', 'they', 'who', 'must', 'could&nbsp;', 'little', 'movement']
# Video ID: Bq-egJlwHlo, Publish Date: 20240422, Passive Voice Count: 2, Relative Frequency (IPM): 4132.23, VVN Strings: ['found', 'found'], Preceding Strings: ['that', 'said']
# Video ID: ZT8d9-98PIs, Publish Date: 20240803, Passive Voice Count: 31, Relative Frequency (IPM): 4891.13, VVN Strings: ['turned', 'approved', 'leveled', 'brought', 'displaced', 'denied', 'surrounded', 'prosecuted', 'set', 'prosecuted', 'raided', 'destroyed', 'detained', 'abducted', 'shut', 'stripped', 'left', 'killed', 'killed', 'brought', 'brought', 'attacked', 'stationed', 'found', 'taken', 'killed', 'killed', 'given', 'destroyed', 'destroyed', 'killed'], Preceding Strings: ['I', 'what', 'that', 'had', 'they', 'I', 'we', 'that', 'conditions', 'war', 'it', 'unit', 'he', 'he', 'hospital', 'he', 'he', 'stuff', 'Lad', 'who', 'he', 'lives', 'literally', 'them', 'would', 'that', 'that', 'has', 'systems', 'Systems', 'that']
# Video ID: Ux5Zk8CzGec, Publish Date: 20231011, Passive Voice Count: 6, Relative Frequency (IPM): 5763.69, VVN Strings: ['kidnapped', 'raided', 'burned', 'kidnapped', 'done', 'born'], Preceding Strings: ['to', 'kibuts', 'houses', 'who', 'nothing', 'I']
# Video ID: qcg07VlxBT4, Publish Date: 20240509, Passive Voice Count: 4, Relative Frequency (IPM): 3703.70, VVN Strings: ['engaged', 'displaced', 'struck', 'fired'], Preceding Strings: ['Forces', 'Border', 'Matula', 'Rockets']
# Video ID: C87Aknwdfug, Publish Date: 20231106, Passive Voice Count: 6, Relative Frequency (IPM): 3908.79, VVN Strings: ['killed', 'killed', 'pulled', 'born', 'forced', 'born'], Preceding Strings: ['children', 'civilians', 'she', 'who', 'but', 'imod']
# Video ID: eZdCXC1ubOw, Publish Date: 20240804, Passive Voice Count: 7, Relative Frequency (IPM): 5533.60, VVN Strings: ['injured', 'killed', 'killed', 'shot', 'confirmed', 'done', 'shot'], Preceding Strings: ['who', 'they', 'people', 'Bank', 'but', 'it', 'that']
# Video ID: RJ72FmcnLRA, Publish Date: 20231101, Passive Voice Count: 11, Relative Frequency (IPM): 3174.60, VVN Strings: ['forced', 'allowed', 'injured', 'allowed', 'put', 'told', 'killed', 'transferred', 'let', 'released', 'released'], Preceding Strings: ['Strip', 'holders', 'civilians', 'gazin', 'who', 'Nationals', 'soldiers', 'uh', 'people', 'hostages', 'hostages']
# Video ID: wM3WA2Eafl4, Publish Date: 20231125, Passive Voice Count: 21, Relative Frequency (IPM): 8430.35, VVN Strings: ['freed', 'released', 'released', 'jailed', 'released', 'set', 'included', 'killed', 'released', 'returned', 'jailed', 'jailed', 'shot', 'felt', 'reunited', 'paraded', 'wounded', 'released', 'shot', 'killed', 'involved'], Preceding Strings: ['inmates', 'hostages', 'Palestinians', 'that', 'prisons', 'CHS', 'they', 'people', 'Palestinians', "she's", 'daughter', 'she', 'she', 'family', 'prisoners', 'prisoners', 'people', 'who', 'Bank', 'two', 'was']
# Video ID: _q70phXW2es, Publish Date: 20240307, Passive Voice Count: 3, Relative Frequency (IPM): 2096.44, VVN Strings: ['turned', 'looted', 'suppressed'], Preceding Strings: ['organizations', 'uh', 'rule']
# Video ID: MgeO5qIGmqU, Publish Date: 20231123, Passive Voice Count: 9, Relative Frequency (IPM): 3918.15, VVN Strings: ['done', 'supposed', 'involved', 'agreed', 'bombed', 'taken', 'released', 'captured', 'captured'], Preceding Strings: ['that', 'he', 'who', 'so', 'it', 'they', 'prisoners', 'that', 'who']
# Video ID: O4TAt3-qMXY, Publish Date: 20240226, Passive Voice Count: 2, Relative Frequency (IPM): 1235.33, VVN Strings: ['entitled', 'entitled'], Preceding Strings: ['they', 'we']
# Video ID: AcfMmP4-Xkg, Publish Date: 20240602, Passive Voice Count: 6, Relative Frequency (IPM): 2914.04, VVN Strings: ['laid', 'put', 'proposed', 'worked', 'crossed', 'accomplished'], Preceding Strings: ['it', 'it', 'what', 'has', 'lines', 'steps']
# Video ID: pghyvBNaG_4, Publish Date: 20231229, Passive Voice Count: 12, Relative Frequency (IPM): 9188.36, VVN Strings: ['destroyed', 'killed', 'killed', 'displaced', 'destroyed', 'classified', 'killed', 'bombed', 'displaced', 'killed', 'killed', 'wounded'], Preceding Strings: ['house', 'children', 'people', '80%', 'houses', 'which', 'children', 'house', 'population', 'who', 'people', 'more']
# Video ID: 9tMD7wTRcZ4, Publish Date: 20231031, Passive Voice Count: 3, Relative Frequency (IPM): 2629.27, VVN Strings: ['kidnapped', 'found', 'assured'], Preceding Strings: ['11', 'have', 'you']
# Video ID: _2SbkxtSl8g, Publish Date: 20240105, Passive Voice Count: 5, Relative Frequency (IPM): 3419.97, VVN Strings: ['killed', 'considered', 'laid', 'killed', 'caused'], Preceding Strings: ['who', 'aruri', 'members', 'official', 'it']
# Video ID: B8Nznaz4SY8, Publish Date: 20240327, Passive Voice Count: 6, Relative Frequency (IPM): 3151.26, VVN Strings: ['surprised', 'killed', 'denied', 'denied', 'announced', 'announced'], Preceding Strings: ['we', 'people', 'have', 'hospital', 'that', 'that']
# Video ID: xJSMk7Ey17U, Publish Date: 20231123, Passive Voice Count: 17, Relative Frequency (IPM): 5426.11, VVN Strings: ['reported', 'killed', 'exerted', 'killed', 'delayed', 'achieved', 'delayed', 'taken', 'opposed', 'struck', 'discussed', 'arrested', 'convicted', 'delayed', 'delayed', 'made', 'delayed'], Preceding Strings: ['have', 'civilians', 'pressure', 'who', 'group', 'improvement', 'deal', 'they', 'who', 'deal', 'um', 'uh', 'have', 'has', 'the', 'mention', 'already']
# Video ID: Ipb25CX0fEY, Publish Date: 20231222, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: LYVQrakhMqI, Publish Date: 20231020, Passive Voice Count: 2, Relative Frequency (IPM): 1386.96, VVN Strings: ['bombed', 'destroyed'], Preceding Strings: ['out', 'buildings']
# Video ID: BK-W8EjLCOk, Publish Date: 20231106, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: rbgU5S1rH-Q, Publish Date: 20231124, Passive Voice Count: 11, Relative Frequency (IPM): 2932.55, VVN Strings: ['killed', 'expected', 'told', 'notified', 'told', 'approved', 'displaced', 'discharged', 'taken', 'left', 'told'], Preceding Strings: ['Israelis', 'that', 'we', 'are', 'we', 'names', 'that', 'and', 'were', 'was', 'people']
# Video ID: oLiqtXezpuM, Publish Date: 20240815, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: g37yu-lfdxA, Publish Date: 20240815, Passive Voice Count: 6, Relative Frequency (IPM): 2076.84, VVN Strings: ['released', 'accused', 'suggested', 'assassinated', 'involved', 'Left'], Preceding Strings: ['was', "that's", 'that', 'Hamas', 'you', 'whoever']
# Video ID: uzQBNEz_k50, Publish Date: 20240826, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: KOFcIP-lc6M, Publish Date: 20231013, Passive Voice Count: 8, Relative Frequency (IPM): 5079.37, VVN Strings: ['killed', 'disbanded', 'killed', 'killed', 'set', 'engaged', 'heated', 'asked'], Preceding Strings: ['Fighters', 'militias', 'soldiers', 'Fighters', 'that', 'hasah', 'has', 'uh']
# Video ID: ngzBDjPIj18, Publish Date: 20240729, Passive Voice Count: 3, Relative Frequency (IPM): 2599.65, VVN Strings: ['driven', 'coopted', 'made'], Preceding Strings: ['population', 'have', 'aid']
# Video ID: knm9ILovWlk, Publish Date: 20240510, Passive Voice Count: 5, Relative Frequency (IPM): 3335.56, VVN Strings: ['displaced', 'displaced', 'raised', 'asked', 'displaced'], Preceding Strings: ["who've", 'Gaza', 'has', 'have', 'that']
# Video ID: psr9UMCbfb4, Publish Date: 20240319, Passive Voice Count: 3, Relative Frequency (IPM): 1735.11, VVN Strings: ['allowed', 'based', 'targeted'], Preceding Strings: ['trickle', 'who', 'were']
# Video ID: Q4hgtJy2zNI, Publish Date: 20240127, Passive Voice Count: 4, Relative Frequency (IPM): 2038.74, VVN Strings: ['killed', 'involved', 'involved', 'reported'], Preceding Strings: ['people', 'staffers', 'employees', 'employees']
# Video ID: L3W9fvtTHKs, Publish Date: 20240713, Passive Voice Count: 2, Relative Frequency (IPM): 2869.44, VVN Strings: ['taken', 'deemed'], Preceding Strings: ['dead', 'war']
# Video ID: HsAgj-mZLYg, Publish Date: 20231014, Passive Voice Count: 4, Relative Frequency (IPM): 1482.03, VVN Strings: ['given', 'cut', 'killed', 'announced'], Preceding Strings: ['they', 'Israel', 'commander', 'has']
# Video ID: c7VoO1mKZIw, Publish Date: 20231015, Passive Voice Count: 7, Relative Frequency (IPM): 4569.19, VVN Strings: ['taken', 'represented', 'abducted', 'killed', 'taken', 'killed', 'struck'], Preceding Strings: ['she', 'nationalities', 'people', 'holding', 'hostages', 'Abdullah', 'Israel']
# Video ID: n-UkvlrIkug, Publish Date: 20240103, Passive Voice Count: 1, Relative Frequency (IPM): 2415.46, VVN Strings: ['reported'], Preceding Strings: ['shelling']
# Video ID: d2m7WC5nem4, Publish Date: 20240316, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: kNgUiYzUlWc, Publish Date: 20231106, Passive Voice Count: 15, Relative Frequency (IPM): 4349.09, VVN Strings: ['killed', 'killed', 'allowed', 'deemed', 'struck', 'cut', 'struck', 'made', 'carried', 'shuttered', 'freed', 'killed', 'injured', 'inflicted', 'weakened'], Preceding Strings: ['people', 'says', 'that', 'which', 'also', 'communication', 'mentioned', 'drop', 'operation', 'it', 'who', 'Palestinians', 'people', 'that', 'Hamas']
# Video ID: EHqq66hs68Y, Publish Date: 20231105, Passive Voice Count: 5, Relative Frequency (IPM): 3320.05, VVN Strings: ['conducted', 'cut', 'centered', 'killed', 'based'], Preceding Strings: ['that', 'services', 'bombardments', 'children', 'strike']
# Video ID: 4iFfFJcCc1Y, Publish Date: 20240123, Passive Voice Count: 4, Relative Frequency (IPM): 3603.60, VVN Strings: ['killed', 'engaged', 'mined', 'attacked'], Preceding Strings: ['people', 'that', 'it', 'building']
# Video ID: CMUIiVuf0q4, Publish Date: 20231111, Passive Voice Count: 7, Relative Frequency (IPM): 2220.81, VVN Strings: ['suspended', 'struck', 'allowed', 'embedded', 'kidnapped', 'called', 'relocated'], Preceding Strings: ['Hospital', 'hospital', 'that', 'far', 'that', 'people', 'refugees']
# Video ID: qLW2CzsF_b8, Publish Date: 20231107, Passive Voice Count: 6, Relative Frequency (IPM): 2027.71, VVN Strings: ['kidnapped', 'suggested', 'killed', 'told', 'given', 'described'], Preceding Strings: ['who', 'now', 'khed', 'what', 'that', 'that']
# Video ID: EZRYRDPIuiY, Publish Date: 20231106, Passive Voice Count: 6, Relative Frequency (IPM): 3911.34, VVN Strings: ['killed', 'conducted', 'bombed', 'told', 'completed', 'killed'], Preceding Strings: ['people', 'that', 'hospital', 'civilians', 'operation', 'those']
# Video ID: fw3FYfcR6GE, Publish Date: 20240107, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: dzcSrGxrTNc, Publish Date: 20231015, Passive Voice Count: 7, Relative Frequency (IPM): 3448.28, VVN Strings: ['killed', 'displaced', 'evacuated', 'told', 'given', 'Unleashed', 'killed'], Preceding Strings: ['civilians', 'I', 'area', 'north', 'that', 'attack', 'Israel']
# Video ID: hYC4XmIAJ5M, Publish Date: 20240126, Passive Voice Count: 4, Relative Frequency (IPM): 4926.11, VVN Strings: ['martyred', 'hit', 'killed', 'committed'], Preceding Strings: ['people', 'I', 'to', 'that']
# Video ID: i99qdu2QH0w, Publish Date: 20231011, Passive Voice Count: 7, Relative Frequency (IPM): 3216.91, VVN Strings: ['killed', 'told', 'hit', 'shut', 'caught', 'weakened', 'stored'], Preceding Strings: ['people', 'person', 'facilities', 'has', 'Israel', 'had', 'um']
# Video ID: UW7fo9FPdys, Publish Date: 20240517, Passive Voice Count: 3, Relative Frequency (IPM): 2892.96, VVN Strings: ['designed', 'accused', 'disrupted'], Preceding Strings: ['and', 'have', 'operations']
# Video ID: w8K0unl_SYY, Publish Date: 20240111, Passive Voice Count: 4, Relative Frequency (IPM): 5291.01, VVN Strings: ['hit', 'buried', 'killed', 'committed'], Preceding Strings: ['they', 'Martyrs', 'them', 'that']
# Video ID: U8LQIxpXv8M, Publish Date: 20231105, Passive Voice Count: 3, Relative Frequency (IPM): 2076.12, VVN Strings: ['killed', 'damaged', 'supposed'], Preceding Strings: ['people', 'road', 'is']
# Video ID: 62FAnfkm6vU, Publish Date: 20231019, Passive Voice Count: 6, Relative Frequency (IPM): 3949.97, VVN Strings: ['killed', 'caused', 'bombed', 'displaced', 'spoken', 'spared'], Preceding Strings: ['people', 'say', 'in', 'uh', 'have', 'Crossing']
# Video ID: zCnUBmIVTh8, Publish Date: 20231206, Passive Voice Count: 2, Relative Frequency (IPM): 1194.03, VVN Strings: ['told', 'indicated'], Preceding Strings: ['people', 'that']
# Video ID: 2A5yuft_ep4, Publish Date: 20231211, Passive Voice Count: 8, Relative Frequency (IPM): 2952.03, VVN Strings: ['reported', 'killed', 'blocked', 'produced', 'called', 'displaced', 'displaced', 'displaced'], Preceding Strings: ['battles', 'people', 'one', 'that', 'they', 'them', 'they', 'Palestinians']
# Video ID: Zfse3uZvHjM, Publish Date: 20231112, Passive Voice Count: 3, Relative Frequency (IPM): 1307.19, VVN Strings: ['born', 'allowed', 'confirmed'], Preceding Strings: ['she', 'Cross', 'nothing']
# Video ID: gYiEEu4-f0s, Publish Date: 20231124, Passive Voice Count: 7, Relative Frequency (IPM): 1691.64, VVN Strings: ['displaced', 'filmed', 'destroyed', 'Riven', 'mentioned', 'built', 'killed'], Preceding Strings: ['I', 'vehicles', 'that', 'weeks', 'they', 'this', 'workers']
# Video ID: Q5paF8cALsc, Publish Date: 20231205, Passive Voice Count: 5, Relative Frequency (IPM): 2534.21, VVN Strings: ['born', 'taken', 'displaced', 'asked', 'bombed'], Preceding Strings: ['he', 'footage', 'we', 'uh', 'have']
# Video ID: qLwNWATuVVw, Publish Date: 20231123, Passive Voice Count: 8, Relative Frequency (IPM): 2522.07, VVN Strings: ['postponed', 'arrested', 'charged', 'arrested', 'eliminated', 'released', 'told', 'mounted'], Preceding Strings: ['exchange', 'hospital', 'that', 'that', 'commanders', 'hostages', 'were', 'criticism']
# Video ID: DJPNkvLvnl0, Publish Date: 20240218, Passive Voice Count: 2, Relative Frequency (IPM): 2721.09, VVN Strings: ['killed', 'arrested'], Preceding Strings: ['were', 'were']
# Video ID: uLdv113Mn9w, Publish Date: 20231204, Passive Voice Count: 11, Relative Frequency (IPM): 2873.56, VVN Strings: ['reported', 'told', 'cut', 'instructed', 'released', 'killed', 'averted', 'averted', 'told', 'told', 'eliminated'], Preceding Strings: ['bombing', 'they', 'ourselves', 'we', 'uh', 'civilians', 'could', 'could', 'they', 'Gaza', 'Hamas']
# Video ID: TPDSbBydLW4, Publish Date: 20231023, Passive Voice Count: 7, Relative Frequency (IPM): 4046.24, VVN Strings: ['displaced', 'killed', 'destroyed', 'displaced', 'allowed', 'killed', 'called'], Preceding Strings: ['people', 'people', 'houses', 'population', 'fuel', 'Soldier', 'have']
# Video ID: 87m6LOCi_Cw, Publish Date: 20231028, Passive Voice Count: 5, Relative Frequency (IPM): 2385.50, VVN Strings: ['knocked', 'consulted', 'damaged', 'targeted', 'cut'], Preceding Strings: ['Gaza', 'they', 'ambulances', 'that', 'services']
# Video ID: F-qKjLxYYSw, Publish Date: 20231220, Passive Voice Count: 8, Relative Frequency (IPM): 4484.30, VVN Strings: ['killed', 'killed', 'displaced', 'killed', 'lost', 'held', 'delayed', 'expected'], Preceding Strings: ['civilians', 'grandkids', 'gazans', 'brother', 'communication', 'protests', 'vote', 'it']
# Video ID: sVmsNN_RN7w, Publish Date: 20231221, Passive Voice Count: 11, Relative Frequency (IPM): 8320.73, VVN Strings: ['used', 'killed', 'damaged', 'delayed', 'delayed', 'reported', 'accused', 'supposed', 'released', 'used', 'used'], Preceding Strings: ['tunnels', 'have', 'infrastructure', 'vote', 'fighting', 'progress', 'has', 'civilians', 'bodies', 'says', 'it']
# Video ID: q7BrwJ8LREc, Publish Date: 20231207, Passive Voice Count: 18, Relative Frequency (IPM): 5136.99, VVN Strings: ['told', 'defined', 'surprised', 'handled', 'held', 'held', 'scared', 'scared', 'terrified', 'perceived', 'deemed', 'killed', 'killed', 'taken', 'released', 'held', 'taken', 'taken'], Preceding Strings: ['people', 'has', 'Israel', 'the', 'who', 'they', 'they', 'they', 'they', 'has', 'that', 'people', 'belongings', 'IAI', 'that', 'and', 'he', 'that']
# ...
# Video ID: 8gG4ftCgmwk, Publish Date: 20240530, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: 6na_sXe86Yc, Publish Date: 20240114, Passive Voice Count: 7, Relative Frequency (IPM): 7106.60, VVN Strings: ['abducted', 'released', 'displaced', 'forced', 'returned', 'achieved', 'killed'], Preceding Strings: ['people', '110', 'homes', 'garans', 'hostages', 'aims', 'that']
# Video ID: rty7KeJlw84, Publish Date: 20231222, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: Ujo40lVL_nw, Publish Date: 20231109, Passive Voice Count: 6, Relative Frequency (IPM): 2504.17, VVN Strings: ['discussed', 'made', 'released', 'protected', 'remoted', 'called'], Preceding Strings: ['issues', 'that', 'that', 'that', 'that', 'as']
# Video ID: KFh0-oCzXXo, Publish Date: 20240830, Passive Voice Count: 4, Relative Frequency (IPM): 4689.33, VVN Strings: ['delivered', 'agreed', 'eradicated', 'eradicated'], Preceding Strings: ['have', 'have', 'has', 'it']
# Video ID: Sf6xl5HHchw, Publish Date: 20231014, Passive Voice Count: 6, Relative Frequency (IPM): 2606.43, VVN Strings: ['designated', 'focused', 'affected', 'killed', 'engaged', 'called'], Preceding Strings: ['Hamas', 'years', 'countries', 'least', 'Iran', 'Israelis']
# Video ID: 5RVkEF2nxSc, Publish Date: 20231119, Passive Voice Count: 11, Relative Frequency (IPM): 5104.41, VVN Strings: ['killed', 'killed', 'ordered', 'evacuated', 'evacuated', 'told', 'posted', 'said', 'killed', 'injured', 'taken'], Preceding Strings: ['most', 'child', 'say', 'have', 'they', 'they', 'that', 'that', 'thousands', 'who', 'who']
# Video ID: wCk3oISrsE0, Publish Date: 20240802, Passive Voice Count: 12, Relative Frequency (IPM): 3723.24, VVN Strings: ['assassinated', 'involved', 'mentioned', 'targeted', 'involved', 'announced', 'killed', 'planted', 'used', 'said', 'said', 'telegraphed'], Preceding Strings: ['he', 'he', 'that', 'course', 'Hano', 'that', 'already', 'that', 'that', 'what', 'what', 'attacks']
# Video ID: fMF3L1fqtcE, Publish Date: 20231227, Passive Voice Count: 4, Relative Frequency (IPM): 4162.33, VVN Strings: ['killed', 'forced', 'brought', 'displaced'], Preceding Strings: ['21,000', 'she', 'that', 'go']
# Video ID: cipDYZL9Nbw, Publish Date: 20231025, Passive Voice Count: 1, Relative Frequency (IPM): 2192.98, VVN Strings: ['killed'], Preceding Strings: ['Palestinians']
# Video ID: 293T__NKw_8, Publish Date: 20240603, Passive Voice Count: 4, Relative Frequency (IPM): 2414.00, VVN Strings: ['forced', 'transmitted', 'supposed', 'discussed'], Preceding Strings: ['may', 'as', 'already', 'it']
# Video ID: 3dNk8sQHEfM, Publish Date: 20240424, Passive Voice Count: 13, Relative Frequency (IPM): 5671.90, VVN Strings: ['declared', 'arrested', 'charged', 'deprived', 'beaten', 'shaken', 'charged', 'arrested', 'tolerated', 'put', 'arrested', 'spent', 'punished'], Preceding Strings: ['that', 'Israel', 'Khalifa', 'he', 'and', 'system', 'well', 'he', 'protest', 'indictments', 'who', 'he', 'not']
# Video ID: Z0OzIfLUTnw, Publish Date: 20240606, Passive Voice Count: 5, Relative Frequency (IPM): 2367.42, VVN Strings: ['evacuated', 'negotiated', 'conducted', 'experienced', 'engaged'], Preceding Strings: ['Border', 'deal', 'ceasefires', 'the', 'Lebanon']
# Video ID: cDJq1g81cIY, Publish Date: 20240407, Passive Voice Count: 5, Relative Frequency (IPM): 2556.24, VVN Strings: ['displaced', 'killed', 'used', 'killed', 'done'], Preceding Strings: ['we', 'who', 'plans', 'that', 'ground']
# Video ID: WBNNzq271uA, Publish Date: 20231113, Passive Voice Count: 1, Relative Frequency (IPM): 690.13, VVN Strings: ['labeled'], Preceding Strings: ['Jerusalem']
# Video ID: 1d736STrZmM, Publish Date: 20240820, Passive Voice Count: 2, Relative Frequency (IPM): 1067.81, VVN Strings: ['closed', 'narrowed'], Preceding Strings: ['gaps', 'gaps']
# Video ID: dTvnQjLcKbM, Publish Date: 20231018, Passive Voice Count: 10, Relative Frequency (IPM): 6684.49, VVN Strings: ['forced', 'handed', 'founded', 'ousted', 'outlawed', 'expected', 'transferred', 'canceled', 'meant', 'driven'], Preceding Strings: ['it', 'Cairo', 'which', 'but', 'group', 'Schultz', 'example', 'meeting', 'he', 'who']
# Video ID: TD4b32NnAz8, Publish Date: 20231012, Passive Voice Count: 7, Relative Frequency (IPM): 3239.24, VVN Strings: ['decimated', 'opposed', 'sold', 'displaced', 'instructed', 'instructed', 'located'], Preceding Strings: ["they've", 'violence', 'it', 'who', 'who', 'uh', 'it']
# Video ID: BtLh-HcFA8Y, Publish Date: 20240411, Passive Voice Count: 6, Relative Frequency (IPM): 4073.32, VVN Strings: ['breached', 'limited', 'mentioned', 'targeted', 'shunned', 'done'], Preceding Strings: ['Crossing', 'Crossing', 'one', 'because', 'them', 'something']
# Video ID: 4WLnCCxbQc0, Publish Date: 20231027, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: l9JcPdD9XKo, Publish Date: 20240603, Passive Voice Count: 15, Relative Frequency (IPM): 4347.83, VVN Strings: ['confirmed', 'held', 'presented', 'submitted', 'presented', 'presented', 'brought', 'submitted', 'worried', 'given', 'given', 'killed', 'set', 'suggested', 'confirmed'], Preceding Strings: ['Hamas', 'thought', 'which', 'actually', 'which', 'but', 'that', 'which', 'he', 'that', 'that', 'that', 'that', 'people', 'that']
# Video ID: uC6VJnEUctQ, Publish Date: 20240613, Passive Voice Count: 2, Relative Frequency (IPM): 1158.75, VVN Strings: ['laid', 'laid'], Preceding Strings: ['it', 'it']
# Video ID: 5ltlb1Li5K4, Publish Date: 20240123, Passive Voice Count: 6, Relative Frequency (IPM): 1958.22, VVN Strings: ['dismantled', 'locked', 'believed', 'supported', 'invested', 'hit'], Preceding Strings: ['they', 'has', 'it', 'groups', 'year', 'Yemen']
# Video ID: PTZivpzjoNQ, Publish Date: 20240514, Passive Voice Count: 5, Relative Frequency (IPM): 4321.52, VVN Strings: ['arrested', 'seen', 'killed', 'given', 'brought'], Preceding Strings: ['people', 'protesters', 'Palestinians', 'government', 'body']
# Video ID: BiSwT0ljRPM, Publish Date: 20231209, Passive Voice Count: 6, Relative Frequency (IPM): 2507.31, VVN Strings: ['killed', 'manufactured', 'displaced', 'shut', 'shut', 'shut'], Preceding Strings: ['people', 'weapons', 'that', 'system', 'system', 'system']
# Video ID: uoX-K8O9lYk, Publish Date: 20240903, Passive Voice Count: 1, Relative Frequency (IPM): 903.34, VVN Strings: ['shot'], Preceding Strings: ['who']
# Video ID: TFr8X8Bc2S8, Publish Date: 20231201, Passive Voice Count: 5, Relative Frequency (IPM): 2582.64, VVN Strings: ['unveiled', 'orchestrated', 'hit', 'signed', 'supposed'], Preceding Strings: ['clock', 'protests', 'Both', 'They', 'they']
# Video ID: LEze_S20H_E, Publish Date: 20240530, Passive Voice Count: 2, Relative Frequency (IPM): 998.00, VVN Strings: ['conducted', 'killed'], Preceding Strings: ['operation', 'parents']
# Video ID: RUqJObE91Eo, Publish Date: 20231025, Passive Voice Count: 6, Relative Frequency (IPM): 1894.54, VVN Strings: ['asked', 'reported', 'distributed', 'fired', 'let', 'torn'], Preceding Strings: ['people', 'casualties', 'supplies', 'had', 'that', 'that']
# Video ID: gCnkQRK0IJY, Publish Date: 20231118, Passive Voice Count: 1, Relative Frequency (IPM): 774.59, VVN Strings: ['killed'], Preceding Strings: ['thousands']
# Video ID: izNvwGo2G8o, Publish Date: 20240808, Passive Voice Count: 9, Relative Frequency (IPM): 4470.94, VVN Strings: ['developed', 'instituted', 'developed', 'used', 'deemed', 'hurt', 'killed', 'shut', 'brushed'], Preceding Strings: ['and', 'it', 'it', 'them', 'um', 'pride', 'hanene', 'missiles', 'they']
# Video ID: sdvW1YAPZBU, Publish Date: 20240227, Passive Voice Count: 7, Relative Frequency (IPM): 2886.60, VVN Strings: ['taken', 'released', 'targeted', 'finalized', 'signed', 'used', 'attacked'], Preceding Strings: ['who', 'details', 'they', 'nothing', 'treaty', 'which', 'we']
# Video ID: 6w5ShwRFEgs, Publish Date: 20240618, Passive Voice Count: 2, Relative Frequency (IPM): 4901.96, VVN Strings: ['expected', 'formed'], Preceding Strings: ['move', 'uh']
# Video ID: Rk7Q8B-FqPc, Publish Date: 20240608, Passive Voice Count: 6, Relative Frequency (IPM): 1886.20, VVN Strings: ['rejected', 'founded', 'expelled', 'destroyed', 'supported', 'elected'], Preceding Strings: ['plans', 'Israel', 'Palestinians', 'has', 'arms', 'man']
# Video ID: zFclOJ9cC84, Publish Date: 20240418, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: DNn3FIenUBg, Publish Date: 20240409, Passive Voice Count: 4, Relative Frequency (IPM): 1461.45, VVN Strings: ['lost', 'supported', 'quoted', 'alluded'], Preceding Strings: ['and', 'then', 'convention', 'that']
# Video ID: DiSOkm52pNM, Publish Date: 20240531, Passive Voice Count: 1, Relative Frequency (IPM): 634.12, VVN Strings: ['evacuated'], Preceding Strings: ['they']
# Video ID: GIJQImodLwk, Publish Date: 20240111, Passive Voice Count: 4, Relative Frequency (IPM): 1884.13, VVN Strings: ['made', 'threatened', 'brought', 'brought'], Preceding Strings: ['case', 'that', 'that', 'that']
# Video ID: VA2tiAHmbm0, Publish Date: 20231104, Passive Voice Count: 6, Relative Frequency (IPM): 3094.38, VVN Strings: ['proposed', 'established', 'attacked', 'driven', 'born', 'elected'], Preceding Strings: ['that', 'It', 'And', 'or', 'who', 'Hamas']
# Video ID: 3MMrXclUn4o, Publish Date: 20240607, Passive Voice Count: 1, Relative Frequency (IPM): 1655.63, VVN Strings: ['added'], Preceding Strings: ['have']
# Video ID: BxKsbGQN8bI, Publish Date: 20240209, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: YkhE__tT7MA, Publish Date: 20231219, Passive Voice Count: 12, Relative Frequency (IPM): 5853.66, VVN Strings: ['buried', 'shown', 'buried', 'killed', 'shown', 'prevented', 'released', 'released', 'killed', 'killed', 'killed', 'killed'], Preceding Strings: ['bodies', 'Health', 'people', 'militants', 'careful', 'journalists', 'that', 'that', 'civilians', 'that', 'civilians', 'uh']
# Video ID: YXko1JbMs9E, Publish Date: 20240907, Passive Voice Count: 5, Relative Frequency (IPM): 4139.07, VVN Strings: ['shot', 'shot', 'shot', 'identified', 'shot'], Preceding Strings: ['who', 'she', 'she', 'question', 'she']
# Video ID: NClxLXeu358, Publish Date: 20240517, Passive Voice Count: 2, Relative Frequency (IPM): 1014.20, VVN Strings: ['set', 'dropped'], Preceding Strings: ['believe', 'that']
# Video ID: 8hXB7HJqvTg, Publish Date: 20240419, Passive Voice Count: 19, Relative Frequency (IPM): 3932.93, VVN Strings: ['activated', 'heard', 'related', 'informed', 'asked', 'carried', 'shot', 'intercepted', 'backed', 'triggered', 'put', 'hit', 'struck', 'upgraded', 'presented', 'shot', 'involved', 'struck', 'established'], Preceding Strings: ['defenses', 'that', 'this', 'US', 'he', 'attacks', 'drones', 'and', 'strike', 'Iran', 'they', 'sites', 'that', 'these', 'these', 'Iran', 'alleging', 'soil', 'that']
# Video ID: -JgQbTVWdfs, Publish Date: 20240801, Passive Voice Count: 16, Relative Frequency (IPM): 4970.49, VVN Strings: ['killed', 'killed', 'targeted', 'confirmed', 'killed', 'killed', 'taken', 'killed', 'seen', 'killed', 'killed', 'established', 'accused', 'targeted', 'portrayed', 'killed'], Preceding Strings: ['he', 'dive', 'he', 'it', 'salame', 'also', 'he', 'Dave', 'and', 'Dave', 'bodyguard', 'it', 'shukur', 'might', 'he', 'hania']
# Video ID: 7UWZAFGq59Y, Publish Date: 20231213, Passive Voice Count: 5, Relative Frequency (IPM): 2002.40, VVN Strings: ['destroyed', 'martyred', 'adopted', 'sent', 'opened'], Preceding Strings: ['house', 'child', 'no', 'that', 'Crossing']
# Video ID: nY-wo0iUeTk, Publish Date: 20231224, Passive Voice Count: 2, Relative Frequency (IPM): 1990.05, VVN Strings: ['killed', 'killed'], Preceding Strings: ['people', 'that']
# Video ID: -hiLFXyM4UM, Publish Date: 20240811, Passive Voice Count: 2, Relative Frequency (IPM): 1666.67, VVN Strings: ['taken', 'rushed'], Preceding Strings: ['steps', 'casualties']
# Video ID: JrV3hW7wsgc, Publish Date: 20240807, Passive Voice Count: 4, Relative Frequency (IPM): 2053.39, VVN Strings: ['assassinated', 'seen', 'killed', 'engaged'], Preceding Strings: ['who', 'who', 'who', 'we']
# Video ID: kD3wd2YLV24, Publish Date: 20240506, Passive Voice Count: 3, Relative Frequency (IPM): 2454.99, VVN Strings: ['watered', 'accepted', 'committed'], Preceding Strings: ['proposal', 'proposal', 'that']
# Video ID: B9bQLW-pthA, Publish Date: 20240312, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: B9bQLW-pthA, Publish Date: 20240312, Passive Voice Count: 0, Relative Frequency (IPM): 0.00, VVN Strings: [], Preceding Strings: []
# Video ID: NK8hqpOL4Is, Publish Date: 20231129, Passive Voice Count: 28, Relative Frequency (IPM): 6321.97, VVN Strings: ['released', 'welcomed', 'released', 'hit', 'displaced', 'brought', 'destroyed', 'abducted', 'abducted', 'released', 'kept', 'released', 'surrounded', 'released', 'treated', 'kept', 'kept', 'kept', 'trained', 'approached', 'approved', 'made', 'murdered', 'trained', 'trained', 'released', 'met', 'released'], Preceding Strings: ['hostages', 'people', 'that', 'South', 'people', 'displaced', 'houses', 'that', 'that', 'that', 'conditions', 'Nationals', 'that', 'hostages', 'they', 'them', 'them', 'some', 'she', 'we', 'protocol', 'that', 'mother', 'he', 'them', 'Strip', 'they', 'who']
# Video ID: DFeeBJaLyWI, Publish Date: 20240411, Passive Voice Count: 4, Relative Frequency (IPM): 4434.59, VVN Strings: ['bombed', 'shaken', 'displaced', 'confirmed'], Preceding Strings: ['was', 'system', 'that', 'as']
# Video ID: 5u4pjrwsYH0, Publish Date: 20240129, Passive Voice Count: 5, Relative Frequency (IPM): 2915.45, VVN Strings: ['involved', 'displaced', 'given', 'pledged', 'leveled'], Preceding Strings: ['workers', 'Gaza', 'that', "what's", 'that']
# Video ID: -XOz2IctcWo, Publish Date: 20231013, Passive Voice Count: 7, Relative Frequency (IPM): 3833.52, VVN Strings: ['hit', 'killed', 'killed', 'mixed', 'disconnected', 'given', 'targeted'], Preceding Strings: ['so', 'people', 'people', 'that', 'them', 'and', 'uh']
# Video ID: Xcs1jAmf2go, Publish Date: 20231108, Passive Voice Count: 4, Relative Frequency (IPM): 3910.07, VVN Strings: ['killed', 'killed', 'destroyed', 'displaced'], Preceding Strings: ['people', 'khed', 'houses', 'people']
# Video ID: cKPjin6XT4U, Publish Date: 20231021, Passive Voice Count: 2, Relative Frequency (IPM): 2378.12, VVN Strings: ['founded', 'used'], Preceding Strings: ['Israel', 'word']
# Video ID: XggSfFCRJuQ, Publish Date: 20231203, Passive Voice Count: 4, Relative Frequency (IPM): 7326.01, VVN Strings: ['linked', 'deployed', 'involved', 'reported'], Preceding Strings: ['vessels', 'that', 'vessels', 'injuries']
# Video ID: 179U7wS6H-4, Publish Date: 20240720, Passive Voice Count: 10, Relative Frequency (IPM): 9025.27, VVN Strings: ['triggered', 'sounded', 'detected', 'launched', 'launched', 'used', 'used', 'developed', 'used', 'involved'], Preceding Strings: ['alarms', 'alerts', 'it', 'Drone', 'drone', 'hoodies', 'that', 'drone', 'that', 'could']
# Video ID: qUDkZ6V1uKM, Publish Date: 20231026, Passive Voice Count: 3, Relative Frequency (IPM): 1226.49, VVN Strings: ['asked', 'called', 'released'], Preceding Strings: ['uh', 'uh', 'were']
# Video ID: None, Publish Date: None, Passive Voice Count: 5, Relative Frequency (IPM): 3513.70, VVN Strings: ['transmitted', 'presented', 'given', 'described', 'degraded'], Preceding Strings: ['that', 'plan', 'it', 'what', 'capabilities']
#
# Total Passive Voice Count: 4697
# Total Relative Frequency (IPM): 3001.67
#
# Top 10 most common VVN strings and their frequencies:
# killed: 636
# taken: 147
# released: 143
# displaced: 123
# told: 82
# made: 60
# destroyed: 60
# used: 53
# held: 51
# involved: 51
#
# Top 10 most common preceding strings and their frequencies:
# that: 486
# people: 247
# they: 230
# who: 205
# it: 162
# he: 117
# have: 95
# has: 88
# Palestinians: 85
# which: 64
