# %%
import os
import re
import subprocess

def list_txt_files(directory):
    # Find all .txt files in the directory (non-recursively)
    txt_files = []
    for file in os.listdir(directory):
        file_path = os.path.join(directory, file)
        if os.path.isfile(file_path) and file.endswith('.txt'):
            txt_files.append(file_path)
    return txt_files
    
# Function to extract text between <doc> and </doc> tags
def extract_text_from_file(file_path, encoding='utf-8'):
    try:
        with open(file_path, 'r', encoding=encoding) as file:
            content = file.read()
        # Use regular expressions to find the text between <doc> and </doc>
        #match = re.search(r'<doc>(.*?)</doc>', content, re.DOTALL)
        #if match:
        #    return match.group(1).strip()
        #else:
            return content
    except UnicodeDecodeError as e:
        print(f"Error reading file {file_path}: {e}")
        return None

# Function to tokenize text into words and punctuation
def tokenize(text):
    # Regex to split words and punctuation
    # \w+ matches word characters (including numbers and underscores)
    # [^\w\s] matches punctuation (anything that's not a word or whitespace)
    tokens = re.findall(r'\w+|[^\w\s]', text, re.UNICODE)
    return tokens

# Function to write tokens to a new file with each token on a new line
def write_words_to_file(text, output_path, encoding='utf-8'):
    try:
        # Tokenize the text using the tokenizer
        tokens = tokenize(text)
        with open(output_path, 'w', encoding=encoding) as file:
            for token in tokens:
                file.write(token + '\n')
        print(f"Tokens have been successfully written to {output_path}")
    except UnicodeEncodeError as e:
        print(f"Error writing file {output_path}: {e}")

# Function to execute TreeTagger and process the output
def run_treetagger(input_path, output_path):
    treetagger_path = 'tree-tagger-windows-3.2.3a/TreeTagger/bin/tree-tagger.exe'  # Replace with the path to your TreeTagger executable
    parameter_path = 'tree-tagger-windows-3.2.3a/TreeTagger/lib/english.par'  # Replace with the path to your TreeTagger parameter file
    cmd = [treetagger_path, parameter_path, '-token', '-lemma', '-no-unknown', input_path]
    
    try:
        # Run TreeTagger and capture the output
        result = subprocess.run(cmd, capture_output=True, text=True, encoding='utf-8')
        
        if result.returncode == 0:
            if result.stdout:  # Check if stdout is not None
                with open(output_path, 'w', encoding='utf-8') as file:
                    file.write(result.stdout)
                print(f"TreeTagger output has been written to {output_path}")
            else:
                print(f"No output from TreeTagger for file: {input_path}")
        else:
            print(f"Error running TreeTagger: {result.stderr}")
    
    except Exception as e:
        print(f"An exception occurred: {e}")

def process_files(directory):
    # Find all .txt files
    txt_files = list_txt_files(directory)
    for txt_file in txt_files:
        # Ensure the directory for TreeTagger output exists
        treetagger_output_dir = os.path.join(os.path.dirname(txt_file), 'treetagger_output')
        os.makedirs(treetagger_output_dir, exist_ok=True)
        
        # Define paths
        temp_text_file_path = os.path.join(treetagger_output_dir, os.path.basename(txt_file).replace('.txt', '_words.txt'))
        treetagger_output_path = os.path.join(treetagger_output_dir, os.path.basename(txt_file).replace('.txt', '_treetagger_output.txt'))

        # Extract text and write to new file
        text = extract_text_from_file(txt_file)
        if text:
            write_words_to_file(text, temp_text_file_path)
            print(f"Words have been written to {temp_text_file_path}")

            # Run TreeTagger
            run_treetagger(temp_text_file_path, treetagger_output_path)

            # Clean up temporary file
            os.remove(temp_text_file_path)
        else:
            print(f"No text found in <doc> tags for file: {txt_file}")


# Example usage
directory_path = 'data/en_DW/'  # Root directory containing subfolders with .txt files
process_files(directory_path)
# Out:
# Tokens have been successfully written to data/en_DW\treetagger_output\'chaos' & 'despair' at gaza hospital after israeli strike on 'safe zone' - un eyewitness  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\'chaos' & 'despair' at gaza hospital after israeli strike on 'safe zone' - un eyewitness  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\'chaos' & 'despair' at gaza hospital after israeli strike on 'safe zone' - un eyewitness  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\'it is time for this war to end' kamala harris speaks after meeting israeli pm netanyahu  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\'it is time for this war to end' kamala harris speaks after meeting israeli pm netanyahu  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\'it is time for this war to end' kamala harris speaks after meeting israeli pm netanyahu  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\'no other way to respond to hamas after october 7' israel’s ambassador to germany  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\'no other way to respond to hamas after october 7' israel’s ambassador to germany  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\'no other way to respond to hamas after october 7' israel’s ambassador to germany  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\'our first role is to protect israeli civilians' - idf spokesperson on the war in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\'our first role is to protect israeli civilians' - idf spokesperson on the war in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\'our first role is to protect israeli civilians' - idf spokesperson on the war in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\'responsibility for the overall security of gaza' netanyahu hints at prolonged military presence_words.txt
# Words have been written to data/en_DW\treetagger_output\'responsibility for the overall security of gaza' netanyahu hints at prolonged military presence_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\'responsibility for the overall security of gaza' netanyahu hints at prolonged military presence_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\'take the prisoners, bring our families home' relatives of hostages hope for deal  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\'take the prisoners, bring our families home' relatives of hostages hope for deal  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\'take the prisoners, bring our families home' relatives of hostages hope for deal  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\'time is running out' — former israeli government advisor on hamas-held hostages  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\'time is running out' — former israeli government advisor on hamas-held hostages  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\'time is running out' — former israeli government advisor on hamas-held hostages  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\'when fighting a monster, you cannot become a monster' ian bremmer on the israel-hamas conflict_words.txt
# Words have been written to data/en_DW\treetagger_output\'when fighting a monster, you cannot become a monster' ian bremmer on the israel-hamas conflict_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\'when fighting a monster, you cannot become a monster' ian bremmer on the israel-hamas conflict_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\28 premature babies arrive in egypt from gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\28 premature babies arrive in egypt from gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\28 premature babies arrive in egypt from gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\54 thai nationals being held hostage by hamas  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\54 thai nationals being held hostage by hamas  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\54 thai nationals being held hostage by hamas  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\85 journalists have already died in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\85 journalists have already died in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\85 journalists have already died in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\a week that changed the middle east  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\a week that changed the middle east  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\a week that changed the middle east  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\after death of hamas leader in beirut how will hezbollah respond  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\after death of hamas leader in beirut how will hezbollah respond  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\after death of hamas leader in beirut how will hezbollah respond  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\after encircling khan younis – what are the idf’s plans for the coming days  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\after encircling khan younis – what are the idf’s plans for the coming days  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\after encircling khan younis – what are the idf’s plans for the coming days  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\after killing of aid workers, how have aid organizations been affected  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\after killing of aid workers, how have aid organizations been affected  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\after killing of aid workers, how have aid organizations been affected  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\after netanyhau comments, what is israel’s end-game in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\after netanyhau comments, what is israel’s end-game in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\after netanyhau comments, what is israel’s end-game in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\after six months of war, are hostages in gaza being forgotten  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\after six months of war, are hostages in gaza being forgotten  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\after six months of war, are hostages in gaza being forgotten  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\after successful release what can be expected in the coming days  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\after successful release what can be expected in the coming days  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\after successful release what can be expected in the coming days  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\agencies rush to deliver aid to gaza as long as truce holds  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\agencies rush to deliver aid to gaza as long as truce holds  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\agencies rush to deliver aid to gaza as long as truce holds  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\aid groups accuse israel of targeting gaza's water and sanitation services  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\aid groups accuse israel of targeting gaza's water and sanitation services  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\aid groups accuse israel of targeting gaza's water and sanitation services  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\aid organizations warn that the current heatwave deepens humanitarian crisis in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\aid organizations warn that the current heatwave deepens humanitarian crisis in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\aid organizations warn that the current heatwave deepens humanitarian crisis in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\airlines suspend flights to lebanon, iran, and israel over fears of intensifying regional conflict_words.txt
# Words have been written to data/en_DW\treetagger_output\airlines suspend flights to lebanon, iran, and israel over fears of intensifying regional conflict_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\airlines suspend flights to lebanon, iran, and israel over fears of intensifying regional conflict_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\al-shifa hospital in gaza raided while families of hamas hostages march  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\al-shifa hospital in gaza raided while families of hamas hostages march  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\al-shifa hospital in gaza raided while families of hamas hostages march  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\all you need to know about the killing of hamas political leader haniyeh  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\all you need to know about the killing of hamas political leader haniyeh  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\all you need to know about the killing of hamas political leader haniyeh  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\amid fears of israeli offensive, parents struggle to provide for their children in rafah  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\amid fears of israeli offensive, parents struggle to provide for their children in rafah  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\amid fears of israeli offensive, parents struggle to provide for their children in rafah  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\an israeli and a palestinian state will the two sides listen to the eu  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\an israeli and a palestinian state will the two sides listen to the eu  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\an israeli and a palestinian state will the two sides listen to the eu  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\another strike reported at jabaliya refugee camp in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\another strike reported at jabaliya refugee camp in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\another strike reported at jabaliya refugee camp in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\anti-war protesters interrupt biden's campaign speech  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\anti-war protesters interrupt biden's campaign speech  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\anti-war protesters interrupt biden's campaign speech  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\antony blinken visits israel, reiterates us support i dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\antony blinken visits israel, reiterates us support i dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\antony blinken visits israel, reiterates us support i dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\appeal to avoid an escalation of the conflict  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\appeal to avoid an escalation of the conflict  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\appeal to avoid an escalation of the conflict  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\are israel and lebanon inching closer to a full-scale war  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\are israel and lebanon inching closer to a full-scale war  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\are israel and lebanon inching closer to a full-scale war  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\are we already in the midst of a regional war in the middle east_words.txt
# Words have been written to data/en_DW\treetagger_output\are we already in the midst of a regional war in the middle east_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\are we already in the midst of a regional war in the middle east_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\are we getting an accurate picture of what is happening in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\are we getting an accurate picture of what is happening in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\are we getting an accurate picture of what is happening in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\army chief iran's missile attack on israel's territory will be met with a response  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\army chief iran's missile attack on israel's territory will be met with a response  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\army chief iran's missile attack on israel's territory will be met with a response  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\assessing the war's impact on the israeli economy  dw business_words.txt
# Words have been written to data/en_DW\treetagger_output\assessing the war's impact on the israeli economy  dw business_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\assessing the war's impact on the israeli economy  dw business_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\at least 1 dead after ramming, stabbing incident near tel aviv  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\at least 1 dead after ramming, stabbing incident near tel aviv  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\at least 1 dead after ramming, stabbing incident near tel aviv  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\at least 3 dead in shooting at jerusalem bus stop  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\at least 3 dead in shooting at jerusalem bus stop  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\at least 3 dead in shooting at jerusalem bus stop  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\attacks and retaliatory strikes why the red sea conflict is so dangerous  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\attacks and retaliatory strikes why the red sea conflict is so dangerous  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\attacks and retaliatory strikes why the red sea conflict is so dangerous  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\authorities open investigation into dam collapse  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\authorities open investigation into dam collapse  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\authorities open investigation into dam collapse  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\baerbock says world court ruling on gaza is binding  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\baerbock says world court ruling on gaza is binding  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\baerbock says world court ruling on gaza is binding  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\behind israel’s use of unguided munitions in gaza   dw analysis_words.txt
# Words have been written to data/en_DW\treetagger_output\behind israel’s use of unguided munitions in gaza   dw analysis_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\behind israel’s use of unguided munitions in gaza   dw analysis_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\benjamin netanyahu at odds with his war cabinet and military generals  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\benjamin netanyahu at odds with his war cabinet and military generals  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\benjamin netanyahu at odds with his war cabinet and military generals  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\benny gantz at the white house how united is israel's government on gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\benny gantz at the white house how united is israel's government on gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\benny gantz at the white house how united is israel's government on gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\benny gantz slams netanyahu's 'empty promises' as he quits israel's war cabinet  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\benny gantz slams netanyahu's 'empty promises' as he quits israel's war cabinet  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\benny gantz slams netanyahu's 'empty promises' as he quits israel's war cabinet  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\berlin hosts large rally in solidarity with israel  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\berlin hosts large rally in solidarity with israel  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\berlin hosts large rally in solidarity with israel  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\biden calls for 'credible plan' by israel to ensure safety of civilians in rafah  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\biden calls for 'credible plan' by israel to ensure safety of civilians in rafah  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\biden calls for 'credible plan' by israel to ensure safety of civilians in rafah  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\biden hamas and putin both seek to 'completely annihilate a neighboring democracy'  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\biden hamas and putin both seek to 'completely annihilate a neighboring democracy'  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\biden hamas and putin both seek to 'completely annihilate a neighboring democracy'  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\biden optimistic about gaza cease-fire 'bridging proposal' what are the snags  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\biden optimistic about gaza cease-fire 'bridging proposal' what are the snags  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\biden optimistic about gaza cease-fire 'bridging proposal' what are the snags  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken heads to middle east as israel says it will change military tactics in gaza_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken heads to middle east as israel says it will change military tactics in gaza_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken heads to middle east as israel says it will change military tactics in gaza_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken heads to mideast how could he push israel toward cease-fire  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken heads to mideast how could he push israel toward cease-fire  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken heads to mideast how could he push israel toward cease-fire  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken in israel can the us dictate a less intense war in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken in israel can the us dictate a less intense war in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken in israel can the us dictate a less intense war in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken in israel says netanyahu backs us truce plan  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken in israel says netanyahu backs us truce plan  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken in israel says netanyahu backs us truce plan  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken in israel to discuss allowing more aid into gaza  dw analysis_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken in israel to discuss allowing more aid into gaza  dw analysis_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken in israel to discuss allowing more aid into gaza  dw analysis_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken in israel what can us diplomacy do to end the war  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken in israel what can us diplomacy do to end the war  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken in israel what can us diplomacy do to end the war  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken in saudi arabia for gaza cease-fire talks  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken in saudi arabia for gaza cease-fire talks  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken in saudi arabia for gaza cease-fire talks  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken in the middle east what are gaza cease-fire deal breakers  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken in the middle east what are gaza cease-fire deal breakers  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken in the middle east what are gaza cease-fire deal breakers  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken on diplomacy tour amid fears of escalation in middle east conflict  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken on diplomacy tour amid fears of escalation in middle east conflict  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken on diplomacy tour amid fears of escalation in middle east conflict  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken on yet another middle east tour what's on the agenda  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken on yet another middle east tour what's on the agenda  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken on yet another middle east tour what's on the agenda  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken us circulated un draft resolution on gaza truce  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken us circulated un draft resolution on gaza truce  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken us circulated un draft resolution on gaza truce  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken visits ankara to discuss gaza as turkey-israel tensions soar  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken visits ankara to discuss gaza as turkey-israel tensions soar  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken visits ankara to discuss gaza as turkey-israel tensions soar  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\blinken ‘an extraordinarily generous proposal on the part of israel’  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\blinken ‘an extraordinarily generous proposal on the part of israel’  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\blinken ‘an extraordinarily generous proposal on the part of israel’  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\boycott, protests and standing ovations surround netanyahu's speech in the us  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\boycott, protests and standing ovations surround netanyahu's speech in the us  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\boycott, protests and standing ovations surround netanyahu's speech in the us  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\breaking news israel targets hezbollah commander in beirut strike  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\breaking news israel targets hezbollah commander in beirut strike  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\breaking news israel targets hezbollah commander in beirut strike  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can blinken achieve wider peace in middle east  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\can blinken achieve wider peace in middle east  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can blinken achieve wider peace in middle east  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can blinken's visit to israel lead to a gaza cease-fire deal  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\can blinken's visit to israel lead to a gaza cease-fire deal  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can blinken's visit to israel lead to a gaza cease-fire deal  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can germans unite on israel-hamas war after berlin's violent protests  focus on europe_words.txt
# Words have been written to data/en_DW\treetagger_output\can germans unite on israel-hamas war after berlin's violent protests  focus on europe_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can germans unite on israel-hamas war after berlin's violent protests  focus on europe_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can germany mediate between israel and iran  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\can germany mediate between israel and iran  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can germany mediate between israel and iran  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can israel and lebanon's hezbollah avoid further conflict  news desk_words.txt
# Words have been written to data/en_DW\treetagger_output\can israel and lebanon's hezbollah avoid further conflict  news desk_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can israel and lebanon's hezbollah avoid further conflict  news desk_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can israel prove its claims of unrwa complicity in hamas terror  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\can israel prove its claims of unrwa complicity in hamas terror  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can israel prove its claims of unrwa complicity in hamas terror  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can israel stand alone without weapons deliveries from the us  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\can israel stand alone without weapons deliveries from the us  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can israel stand alone without weapons deliveries from the us  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can social media shape the course of the israel-hamas conflict  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\can social media shape the course of the israel-hamas conflict  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can social media shape the course of the israel-hamas conflict  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can the eu help hostages in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\can the eu help hostages in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can the eu help hostages in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can the gaza cease-fire talks be salvaged  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\can the gaza cease-fire talks be salvaged  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can the gaza cease-fire talks be salvaged  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can the icj stop israel's blockade of food deliveries into gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\can the icj stop israel's blockade of food deliveries into gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can the icj stop israel's blockade of food deliveries into gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\can the international court of justice stop the war in gaza  dw analysis_words.txt
# Words have been written to data/en_DW\treetagger_output\can the international court of justice stop the war in gaza  dw analysis_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\can the international court of justice stop the war in gaza  dw analysis_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\cease-fire negotiations resume for israel-hamas war  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\cease-fire negotiations resume for israel-hamas war  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\cease-fire negotiations resume for israel-hamas war  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\cease-fire talks continue amid warnings on internally displaced palestinians  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\cease-fire talks continue amid warnings on internally displaced palestinians  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\cease-fire talks continue amid warnings on internally displaced palestinians  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\challenges facing palestinian men seeking asylum in europe as they flee the war in gaza   dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\challenges facing palestinian men seeking asylum in europe as they flee the war in gaza   dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\challenges facing palestinian men seeking asylum in europe as they flee the war in gaza   dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\chaos in the israeli parliament  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\chaos in the israeli parliament  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\chaos in the israeli parliament  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\civilian casualties prompt protests as israel continues to pound gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\civilian casualties prompt protests as israel continues to pound gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\civilian casualties prompt protests as israel continues to pound gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\civilians killed and abducted how are israelis dealing with the horror  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\civilians killed and abducted how are israelis dealing with the horror  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\civilians killed and abducted how are israelis dealing with the horror  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\concern mounts for civilians as israel orders rafah evacuation  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\concern mounts for civilians as israel orders rafah evacuation  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\concern mounts for civilians as israel orders rafah evacuation  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\concerns grow over possible iranian attack on israel  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\concerns grow over possible iranian attack on israel  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\concerns grow over possible iranian attack on israel  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\conflicting reports about what happened in gaza – what we do and don't know  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\conflicting reports about what happened in gaza – what we do and don't know  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\conflicting reports about what happened in gaza – what we do and don't know  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\could blinken broker a humanitarian pause in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\could blinken broker a humanitarian pause in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\could blinken broker a humanitarian pause in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\could further european countries recognize palestinian statehood  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\could further european countries recognize palestinian statehood  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\could further european countries recognize palestinian statehood  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\could hezbollah drag lebanon into a war with israel  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\could hezbollah drag lebanon into a war with israel  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\could hezbollah drag lebanon into a war with israel  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\could israel's large-scale west bank operation backfire   dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\could israel's large-scale west bank operation backfire   dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\could israel's large-scale west bank operation backfire   dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\could violence in the middle east threaten the social peace in germany  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\could violence in the middle east threaten the social peace in germany  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\could violence in the middle east threaten the social peace in germany  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\countries urge israel-hamas cease-fire talks following hamas leader assassination  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\countries urge israel-hamas cease-fire talks following hamas leader assassination  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\countries urge israel-hamas cease-fire talks following hamas leader assassination  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\cpj 53 reporters confirmed dead in israel-gaza war  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\cpj 53 reporters confirmed dead in israel-gaza war  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\cpj 53 reporters confirmed dead in israel-gaza war  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\damascus iranian commander and officers killed, officials claim israel behind strike  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\damascus iranian commander and officers killed, officials claim israel behind strike  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\damascus iranian commander and officers killed, officials claim israel behind strike  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\deadly israeli attack on school in gaza refugee camp  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\deadly israeli attack on school in gaza refugee camp  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\deadly israeli attack on school in gaza refugee camp  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\deadly strikes on southern gaza after mass evacuation order  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\deadly strikes on southern gaza after mass evacuation order  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\deadly strikes on southern gaza after mass evacuation order  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\decoding the underground israel's tactical war on hamas tunnels  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\decoding the underground israel's tactical war on hamas tunnels  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\decoding the underground israel's tactical war on hamas tunnels  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\delayed release of more hostages, prisoners after deal nearly collapses  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\delayed release of more hostages, prisoners after deal nearly collapses  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\delayed release of more hostages, prisoners after deal nearly collapses  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\destruction and agricultural collapse ecocide in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\destruction and agricultural collapse ecocide in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\destruction and agricultural collapse ecocide in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\dire conditions at al mawasi humanitarian zone  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\dire conditions at al mawasi humanitarian zone  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\dire conditions at al mawasi humanitarian zone  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\displaced families in gaza face daily ordeal  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\displaced families in gaza face daily ordeal  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\displaced families in gaza face daily ordeal  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\displaced gazans in search of security  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\displaced gazans in search of security  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\displaced gazans in search of security  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\displaced gazans return to their homes in the north  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\displaced gazans return to their homes in the north  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\displaced gazans return to their homes in the north  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\displaced palestinians ‘will we go back home or will people just die here’  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\displaced palestinians ‘will we go back home or will people just die here’  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\displaced palestinians ‘will we go back home or will people just die here’  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\dnc pro-palestinian protesters demand cease-fire and end to us arms transfers to israel   dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\dnc pro-palestinian protesters demand cease-fire and end to us arms transfers to israel   dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\dnc pro-palestinian protesters demand cease-fire and end to us arms transfers to israel   dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\do iran and its allies pose an existential threat to israel  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\do iran and its allies pose an existential threat to israel  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\do iran and its allies pose an existential threat to israel  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\do western warnings to israel remain without consequence  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\do western warnings to israel remain without consequence  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\do western warnings to israel remain without consequence  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\doctor at maternity hospital in rafah in one shift, two or three children die  dw news_words.txt
# ...
# Words have been written to data/en_DW\treetagger_output\why israel must provide evidence that hamas is in al-shifa hospital  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why israel must provide evidence that hamas is in al-shifa hospital  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why israel's multi-layered air defense system is so effective  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why israel's multi-layered air defense system is so effective  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why israel's multi-layered air defense system is so effective  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why israel's planned rafah offensive tests ties with egypt  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why israel's planned rafah offensive tests ties with egypt  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why israel's planned rafah offensive tests ties with egypt  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why israeli prime minister benjamin netanyahu has moved to dissolve his war cabinet  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why israeli prime minister benjamin netanyahu has moved to dissolve his war cabinet  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why israeli prime minister benjamin netanyahu has moved to dissolve his war cabinet  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why israelis and palestinians have yet to agree on the details of a two-state solution  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why israelis and palestinians have yet to agree on the details of a two-state solution  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why israelis and palestinians have yet to agree on the details of a two-state solution  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why israel’s ultra-orthodox jews might soon have to serve in the military  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why israel’s ultra-orthodox jews might soon have to serve in the military  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why israel’s ultra-orthodox jews might soon have to serve in the military  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why nicaragua is dragging germany before the international court of justice  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why nicaragua is dragging germany before the international court of justice  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why nicaragua is dragging germany before the international court of justice  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why one israeli critic thinks the war in gaza serves those in power  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why one israeli critic thinks the war in gaza serves those in power  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why one israeli critic thinks the war in gaza serves those in power  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why south africa has taken israel to the un court  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why south africa has taken israel to the un court  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why south africa has taken israel to the un court  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why the israeli-palestinian conflict is so hard to resolve  mapped out_words.txt
# Words have been written to data/en_DW\treetagger_output\why the israeli-palestinian conflict is so hard to resolve  mapped out_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why the israeli-palestinian conflict is so hard to resolve  mapped out_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why the un blacklists the israel defense forces for harming children  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why the un blacklists the israel defense forces for harming children  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why the un blacklists the israel defense forces for harming children  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why the us warns israel against major operation in rafah  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why the us warns israel against major operation in rafah  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why the us warns israel against major operation in rafah  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\why tracking civilian casualties in the israel-hamas war is so difficult  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\why tracking civilian casualties in the israel-hamas war is so difficult  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\why tracking civilian casualties in the israel-hamas war is so difficult  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will death of woman in west bank trigger stronger response from israel's allies  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will death of woman in west bank trigger stronger response from israel's allies  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will death of woman in west bank trigger stronger response from israel's allies  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will gaza aid pier be enough to save famine-stricken palestinians  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will gaza aid pier be enough to save famine-stricken palestinians  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will gaza aid pier be enough to save famine-stricken palestinians  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will iran retaliate against israel again  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will iran retaliate against israel again  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will iran retaliate against israel again  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will iran's response to haniyeh's killing be rational or driven by emotion  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will iran's response to haniyeh's killing be rational or driven by emotion  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will iran's response to haniyeh's killing be rational or driven by emotion  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will israel continue its war in gaza despite increasing international isolation  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will israel continue its war in gaza despite increasing international isolation  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will israel continue its war in gaza despite increasing international isolation  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will israel listen to biden's calls to protect gaza civilians  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will israel listen to biden's calls to protect gaza civilians  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will israel listen to biden's calls to protect gaza civilians  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will israel negotiate with hamas for the release of hostages  dw news⁣_words.txt
# Words have been written to data/en_DW\treetagger_output\will israel negotiate with hamas for the release of hostages  dw news⁣_words.txt
# Error running TreeTagger: 	reading parameters ...
#
# ERROR: Can't open for reading: data/en_DW\treetagger_output\will israel negotiate with hamas for the release of hostages  dw news?_words.txt
# aborted.
#
# Tokens have been successfully written to data/en_DW\treetagger_output\will israel's deadly strike on gaza school force cease-fire  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will israel's deadly strike on gaza school force cease-fire  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will israel's deadly strike on gaza school force cease-fire  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will the appointment of sinwar change anything in hamas' strategy  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will the appointment of sinwar change anything in hamas' strategy  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will the appointment of sinwar change anything in hamas' strategy  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will the latest cease-fire proposal end the gaza war  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will the latest cease-fire proposal end the gaza war  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will the latest cease-fire proposal end the gaza war  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\Will the new maritime aid corridor bring substantial relief into Gaza  DW News.ar_words.txt
# Words have been written to data/en_DW\treetagger_output\Will the new maritime aid corridor bring substantial relief into Gaza  DW News.ar_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\Will the new maritime aid corridor bring substantial relief into Gaza  DW News.ar_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will the new maritime aid corridor bring substantial relief into gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will the new maritime aid corridor bring substantial relief into gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will the new maritime aid corridor bring substantial relief into gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will the war resume at full force when the truce ends  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will the war resume at full force when the truce ends  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will the war resume at full force when the truce ends  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will there be a new land crossing into northern gaza as israel's military says  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will there be a new land crossing into northern gaza as israel's military says  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will there be a new land crossing into northern gaza as israel's military says  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\will unrwa funding cuts hit wrong target   dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\will unrwa funding cuts hit wrong target   dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\will unrwa funding cuts hit wrong target   dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\with energy supply down, time my be running out for injured people in gaza’s hospitals  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\with energy supply down, time my be running out for injured people in gaza’s hospitals  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\with energy supply down, time my be running out for injured people in gaza’s hospitals  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\without ceasefire, is there any way to meet humanitarian needs in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\without ceasefire, is there any way to meet humanitarian needs in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\without ceasefire, is there any way to meet humanitarian needs in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\world leaders meet in egypt for summit on israel-hamas war  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\world leaders meet in egypt for summit on israel-hamas war  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\world leaders meet in egypt for summit on israel-hamas war  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\yemen's houthi rebels claim attacks on ships in the red sea  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\yemen's houthi rebels claim attacks on ships in the red sea  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\yemen's houthi rebels claim attacks on ships in the red sea  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\yemen's houthis claim responsibility for fatal drone attack on tel aviv  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\yemen's houthis claim responsibility for fatal drone attack on tel aviv  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\yemen's houthis claim responsibility for fatal drone attack on tel aviv  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\‘beyond worst case scenario’ the situation on the ground in gaza  dw news_words.txt
# Words have been written to data/en_DW\treetagger_output\‘beyond worst case scenario’ the situation on the ground in gaza  dw news_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\‘beyond worst case scenario’ the situation on the ground in gaza  dw news_treetagger_output.txt
# Tokens have been successfully written to data/en_DW\treetagger_output\‘it’s time for this war to end’_words.txt
# Words have been written to data/en_DW\treetagger_output\‘it’s time for this war to end’_words.txt
# TreeTagger output has been written to data/en_DW\treetagger_output\‘it’s time for this war to end’_treetagger_output.txt
